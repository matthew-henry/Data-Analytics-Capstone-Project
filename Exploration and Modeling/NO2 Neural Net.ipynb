# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
tf.random.set_seed(123)

# %%
df = pd.read_csv('LA NO2.csv', parse_dates=['date', 'utc','local'], index_col='utc')
df = df.resample('d').mean()
df = df.interpolate(method='time')
df.head()
# Out:
#                value  mobile   latitude  longitude  url  averaging_time  \
# utc
# 2020-01-02  0.010444     0.0  34.181976 -118.36304  NaN             1.0
# 2020-01-03  0.027417     0.0  34.181976 -118.36304  NaN             1.0
# 2020-01-04  0.029000     0.0  34.181976 -118.36304  NaN             1.0
# 2020-01-05  0.023833     0.0  34.181976 -118.36304  NaN             1.0
# 2020-01-06  0.024357     0.0  34.181976 -118.36304  NaN             1.0
#
#                  station  latitude-2  longitude-2  elevation  ...     slp  \
# utc                                                           ...
# 2020-01-02  7.228802e+10    34.20056    -118.3575      225.9  ...  1012.5
# 2020-01-03  7.228802e+10    34.20056    -118.3575      225.9  ...  1019.9
# 2020-01-04  7.228802e+10    34.20056    -118.3575      225.9  ...  1025.1
# 2020-01-05  7.228802e+10    34.20056    -118.3575      225.9  ...  1024.2
# 2020-01-06  7.228802e+10    34.20056    -118.3575      225.9  ...  1023.5
#
#               stp  visibility  wind_speed  max_sustained_wind       gust  \
# utc
# 2020-01-02  986.8        10.0         4.5                12.0        NaN
# 2020-01-03  994.0        10.0         1.6                 6.0        NaN
# 2020-01-04  999.1        10.0         1.1                 6.0        NaN
# 2020-01-05  998.0        10.0         2.8                11.1  18.100000
# 2020-01-06  997.6        10.0         2.5                 6.0  16.733333
#
#             max_temp  min_temp  precipitation  snow_depth
# utc
# 2020-01-02      68.0      43.0            0.0         0.0
# 2020-01-03      73.0      45.0            0.0         0.0
# 2020-01-04      73.0      42.1            0.0         0.0
# 2020-01-05      73.0      42.1            0.0         0.0
# 2020-01-06      75.0      42.1            0.0         0.0
#
# [5 rows x 22 columns]

# %%
min_date = df.index.values.min()
max_date = df.index.values.max()
train_percent = 0.80
interval = max_date - min_date
train_cutoff = min_date + train_percent*interval

train_df = df[df.index.values <= train_cutoff]
test_df = df[df.index.values > train_cutoff]

# %%
train = train_df[['value', 'stp', 'wind_speed', 'max_sustained_wind', 'max_temp', 'min_temp','temperature', 'dewpoint']]
test = test_df[['value', 'stp', 'wind_speed', 'max_sustained_wind', 'max_temp', 'min_temp','temperature', 'dewpoint']]

# %%
train
#look_back = 1
#trainX, trainY = create_dataset(train, look_back)
#testX, testY = create_dataset(test, look_back)
# Out:
#                value    stp  wind_speed  max_sustained_wind  max_temp  \
# utc
# 2020-01-02  0.010444  986.8         4.5                12.0      68.0
# 2020-01-03  0.027417  994.0         1.6                 6.0      73.0
# 2020-01-04  0.029000  999.1         1.1                 6.0      73.0
# 2020-01-05  0.023833  998.0         2.8                11.1      73.0
# 2020-01-06  0.024357  997.6         2.5                 6.0      75.0
# ...              ...    ...         ...                 ...       ...
# 2022-04-01  0.009212  984.8         4.0                 8.9      73.0
# 2022-04-02  0.006211  988.4         4.0                 8.0      73.0
# 2022-04-03  0.003112  988.1         4.5                 8.9      69.1
# 2022-04-04  0.006617  986.1         5.0                 8.9      73.9
# 2022-04-05  0.007991  985.8         7.3                15.0      89.1
#
#             min_temp  temperature  dewpoint
# utc
# 2020-01-02      43.0         56.6      42.1
# 2020-01-03      45.0         56.7      39.3
# 2020-01-04      42.1         55.5      38.4
# 2020-01-05      42.1         54.7      36.3
# 2020-01-06      42.1         57.6      29.1
# ...              ...          ...       ...
# 2022-04-01      53.1         61.2      49.2
# 2022-04-02      53.1         59.7      50.3
# 2022-04-03      54.0         62.2      50.3
# 2022-04-04      54.0         62.2      50.2
# 2022-04-05      54.0         71.8      47.7
#
# [825 rows x 8 columns]

# %%
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X=[]
    y=[]
    for i in range(len(df_as_np)-window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %%
window_size = 5
X, y = df_to_X_y(train, window_size)
valX, valy = df_to_X_y(test, window_size)

# %%
X.shape, y.shape
# Out:
# ((820, 5, 8), (820,))

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import InputLayer

model = Sequential()
model.add(LSTM(64, input_shape=(5,8)))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))
model.compile(loss='mse', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                18688
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 19,217
# Trainable params: 19,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, y, epochs=100, validation_data=(valX, valy), verbose=2)
# Out:
# Epoch 1/100
# 26/26 - 1s - loss: 0.0185 - val_loss: 4.0066e-05 - 1s/epoch - 57ms/step
# Epoch 2/100
# 26/26 - 0s - loss: 7.0163e-04 - val_loss: 3.4776e-04 - 82ms/epoch - 3ms/step
# Epoch 3/100
# 26/26 - 0s - loss: 1.1052e-04 - val_loss: 1.0143e-04 - 82ms/epoch - 3ms/step
# Epoch 4/100
# 26/26 - 0s - loss: 7.6335e-05 - val_loss: 7.6101e-05 - 81ms/epoch - 3ms/step
# Epoch 5/100
# 26/26 - 0s - loss: 7.4407e-05 - val_loss: 4.5870e-05 - 82ms/epoch - 3ms/step
# Epoch 6/100
# 26/26 - 0s - loss: 7.3379e-05 - val_loss: 4.3118e-05 - 81ms/epoch - 3ms/step
# Epoch 7/100
# 26/26 - 0s - loss: 7.4724e-05 - val_loss: 6.5727e-05 - 81ms/epoch - 3ms/step
# Epoch 8/100
# 26/26 - 0s - loss: 7.4969e-05 - val_loss: 6.7167e-05 - 82ms/epoch - 3ms/step
# Epoch 9/100
# 26/26 - 0s - loss: 7.3953e-05 - val_loss: 5.5908e-05 - 81ms/epoch - 3ms/step
# Epoch 10/100
# 26/26 - 0s - loss: 7.5240e-05 - val_loss: 4.1877e-05 - 80ms/epoch - 3ms/step
# Epoch 11/100
# 26/26 - 0s - loss: 7.6576e-05 - val_loss: 6.2668e-05 - 79ms/epoch - 3ms/step
# Epoch 12/100
# 26/26 - 0s - loss: 8.6909e-05 - val_loss: 2.3956e-05 - 80ms/epoch - 3ms/step
# Epoch 13/100
# 26/26 - 0s - loss: 7.3341e-05 - val_loss: 4.7592e-05 - 79ms/epoch - 3ms/step
# Epoch 14/100
# 26/26 - 0s - loss: 7.4191e-05 - val_loss: 5.7980e-05 - 76ms/epoch - 3ms/step
# Epoch 15/100
# 26/26 - 0s - loss: 7.4775e-05 - val_loss: 4.4619e-05 - 76ms/epoch - 3ms/step
# Epoch 16/100
# 26/26 - 0s - loss: 7.3689e-05 - val_loss: 4.2440e-05 - 79ms/epoch - 3ms/step
# Epoch 17/100
# 26/26 - 0s - loss: 7.3214e-05 - val_loss: 5.2816e-05 - 77ms/epoch - 3ms/step
# Epoch 18/100
# 26/26 - 0s - loss: 7.3753e-05 - val_loss: 3.9447e-05 - 77ms/epoch - 3ms/step
# Epoch 19/100
# 26/26 - 0s - loss: 7.5298e-05 - val_loss: 4.2713e-05 - 82ms/epoch - 3ms/step
# Epoch 20/100
# 26/26 - 0s - loss: 7.3909e-05 - val_loss: 3.9673e-05 - 78ms/epoch - 3ms/step
# Epoch 21/100
# 26/26 - 0s - loss: 7.4887e-05 - val_loss: 3.1263e-05 - 78ms/epoch - 3ms/step
# Epoch 22/100
# 26/26 - 0s - loss: 7.5919e-05 - val_loss: 3.5093e-05 - 129ms/epoch - 5ms/step
# Epoch 23/100
# 26/26 - 0s - loss: 7.4280e-05 - val_loss: 6.1970e-05 - 80ms/epoch - 3ms/step
# Epoch 24/100
# 26/26 - 0s - loss: 7.4248e-05 - val_loss: 2.3826e-05 - 77ms/epoch - 3ms/step
# Epoch 25/100
# 26/26 - 0s - loss: 7.7763e-05 - val_loss: 4.2536e-05 - 80ms/epoch - 3ms/step
# Epoch 26/100
# 26/26 - 0s - loss: 7.4067e-05 - val_loss: 7.4162e-05 - 79ms/epoch - 3ms/step
# Epoch 27/100
# 26/26 - 0s - loss: 7.5603e-05 - val_loss: 5.2149e-05 - 78ms/epoch - 3ms/step
# Epoch 28/100
# 26/26 - 0s - loss: 7.3466e-05 - val_loss: 3.7058e-05 - 79ms/epoch - 3ms/step
# Epoch 29/100
# 26/26 - 0s - loss: 7.4763e-05 - val_loss: 5.0192e-05 - 79ms/epoch - 3ms/step
# Epoch 30/100
# 26/26 - 0s - loss: 7.3910e-05 - val_loss: 4.1057e-05 - 80ms/epoch - 3ms/step
# Epoch 31/100
# 26/26 - 0s - loss: 7.3812e-05 - val_loss: 8.9030e-05 - 79ms/epoch - 3ms/step
# Epoch 32/100
# 26/26 - 0s - loss: 7.6626e-05 - val_loss: 3.5789e-05 - 80ms/epoch - 3ms/step
# Epoch 33/100
# 26/26 - 0s - loss: 7.7074e-05 - val_loss: 3.8210e-05 - 78ms/epoch - 3ms/step
# Epoch 34/100
# 26/26 - 0s - loss: 7.3574e-05 - val_loss: 4.7922e-05 - 81ms/epoch - 3ms/step
# Epoch 35/100
# 26/26 - 0s - loss: 7.7081e-05 - val_loss: 3.6642e-05 - 77ms/epoch - 3ms/step
# Epoch 36/100
# 26/26 - 0s - loss: 7.6617e-05 - val_loss: 2.9725e-05 - 78ms/epoch - 3ms/step
# Epoch 37/100
# 26/26 - 0s - loss: 7.9689e-05 - val_loss: 3.8215e-05 - 79ms/epoch - 3ms/step
# Epoch 38/100
# 26/26 - 0s - loss: 7.5440e-05 - val_loss: 3.4430e-05 - 77ms/epoch - 3ms/step
# Epoch 39/100
# 26/26 - 0s - loss: 7.4427e-05 - val_loss: 4.7053e-05 - 78ms/epoch - 3ms/step
# Epoch 40/100
# 26/26 - 0s - loss: 7.5214e-05 - val_loss: 6.7300e-05 - 78ms/epoch - 3ms/step
# Epoch 41/100
# 26/26 - 0s - loss: 7.6443e-05 - val_loss: 3.6057e-05 - 77ms/epoch - 3ms/step
# Epoch 42/100
# 26/26 - 0s - loss: 7.8195e-05 - val_loss: 4.4599e-05 - 79ms/epoch - 3ms/step
# Epoch 43/100
# 26/26 - 0s - loss: 7.9297e-05 - val_loss: 3.9992e-05 - 78ms/epoch - 3ms/step
# Epoch 44/100
# 26/26 - 0s - loss: 7.5870e-05 - val_loss: 4.6256e-05 - 78ms/epoch - 3ms/step
# Epoch 45/100
# 26/26 - 0s - loss: 8.1533e-05 - val_loss: 8.6432e-05 - 78ms/epoch - 3ms/step
# Epoch 46/100
# 26/26 - 0s - loss: 7.6626e-05 - val_loss: 5.8289e-05 - 79ms/epoch - 3ms/step
# Epoch 47/100
# 26/26 - 0s - loss: 7.6625e-05 - val_loss: 2.1882e-05 - 78ms/epoch - 3ms/step
# Epoch 48/100
# 26/26 - 0s - loss: 7.7656e-05 - val_loss: 1.0042e-04 - 77ms/epoch - 3ms/step
# Epoch 49/100
# 26/26 - 0s - loss: 7.8305e-05 - val_loss: 2.9354e-05 - 78ms/epoch - 3ms/step
# Epoch 50/100
# 26/26 - 0s - loss: 7.6264e-05 - val_loss: 4.6941e-05 - 78ms/epoch - 3ms/step
# Epoch 51/100
# 26/26 - 0s - loss: 7.5542e-05 - val_loss: 5.3364e-05 - 79ms/epoch - 3ms/step
# Epoch 52/100
# 26/26 - 0s - loss: 7.4728e-05 - val_loss: 6.7707e-05 - 78ms/epoch - 3ms/step
# Epoch 53/100
# 26/26 - 0s - loss: 7.7268e-05 - val_loss: 7.4460e-05 - 79ms/epoch - 3ms/step
# Epoch 54/100
# 26/26 - 0s - loss: 9.7675e-05 - val_loss: 4.2545e-05 - 80ms/epoch - 3ms/step
# Epoch 55/100
# 26/26 - 0s - loss: 7.5365e-05 - val_loss: 4.2780e-05 - 80ms/epoch - 3ms/step
# Epoch 56/100
# 26/26 - 0s - loss: 7.4155e-05 - val_loss: 3.9037e-05 - 79ms/epoch - 3ms/step
# Epoch 57/100
# 26/26 - 0s - loss: 7.6187e-05 - val_loss: 3.6588e-05 - 80ms/epoch - 3ms/step
# Epoch 58/100
# 26/26 - 0s - loss: 7.9207e-05 - val_loss: 5.3383e-05 - 82ms/epoch - 3ms/step
# Epoch 59/100
# 26/26 - 0s - loss: 7.6042e-05 - val_loss: 4.0650e-05 - 81ms/epoch - 3ms/step
# Epoch 60/100
# 26/26 - 0s - loss: 7.7594e-05 - val_loss: 6.0142e-05 - 79ms/epoch - 3ms/step
# Epoch 61/100
# 26/26 - 0s - loss: 7.4003e-05 - val_loss: 2.6297e-05 - 77ms/epoch - 3ms/step
# Epoch 62/100
# 26/26 - 0s - loss: 7.6865e-05 - val_loss: 1.1622e-04 - 77ms/epoch - 3ms/step
# Epoch 63/100
# 26/26 - 0s - loss: 8.0859e-05 - val_loss: 3.5666e-05 - 76ms/epoch - 3ms/step
# Epoch 64/100
# 26/26 - 0s - loss: 7.5303e-05 - val_loss: 3.8934e-05 - 78ms/epoch - 3ms/step
# Epoch 65/100
# 26/26 - 0s - loss: 7.4828e-05 - val_loss: 6.1798e-05 - 77ms/epoch - 3ms/step
# Epoch 66/100
# 26/26 - 0s - loss: 7.6002e-05 - val_loss: 3.7474e-05 - 78ms/epoch - 3ms/step
# Epoch 67/100
# 26/26 - 0s - loss: 7.5885e-05 - val_loss: 7.0354e-05 - 79ms/epoch - 3ms/step
# Epoch 68/100
# 26/26 - 0s - loss: 8.0376e-05 - val_loss: 4.3290e-05 - 78ms/epoch - 3ms/step
# Epoch 69/100
# 26/26 - 0s - loss: 7.3477e-05 - val_loss: 4.4575e-05 - 77ms/epoch - 3ms/step
# Epoch 70/100
# 26/26 - 0s - loss: 7.8120e-05 - val_loss: 3.9088e-05 - 77ms/epoch - 3ms/step
# Epoch 71/100
# 26/26 - 0s - loss: 8.4243e-05 - val_loss: 4.8768e-05 - 79ms/epoch - 3ms/step
# Epoch 72/100
# 26/26 - 0s - loss: 7.7495e-05 - val_loss: 3.1966e-05 - 78ms/epoch - 3ms/step
# Epoch 73/100
# 26/26 - 0s - loss: 7.7196e-05 - val_loss: 1.0248e-04 - 79ms/epoch - 3ms/step
# Epoch 74/100
# 26/26 - 0s - loss: 8.3570e-05 - val_loss: 4.8617e-05 - 77ms/epoch - 3ms/step
# Epoch 75/100
# 26/26 - 0s - loss: 8.1885e-05 - val_loss: 5.8973e-05 - 77ms/epoch - 3ms/step
# Epoch 76/100
# 26/26 - 0s - loss: 7.8178e-05 - val_loss: 6.0939e-05 - 78ms/epoch - 3ms/step
# Epoch 77/100
# 26/26 - 0s - loss: 7.5058e-05 - val_loss: 4.9250e-05 - 78ms/epoch - 3ms/step
# Epoch 78/100
# 26/26 - 0s - loss: 7.6944e-05 - val_loss: 2.1926e-05 - 77ms/epoch - 3ms/step
# Epoch 79/100
# 26/26 - 0s - loss: 8.0360e-05 - val_loss: 6.7945e-05 - 79ms/epoch - 3ms/step
# Epoch 80/100
# 26/26 - 0s - loss: 7.8355e-05 - val_loss: 4.5513e-05 - 79ms/epoch - 3ms/step
# Epoch 81/100
# 26/26 - 0s - loss: 7.5341e-05 - val_loss: 6.8178e-05 - 77ms/epoch - 3ms/step
# Epoch 82/100
# 26/26 - 0s - loss: 8.0703e-05 - val_loss: 2.8083e-05 - 78ms/epoch - 3ms/step
# Epoch 83/100
# 26/26 - 0s - loss: 7.7278e-05 - val_loss: 3.9821e-05 - 76ms/epoch - 3ms/step
# Epoch 84/100
# 26/26 - 0s - loss: 8.1116e-05 - val_loss: 2.0123e-05 - 78ms/epoch - 3ms/step
# Epoch 85/100
# 26/26 - 0s - loss: 8.5145e-05 - val_loss: 9.3457e-05 - 77ms/epoch - 3ms/step
# Epoch 86/100
# 26/26 - 0s - loss: 8.1765e-05 - val_loss: 6.5116e-05 - 77ms/epoch - 3ms/step
# Epoch 87/100
# 26/26 - 0s - loss: 7.5731e-05 - val_loss: 4.6906e-05 - 78ms/epoch - 3ms/step
# Epoch 88/100
# 26/26 - 0s - loss: 7.6222e-05 - val_loss: 4.7493e-05 - 77ms/epoch - 3ms/step
# Epoch 89/100
# 26/26 - 0s - loss: 7.5744e-05 - val_loss: 7.4353e-05 - 77ms/epoch - 3ms/step
# Epoch 90/100
# 26/26 - 0s - loss: 7.8686e-05 - val_loss: 2.9093e-05 - 77ms/epoch - 3ms/step
# Epoch 91/100
# 26/26 - 0s - loss: 8.1363e-05 - val_loss: 2.5171e-05 - 78ms/epoch - 3ms/step
# Epoch 92/100
# 26/26 - 0s - loss: 8.1021e-05 - val_loss: 1.0595e-04 - 78ms/epoch - 3ms/step
# Epoch 93/100
# 26/26 - 0s - loss: 7.9655e-05 - val_loss: 7.7783e-05 - 79ms/epoch - 3ms/step
# Epoch 94/100
# 26/26 - 0s - loss: 8.0141e-05 - val_loss: 1.9959e-05 - 79ms/epoch - 3ms/step
# Epoch 95/100
# 26/26 - 0s - loss: 8.6420e-05 - val_loss: 5.9297e-05 - 78ms/epoch - 3ms/step
# Epoch 96/100
# 26/26 - 0s - loss: 7.7418e-05 - val_loss: 8.8315e-05 - 80ms/epoch - 3ms/step
# Epoch 97/100
# 26/26 - 0s - loss: 7.7604e-05 - val_loss: 5.7011e-05 - 79ms/epoch - 3ms/step
# Epoch 98/100
# 26/26 - 0s - loss: 7.8095e-05 - val_loss: 2.4996e-05 - 79ms/epoch - 3ms/step
# Epoch 99/100
# 26/26 - 0s - loss: 9.0728e-05 - val_loss: 2.0662e-05 - 98ms/epoch - 4ms/step
# Epoch 100/100
# 26/26 - 0s - loss: 8.5353e-05 - val_loss: 8.0157e-05 - 77ms/epoch - 3ms/step

# %%
model2 = Sequential()
model2.add(LSTM(64, input_shape=(5,8)))
model2.add(Dense(8, 'sigmoid'))
model2.add(Dense(1, 'linear'))
model2.compile(loss='mse', optimizer='adam')

# %%
model2.fit(X, y, epochs=300, validation_data=(valX, valy), verbose=2)
# Out:
# Epoch 1/300
# 26/26 - 1s - loss: 1.2097 - val_loss: 0.5929 - 1s/epoch - 51ms/step
# Epoch 2/300
# 26/26 - 0s - loss: 0.3607 - val_loss: 0.1781 - 81ms/epoch - 3ms/step
# Epoch 3/300
# 26/26 - 0s - loss: 0.1055 - val_loss: 0.0455 - 82ms/epoch - 3ms/step
# Epoch 4/300
# 26/26 - 0s - loss: 0.0261 - val_loss: 0.0095 - 81ms/epoch - 3ms/step
# Epoch 5/300
# 26/26 - 0s - loss: 0.0055 - val_loss: 0.0015 - 80ms/epoch - 3ms/step
# Epoch 6/300
# 26/26 - 0s - loss: 9.8257e-04 - val_loss: 1.4128e-04 - 81ms/epoch - 3ms/step
# Epoch 7/300
# 26/26 - 0s - loss: 1.9081e-04 - val_loss: 1.9342e-05 - 79ms/epoch - 3ms/step
# Epoch 8/300
# 26/26 - 0s - loss: 8.3695e-05 - val_loss: 3.7173e-05 - 78ms/epoch - 3ms/step
# Epoch 9/300
# 26/26 - 0s - loss: 7.3591e-05 - val_loss: 4.8017e-05 - 78ms/epoch - 3ms/step
# Epoch 10/300
# 26/26 - 0s - loss: 7.3002e-05 - val_loss: 4.9501e-05 - 89ms/epoch - 3ms/step
# Epoch 11/300
# 26/26 - 0s - loss: 7.3035e-05 - val_loss: 5.0392e-05 - 78ms/epoch - 3ms/step
# Epoch 12/300
# 26/26 - 0s - loss: 7.3028e-05 - val_loss: 5.0433e-05 - 107ms/epoch - 4ms/step
# Epoch 13/300
# 26/26 - 0s - loss: 7.3066e-05 - val_loss: 4.9925e-05 - 107ms/epoch - 4ms/step
# Epoch 14/300
# 26/26 - 0s - loss: 7.3047e-05 - val_loss: 4.9887e-05 - 79ms/epoch - 3ms/step
# Epoch 15/300
# 26/26 - 0s - loss: 7.3002e-05 - val_loss: 5.1358e-05 - 79ms/epoch - 3ms/step
# Epoch 16/300
# 26/26 - 0s - loss: 7.3024e-05 - val_loss: 5.0591e-05 - 79ms/epoch - 3ms/step
# Epoch 17/300
# 26/26 - 0s - loss: 7.3018e-05 - val_loss: 5.0177e-05 - 79ms/epoch - 3ms/step
# Epoch 18/300
# 26/26 - 0s - loss: 7.3033e-05 - val_loss: 5.0273e-05 - 141ms/epoch - 5ms/step
# Epoch 19/300
# 26/26 - 0s - loss: 7.3085e-05 - val_loss: 4.8906e-05 - 78ms/epoch - 3ms/step
# Epoch 20/300
# 26/26 - 0s - loss: 7.3094e-05 - val_loss: 5.1415e-05 - 78ms/epoch - 3ms/step
# Epoch 21/300
# 26/26 - 0s - loss: 7.3107e-05 - val_loss: 4.8985e-05 - 112ms/epoch - 4ms/step
# Epoch 22/300
# 26/26 - 0s - loss: 7.3103e-05 - val_loss: 5.1283e-05 - 93ms/epoch - 4ms/step
# Epoch 23/300
# 26/26 - 0s - loss: 7.3030e-05 - val_loss: 4.8186e-05 - 78ms/epoch - 3ms/step
# Epoch 24/300
# 26/26 - 0s - loss: 7.3078e-05 - val_loss: 5.0955e-05 - 78ms/epoch - 3ms/step
# Epoch 25/300
# 26/26 - 0s - loss: 7.3057e-05 - val_loss: 4.9947e-05 - 77ms/epoch - 3ms/step
# Epoch 26/300
# 26/26 - 0s - loss: 7.3075e-05 - val_loss: 4.9083e-05 - 79ms/epoch - 3ms/step
# Epoch 27/300
# 26/26 - 0s - loss: 7.2999e-05 - val_loss: 5.0231e-05 - 78ms/epoch - 3ms/step
# Epoch 28/300
# 26/26 - 0s - loss: 7.3022e-05 - val_loss: 5.0817e-05 - 78ms/epoch - 3ms/step
# Epoch 29/300
# 26/26 - 0s - loss: 7.3051e-05 - val_loss: 4.9235e-05 - 78ms/epoch - 3ms/step
# Epoch 30/300
# 26/26 - 0s - loss: 7.3076e-05 - val_loss: 5.0860e-05 - 78ms/epoch - 3ms/step
# Epoch 31/300
# 26/26 - 0s - loss: 7.3111e-05 - val_loss: 4.9128e-05 - 78ms/epoch - 3ms/step
# Epoch 32/300
# 26/26 - 0s - loss: 7.3225e-05 - val_loss: 5.2421e-05 - 76ms/epoch - 3ms/step
# Epoch 33/300
# 26/26 - 0s - loss: 7.3055e-05 - val_loss: 4.8619e-05 - 78ms/epoch - 3ms/step
# Epoch 34/300
# 26/26 - 0s - loss: 7.3027e-05 - val_loss: 5.0278e-05 - 77ms/epoch - 3ms/step
# Epoch 35/300
# 26/26 - 0s - loss: 7.3032e-05 - val_loss: 5.0123e-05 - 78ms/epoch - 3ms/step
# Epoch 36/300
# 26/26 - 0s - loss: 7.3037e-05 - val_loss: 5.0143e-05 - 76ms/epoch - 3ms/step
# Epoch 37/300
# 26/26 - 0s - loss: 7.3109e-05 - val_loss: 5.1613e-05 - 79ms/epoch - 3ms/step
# Epoch 38/300
# 26/26 - 0s - loss: 7.3046e-05 - val_loss: 4.8550e-05 - 110ms/epoch - 4ms/step
# Epoch 39/300
# 26/26 - 0s - loss: 7.3042e-05 - val_loss: 5.0272e-05 - 79ms/epoch - 3ms/step
# Epoch 40/300
# 26/26 - 0s - loss: 7.3034e-05 - val_loss: 4.9248e-05 - 79ms/epoch - 3ms/step
# Epoch 41/300
# 26/26 - 0s - loss: 7.3031e-05 - val_loss: 5.0415e-05 - 79ms/epoch - 3ms/step
# Epoch 42/300
# 26/26 - 0s - loss: 7.3156e-05 - val_loss: 4.9058e-05 - 80ms/epoch - 3ms/step
# Epoch 43/300
# 26/26 - 0s - loss: 7.3027e-05 - val_loss: 5.1365e-05 - 80ms/epoch - 3ms/step
# Epoch 44/300
# 26/26 - 0s - loss: 7.3070e-05 - val_loss: 4.8264e-05 - 80ms/epoch - 3ms/step
# Epoch 45/300
# 26/26 - 0s - loss: 7.3247e-05 - val_loss: 4.9954e-05 - 78ms/epoch - 3ms/step
# Epoch 46/300
# 26/26 - 0s - loss: 7.3026e-05 - val_loss: 5.1350e-05 - 77ms/epoch - 3ms/step
# Epoch 47/300
# 26/26 - 0s - loss: 7.3095e-05 - val_loss: 5.1370e-05 - 79ms/epoch - 3ms/step
# Epoch 48/300
# 26/26 - 0s - loss: 7.3103e-05 - val_loss: 4.7628e-05 - 79ms/epoch - 3ms/step
# Epoch 49/300
# 26/26 - 0s - loss: 7.3136e-05 - val_loss: 5.0279e-05 - 79ms/epoch - 3ms/step
# Epoch 50/300
# 26/26 - 0s - loss: 7.3043e-05 - val_loss: 4.9245e-05 - 79ms/epoch - 3ms/step
# Epoch 51/300
# 26/26 - 0s - loss: 7.3084e-05 - val_loss: 5.1142e-05 - 79ms/epoch - 3ms/step
# Epoch 52/300
# 26/26 - 0s - loss: 7.3131e-05 - val_loss: 4.9371e-05 - 80ms/epoch - 3ms/step
# Epoch 53/300
# 26/26 - 0s - loss: 7.3077e-05 - val_loss: 4.9658e-05 - 78ms/epoch - 3ms/step
# Epoch 54/300
# 26/26 - 0s - loss: 7.3326e-05 - val_loss: 4.9702e-05 - 79ms/epoch - 3ms/step
# Epoch 55/300
# 26/26 - 0s - loss: 7.3069e-05 - val_loss: 4.8983e-05 - 79ms/epoch - 3ms/step
# Epoch 56/300
# 26/26 - 0s - loss: 7.3216e-05 - val_loss: 5.0647e-05 - 79ms/epoch - 3ms/step
# Epoch 57/300
# 26/26 - 0s - loss: 7.3109e-05 - val_loss: 5.3021e-05 - 80ms/epoch - 3ms/step
# Epoch 58/300
# 26/26 - 0s - loss: 7.3235e-05 - val_loss: 4.7893e-05 - 79ms/epoch - 3ms/step
# Epoch 59/300
# 26/26 - 0s - loss: 7.3081e-05 - val_loss: 5.1808e-05 - 79ms/epoch - 3ms/step
# Epoch 60/300
# 26/26 - 0s - loss: 7.3137e-05 - val_loss: 4.8894e-05 - 79ms/epoch - 3ms/step
# Epoch 61/300
# 26/26 - 0s - loss: 7.3250e-05 - val_loss: 5.1856e-05 - 78ms/epoch - 3ms/step
# Epoch 62/300
# 26/26 - 0s - loss: 7.3031e-05 - val_loss: 4.6424e-05 - 79ms/epoch - 3ms/step
# Epoch 63/300
# 26/26 - 0s - loss: 7.3163e-05 - val_loss: 5.1715e-05 - 79ms/epoch - 3ms/step
# Epoch 64/300
# 26/26 - 0s - loss: 7.3006e-05 - val_loss: 4.8796e-05 - 83ms/epoch - 3ms/step
# Epoch 65/300
# 26/26 - 0s - loss: 7.3156e-05 - val_loss: 4.8365e-05 - 81ms/epoch - 3ms/step
# Epoch 66/300
# 26/26 - 0s - loss: 7.3097e-05 - val_loss: 5.0863e-05 - 79ms/epoch - 3ms/step
# Epoch 67/300
# 26/26 - 0s - loss: 7.3069e-05 - val_loss: 5.1077e-05 - 79ms/epoch - 3ms/step
# Epoch 68/300
# 26/26 - 0s - loss: 7.3067e-05 - val_loss: 4.8263e-05 - 78ms/epoch - 3ms/step
# Epoch 69/300
# 26/26 - 0s - loss: 7.3099e-05 - val_loss: 5.4694e-05 - 80ms/epoch - 3ms/step
# Epoch 70/300
# 26/26 - 0s - loss: 7.3319e-05 - val_loss: 4.8082e-05 - 79ms/epoch - 3ms/step
# Epoch 71/300
# 26/26 - 0s - loss: 7.3042e-05 - val_loss: 5.1416e-05 - 78ms/epoch - 3ms/step
# Epoch 72/300
# 26/26 - 0s - loss: 7.3055e-05 - val_loss: 4.9753e-05 - 84ms/epoch - 3ms/step
# Epoch 73/300
# 26/26 - 0s - loss: 7.3088e-05 - val_loss: 4.9364e-05 - 82ms/epoch - 3ms/step
# Epoch 74/300
# 26/26 - 0s - loss: 7.3081e-05 - val_loss: 5.1418e-05 - 79ms/epoch - 3ms/step
# Epoch 75/300
# 26/26 - 0s - loss: 7.3049e-05 - val_loss: 4.9799e-05 - 79ms/epoch - 3ms/step
# Epoch 76/300
# 26/26 - 0s - loss: 7.3080e-05 - val_loss: 5.3086e-05 - 80ms/epoch - 3ms/step
# Epoch 77/300
# 26/26 - 0s - loss: 7.3091e-05 - val_loss: 4.6874e-05 - 79ms/epoch - 3ms/step
# Epoch 78/300
# 26/26 - 0s - loss: 7.3078e-05 - val_loss: 5.1649e-05 - 79ms/epoch - 3ms/step
# Epoch 79/300
# 26/26 - 0s - loss: 7.3154e-05 - val_loss: 4.9719e-05 - 79ms/epoch - 3ms/step
# Epoch 80/300
# 26/26 - 0s - loss: 7.3076e-05 - val_loss: 5.1537e-05 - 79ms/epoch - 3ms/step
# Epoch 81/300
# 26/26 - 0s - loss: 7.3237e-05 - val_loss: 5.2102e-05 - 80ms/epoch - 3ms/step
# Epoch 82/300
# 26/26 - 0s - loss: 7.3395e-05 - val_loss: 4.8966e-05 - 79ms/epoch - 3ms/step
# Epoch 83/300
# 26/26 - 0s - loss: 7.3119e-05 - val_loss: 5.1666e-05 - 79ms/epoch - 3ms/step
# Epoch 84/300
# 26/26 - 0s - loss: 7.3135e-05 - val_loss: 5.0791e-05 - 80ms/epoch - 3ms/step
# Epoch 85/300
# 26/26 - 0s - loss: 7.3479e-05 - val_loss: 4.7728e-05 - 78ms/epoch - 3ms/step
# Epoch 86/300
# 26/26 - 0s - loss: 7.3179e-05 - val_loss: 5.5750e-05 - 78ms/epoch - 3ms/step
# Epoch 87/300
# 26/26 - 0s - loss: 7.2982e-05 - val_loss: 4.6946e-05 - 78ms/epoch - 3ms/step
# Epoch 88/300
# 26/26 - 0s - loss: 7.3295e-05 - val_loss: 5.0232e-05 - 76ms/epoch - 3ms/step
# Epoch 89/300
# 26/26 - 0s - loss: 7.3196e-05 - val_loss: 4.9044e-05 - 78ms/epoch - 3ms/step
# Epoch 90/300
# 26/26 - 0s - loss: 7.3063e-05 - val_loss: 5.1159e-05 - 77ms/epoch - 3ms/step
# Epoch 91/300
# 26/26 - 0s - loss: 7.3076e-05 - val_loss: 4.9211e-05 - 77ms/epoch - 3ms/step
# Epoch 92/300
# 26/26 - 0s - loss: 7.3202e-05 - val_loss: 5.0688e-05 - 78ms/epoch - 3ms/step
# Epoch 93/300
# 26/26 - 0s - loss: 7.3228e-05 - val_loss: 4.8643e-05 - 79ms/epoch - 3ms/step
# Epoch 94/300
# 26/26 - 0s - loss: 7.3127e-05 - val_loss: 4.8940e-05 - 78ms/epoch - 3ms/step
# Epoch 95/300
# 26/26 - 0s - loss: 7.3083e-05 - val_loss: 4.9695e-05 - 78ms/epoch - 3ms/step
# Epoch 96/300
# 26/26 - 0s - loss: 7.3328e-05 - val_loss: 4.6162e-05 - 77ms/epoch - 3ms/step
# Epoch 97/300
# 26/26 - 0s - loss: 7.2938e-05 - val_loss: 5.3834e-05 - 76ms/epoch - 3ms/step
# Epoch 98/300
# 26/26 - 0s - loss: 7.3619e-05 - val_loss: 5.3568e-05 - 78ms/epoch - 3ms/step
# Epoch 99/300
# 26/26 - 0s - loss: 7.3193e-05 - val_loss: 4.8003e-05 - 80ms/epoch - 3ms/step
# Epoch 100/300
# 26/26 - 0s - loss: 7.3167e-05 - val_loss: 5.0643e-05 - 78ms/epoch - 3ms/step
# Epoch 101/300
# 26/26 - 0s - loss: 7.3289e-05 - val_loss: 5.4258e-05 - 78ms/epoch - 3ms/step
# Epoch 102/300
# 26/26 - 0s - loss: 7.3184e-05 - val_loss: 4.6192e-05 - 77ms/epoch - 3ms/step
# Epoch 103/300
# 26/26 - 0s - loss: 7.3232e-05 - val_loss: 4.6834e-05 - 78ms/epoch - 3ms/step
# Epoch 104/300
# 26/26 - 0s - loss: 7.3250e-05 - val_loss: 4.8110e-05 - 79ms/epoch - 3ms/step
# Epoch 105/300
# 26/26 - 0s - loss: 7.3457e-05 - val_loss: 4.4692e-05 - 80ms/epoch - 3ms/step
# Epoch 106/300
# 26/26 - 0s - loss: 7.3367e-05 - val_loss: 5.6858e-05 - 80ms/epoch - 3ms/step
# Epoch 107/300
# 26/26 - 0s - loss: 7.3193e-05 - val_loss: 4.4995e-05 - 79ms/epoch - 3ms/step
# Epoch 108/300
# 26/26 - 0s - loss: 7.3011e-05 - val_loss: 5.4040e-05 - 79ms/epoch - 3ms/step
# Epoch 109/300
# 26/26 - 0s - loss: 7.3321e-05 - val_loss: 4.9465e-05 - 80ms/epoch - 3ms/step
# Epoch 110/300
# 26/26 - 0s - loss: 7.3187e-05 - val_loss: 5.1233e-05 - 80ms/epoch - 3ms/step
# Epoch 111/300
# 26/26 - 0s - loss: 7.3071e-05 - val_loss: 5.0037e-05 - 79ms/epoch - 3ms/step
# Epoch 112/300
# 26/26 - 0s - loss: 7.3152e-05 - val_loss: 5.0112e-05 - 78ms/epoch - 3ms/step
# Epoch 113/300
# 26/26 - 0s - loss: 7.3064e-05 - val_loss: 4.7326e-05 - 80ms/epoch - 3ms/step
# Epoch 114/300
# 26/26 - 0s - loss: 7.3737e-05 - val_loss: 5.7663e-05 - 79ms/epoch - 3ms/step
# Epoch 115/300
# 26/26 - 0s - loss: 7.3463e-05 - val_loss: 5.3887e-05 - 86ms/epoch - 3ms/step
# Epoch 116/300
# 26/26 - 0s - loss: 7.3346e-05 - val_loss: 5.2312e-05 - 78ms/epoch - 3ms/step
# Epoch 117/300
# 26/26 - 0s - loss: 7.3499e-05 - val_loss: 4.5880e-05 - 78ms/epoch - 3ms/step
# Epoch 118/300
# 26/26 - 0s - loss: 7.3238e-05 - val_loss: 5.1008e-05 - 77ms/epoch - 3ms/step
# Epoch 119/300
# 26/26 - 0s - loss: 7.3376e-05 - val_loss: 5.8161e-05 - 78ms/epoch - 3ms/step
# Epoch 120/300
# 26/26 - 0s - loss: 7.3922e-05 - val_loss: 5.4601e-05 - 77ms/epoch - 3ms/step
# Epoch 121/300
# 26/26 - 0s - loss: 7.3511e-05 - val_loss: 4.6773e-05 - 77ms/epoch - 3ms/step
# Epoch 122/300
# 26/26 - 0s - loss: 7.3392e-05 - val_loss: 5.2358e-05 - 77ms/epoch - 3ms/step
# Epoch 123/300
# 26/26 - 0s - loss: 7.3701e-05 - val_loss: 4.5254e-05 - 77ms/epoch - 3ms/step
# Epoch 124/300
# 26/26 - 0s - loss: 7.3298e-05 - val_loss: 4.5915e-05 - 78ms/epoch - 3ms/step
# Epoch 125/300
# 26/26 - 0s - loss: 7.4004e-05 - val_loss: 6.2972e-05 - 77ms/epoch - 3ms/step
# Epoch 126/300
# 26/26 - 0s - loss: 7.3653e-05 - val_loss: 5.2139e-05 - 77ms/epoch - 3ms/step
# Epoch 127/300
# 26/26 - 0s - loss: 7.3254e-05 - val_loss: 4.9436e-05 - 80ms/epoch - 3ms/step
# Epoch 128/300
# 26/26 - 0s - loss: 7.3756e-05 - val_loss: 6.8352e-05 - 78ms/epoch - 3ms/step
# Epoch 129/300
# 26/26 - 0s - loss: 7.3809e-05 - val_loss: 4.7246e-05 - 78ms/epoch - 3ms/step
# Epoch 130/300
# 26/26 - 0s - loss: 7.3396e-05 - val_loss: 5.0869e-05 - 78ms/epoch - 3ms/step
# Epoch 131/300
# 26/26 - 0s - loss: 7.3183e-05 - val_loss: 5.0536e-05 - 76ms/epoch - 3ms/step
# Epoch 132/300
# 26/26 - 0s - loss: 7.3503e-05 - val_loss: 4.2354e-05 - 79ms/epoch - 3ms/step
# Epoch 133/300
# 26/26 - 0s - loss: 7.3582e-05 - val_loss: 4.7183e-05 - 78ms/epoch - 3ms/step
# Epoch 134/300
# 26/26 - 0s - loss: 7.3251e-05 - val_loss: 4.7059e-05 - 77ms/epoch - 3ms/step
# Epoch 135/300
# 26/26 - 0s - loss: 7.3130e-05 - val_loss: 4.4163e-05 - 77ms/epoch - 3ms/step
# Epoch 136/300
# 26/26 - 0s - loss: 7.3340e-05 - val_loss: 5.5451e-05 - 78ms/epoch - 3ms/step
# Epoch 137/300
# 26/26 - 0s - loss: 7.3506e-05 - val_loss: 4.6445e-05 - 78ms/epoch - 3ms/step
# Epoch 138/300
# 26/26 - 0s - loss: 7.3457e-05 - val_loss: 6.0833e-05 - 78ms/epoch - 3ms/step
# Epoch 139/300
# 26/26 - 0s - loss: 7.3682e-05 - val_loss: 5.0476e-05 - 79ms/epoch - 3ms/step
# Epoch 140/300
# 26/26 - 0s - loss: 7.3411e-05 - val_loss: 4.8520e-05 - 79ms/epoch - 3ms/step
# Epoch 141/300
# 26/26 - 0s - loss: 7.3555e-05 - val_loss: 5.7167e-05 - 80ms/epoch - 3ms/step
# Epoch 142/300
# 26/26 - 0s - loss: 7.3385e-05 - val_loss: 5.7736e-05 - 79ms/epoch - 3ms/step
# Epoch 143/300
# 26/26 - 0s - loss: 7.3158e-05 - val_loss: 4.0420e-05 - 78ms/epoch - 3ms/step
# Epoch 144/300
# 26/26 - 0s - loss: 7.4103e-05 - val_loss: 4.3906e-05 - 78ms/epoch - 3ms/step
# Epoch 145/300
# 26/26 - 0s - loss: 7.3869e-05 - val_loss: 4.3557e-05 - 78ms/epoch - 3ms/step
# Epoch 146/300
# 26/26 - 0s - loss: 7.3357e-05 - val_loss: 4.6745e-05 - 77ms/epoch - 3ms/step
# Epoch 147/300
# 26/26 - 0s - loss: 7.4427e-05 - val_loss: 4.4852e-05 - 77ms/epoch - 3ms/step
# Epoch 148/300
# 26/26 - 0s - loss: 7.3372e-05 - val_loss: 5.6781e-05 - 78ms/epoch - 3ms/step
# Epoch 149/300
# 26/26 - 0s - loss: 7.3826e-05 - val_loss: 5.3974e-05 - 79ms/epoch - 3ms/step
# Epoch 150/300
# 26/26 - 0s - loss: 7.4184e-05 - val_loss: 4.2715e-05 - 77ms/epoch - 3ms/step
# Epoch 151/300
# 26/26 - 0s - loss: 7.3436e-05 - val_loss: 3.9892e-05 - 77ms/epoch - 3ms/step
# Epoch 152/300
# 26/26 - 0s - loss: 7.3941e-05 - val_loss: 5.5615e-05 - 77ms/epoch - 3ms/step
# Epoch 153/300
# 26/26 - 0s - loss: 7.4033e-05 - val_loss: 5.3969e-05 - 78ms/epoch - 3ms/step
# Epoch 154/300
# 26/26 - 0s - loss: 7.3979e-05 - val_loss: 4.5768e-05 - 79ms/epoch - 3ms/step
# Epoch 155/300
# 26/26 - 0s - loss: 7.4497e-05 - val_loss: 3.8457e-05 - 79ms/epoch - 3ms/step
# Epoch 156/300
# 26/26 - 0s - loss: 7.3276e-05 - val_loss: 5.1776e-05 - 78ms/epoch - 3ms/step
# Epoch 157/300
# 26/26 - 0s - loss: 7.3451e-05 - val_loss: 4.9157e-05 - 77ms/epoch - 3ms/step
# Epoch 158/300
# 26/26 - 0s - loss: 7.3246e-05 - val_loss: 5.2286e-05 - 78ms/epoch - 3ms/step
# Epoch 159/300
# 26/26 - 0s - loss: 7.3158e-05 - val_loss: 4.9949e-05 - 78ms/epoch - 3ms/step
# Epoch 160/300
# 26/26 - 0s - loss: 7.3560e-05 - val_loss: 4.6783e-05 - 80ms/epoch - 3ms/step
# Epoch 161/300
# 26/26 - 0s - loss: 7.3675e-05 - val_loss: 5.7282e-05 - 78ms/epoch - 3ms/step
# Epoch 162/300
# 26/26 - 0s - loss: 7.3793e-05 - val_loss: 5.0163e-05 - 78ms/epoch - 3ms/step
# Epoch 163/300
# 26/26 - 0s - loss: 7.4368e-05 - val_loss: 4.3565e-05 - 77ms/epoch - 3ms/step
# Epoch 164/300
# 26/26 - 0s - loss: 7.2988e-05 - val_loss: 6.3901e-05 - 77ms/epoch - 3ms/step
# Epoch 165/300
# 26/26 - 0s - loss: 7.3805e-05 - val_loss: 5.4057e-05 - 80ms/epoch - 3ms/step
# Epoch 166/300
# 26/26 - 0s - loss: 7.4881e-05 - val_loss: 6.6562e-05 - 79ms/epoch - 3ms/step
# Epoch 167/300
# 26/26 - 0s - loss: 7.5723e-05 - val_loss: 6.8527e-05 - 79ms/epoch - 3ms/step
# Epoch 168/300
# 26/26 - 0s - loss: 7.3570e-05 - val_loss: 4.8191e-05 - 78ms/epoch - 3ms/step
# Epoch 169/300
# 26/26 - 0s - loss: 7.3119e-05 - val_loss: 5.0139e-05 - 80ms/epoch - 3ms/step
# Epoch 170/300
# 26/26 - 0s - loss: 7.3535e-05 - val_loss: 4.5915e-05 - 78ms/epoch - 3ms/step
# Epoch 171/300
# 26/26 - 0s - loss: 7.4209e-05 - val_loss: 5.7252e-05 - 79ms/epoch - 3ms/step
# Epoch 172/300
# 26/26 - 0s - loss: 7.4167e-05 - val_loss: 5.3150e-05 - 78ms/epoch - 3ms/step
# Epoch 173/300
# 26/26 - 0s - loss: 7.3502e-05 - val_loss: 4.5969e-05 - 77ms/epoch - 3ms/step
# Epoch 174/300
# 26/26 - 0s - loss: 7.3368e-05 - val_loss: 4.5958e-05 - 89ms/epoch - 3ms/step
# Epoch 175/300
# 26/26 - 0s - loss: 7.3226e-05 - val_loss: 3.7406e-05 - 78ms/epoch - 3ms/step
# Epoch 176/300
# 26/26 - 0s - loss: 7.3057e-05 - val_loss: 6.3545e-05 - 78ms/epoch - 3ms/step
# Epoch 177/300
# 26/26 - 0s - loss: 7.3120e-05 - val_loss: 5.1348e-05 - 79ms/epoch - 3ms/step
# Epoch 178/300
# 26/26 - 0s - loss: 7.3858e-05 - val_loss: 4.6589e-05 - 79ms/epoch - 3ms/step
# Epoch 179/300
# 26/26 - 0s - loss: 7.3219e-05 - val_loss: 4.3995e-05 - 86ms/epoch - 3ms/step
# Epoch 180/300
# 26/26 - 0s - loss: 7.4513e-05 - val_loss: 3.1036e-05 - 77ms/epoch - 3ms/step
# Epoch 181/300
# 26/26 - 0s - loss: 7.4416e-05 - val_loss: 3.9563e-05 - 77ms/epoch - 3ms/step
# Epoch 182/300
# 26/26 - 0s - loss: 7.3532e-05 - val_loss: 4.0231e-05 - 77ms/epoch - 3ms/step
# Epoch 183/300
# 26/26 - 0s - loss: 7.3423e-05 - val_loss: 4.6449e-05 - 78ms/epoch - 3ms/step
# Epoch 184/300
# 26/26 - 0s - loss: 7.3505e-05 - val_loss: 4.2919e-05 - 78ms/epoch - 3ms/step
# Epoch 185/300
# 26/26 - 0s - loss: 7.3047e-05 - val_loss: 3.6250e-05 - 78ms/epoch - 3ms/step
# Epoch 186/300
# 26/26 - 0s - loss: 7.6900e-05 - val_loss: 3.8550e-05 - 77ms/epoch - 3ms/step
# Epoch 187/300
# 26/26 - 0s - loss: 7.3491e-05 - val_loss: 4.6650e-05 - 79ms/epoch - 3ms/step
# Epoch 188/300
# 26/26 - 0s - loss: 7.3885e-05 - val_loss: 5.3910e-05 - 79ms/epoch - 3ms/step
# Epoch 189/300
# 26/26 - 0s - loss: 7.4774e-05 - val_loss: 6.3632e-05 - 77ms/epoch - 3ms/step
# Epoch 190/300
# 26/26 - 0s - loss: 7.3909e-05 - val_loss: 5.9094e-05 - 79ms/epoch - 3ms/step
# Epoch 191/300
# 26/26 - 0s - loss: 7.3659e-05 - val_loss: 4.4791e-05 - 80ms/epoch - 3ms/step
# Epoch 192/300
# 26/26 - 0s - loss: 7.4146e-05 - val_loss: 3.4213e-05 - 80ms/epoch - 3ms/step
# Epoch 193/300
# 26/26 - 0s - loss: 7.3464e-05 - val_loss: 3.8502e-05 - 81ms/epoch - 3ms/step
# Epoch 194/300
# 26/26 - 0s - loss: 7.3450e-05 - val_loss: 4.9484e-05 - 78ms/epoch - 3ms/step
# Epoch 195/300
# 26/26 - 0s - loss: 7.3712e-05 - val_loss: 5.0847e-05 - 78ms/epoch - 3ms/step
# Epoch 196/300
# 26/26 - 0s - loss: 7.3355e-05 - val_loss: 4.4576e-05 - 77ms/epoch - 3ms/step
# Epoch 197/300
# 26/26 - 0s - loss: 7.3349e-05 - val_loss: 3.9883e-05 - 78ms/epoch - 3ms/step
# Epoch 198/300
# 26/26 - 0s - loss: 7.3568e-05 - val_loss: 4.9541e-05 - 79ms/epoch - 3ms/step
# Epoch 199/300
# 26/26 - 0s - loss: 7.5200e-05 - val_loss: 3.1577e-05 - 78ms/epoch - 3ms/step
# Epoch 200/300
# 26/26 - 0s - loss: 7.6521e-05 - val_loss: 3.5785e-05 - 81ms/epoch - 3ms/step
# Epoch 201/300
# 26/26 - 0s - loss: 7.3667e-05 - val_loss: 5.3268e-05 - 80ms/epoch - 3ms/step
# Epoch 202/300
# 26/26 - 0s - loss: 7.5310e-05 - val_loss: 6.1623e-05 - 80ms/epoch - 3ms/step
# Epoch 203/300
# 26/26 - 0s - loss: 7.3741e-05 - val_loss: 4.1228e-05 - 79ms/epoch - 3ms/step
# Epoch 204/300
# 26/26 - 0s - loss: 7.3319e-05 - val_loss: 4.5445e-05 - 79ms/epoch - 3ms/step
# Epoch 205/300
# 26/26 - 0s - loss: 7.3970e-05 - val_loss: 5.9047e-05 - 80ms/epoch - 3ms/step
# Epoch 206/300
# 26/26 - 0s - loss: 7.4463e-05 - val_loss: 4.8841e-05 - 78ms/epoch - 3ms/step
# Epoch 207/300
# 26/26 - 0s - loss: 7.4432e-05 - val_loss: 4.7537e-05 - 77ms/epoch - 3ms/step
# Epoch 208/300
# 26/26 - 0s - loss: 7.4307e-05 - val_loss: 4.4981e-05 - 77ms/epoch - 3ms/step
# Epoch 209/300
# 26/26 - 0s - loss: 7.3273e-05 - val_loss: 4.1049e-05 - 78ms/epoch - 3ms/step
# Epoch 210/300
# 26/26 - 0s - loss: 7.4902e-05 - val_loss: 4.3324e-05 - 78ms/epoch - 3ms/step
# Epoch 211/300
# 26/26 - 0s - loss: 7.4480e-05 - val_loss: 5.5713e-05 - 79ms/epoch - 3ms/step
# Epoch 212/300
# 26/26 - 0s - loss: 7.3614e-05 - val_loss: 5.6960e-05 - 80ms/epoch - 3ms/step
# Epoch 213/300
# 26/26 - 0s - loss: 7.4205e-05 - val_loss: 6.1493e-05 - 78ms/epoch - 3ms/step
# Epoch 214/300
# 26/26 - 0s - loss: 7.5811e-05 - val_loss: 5.1762e-05 - 78ms/epoch - 3ms/step
# Epoch 215/300
# 26/26 - 0s - loss: 7.3747e-05 - val_loss: 5.2665e-05 - 77ms/epoch - 3ms/step
# Epoch 216/300
# 26/26 - 0s - loss: 7.4755e-05 - val_loss: 4.6604e-05 - 79ms/epoch - 3ms/step
# Epoch 217/300
# 26/26 - 0s - loss: 7.5106e-05 - val_loss: 4.0319e-05 - 78ms/epoch - 3ms/step
# Epoch 218/300
# 26/26 - 0s - loss: 7.3567e-05 - val_loss: 4.7882e-05 - 77ms/epoch - 3ms/step
# Epoch 219/300
# 26/26 - 0s - loss: 7.3109e-05 - val_loss: 4.1481e-05 - 78ms/epoch - 3ms/step
# Epoch 220/300
# 26/26 - 0s - loss: 7.3425e-05 - val_loss: 5.3476e-05 - 78ms/epoch - 3ms/step
# Epoch 221/300
# 26/26 - 0s - loss: 7.4542e-05 - val_loss: 7.5867e-05 - 78ms/epoch - 3ms/step
# Epoch 222/300
# 26/26 - 0s - loss: 7.5162e-05 - val_loss: 4.8369e-05 - 78ms/epoch - 3ms/step
# Epoch 223/300
# 26/26 - 0s - loss: 7.4058e-05 - val_loss: 4.3954e-05 - 78ms/epoch - 3ms/step
# Epoch 224/300
# 26/26 - 0s - loss: 7.3586e-05 - val_loss: 5.2529e-05 - 78ms/epoch - 3ms/step
# Epoch 225/300
# 26/26 - 0s - loss: 7.5241e-05 - val_loss: 6.6410e-05 - 81ms/epoch - 3ms/step
# Epoch 226/300
# 26/26 - 0s - loss: 7.3336e-05 - val_loss: 5.1965e-05 - 78ms/epoch - 3ms/step
# Epoch 227/300
# 26/26 - 0s - loss: 7.4068e-05 - val_loss: 4.0679e-05 - 79ms/epoch - 3ms/step
# Epoch 228/300
# 26/26 - 0s - loss: 7.5050e-05 - val_loss: 4.3749e-05 - 80ms/epoch - 3ms/step
# Epoch 229/300
# 26/26 - 0s - loss: 7.3909e-05 - val_loss: 3.9895e-05 - 79ms/epoch - 3ms/step
# Epoch 230/300
# 26/26 - 0s - loss: 7.7101e-05 - val_loss: 7.9999e-05 - 77ms/epoch - 3ms/step
# Epoch 231/300
# 26/26 - 0s - loss: 7.5291e-05 - val_loss: 4.2399e-05 - 77ms/epoch - 3ms/step
# Epoch 232/300
# 26/26 - 0s - loss: 7.3671e-05 - val_loss: 5.2829e-05 - 77ms/epoch - 3ms/step
# Epoch 233/300
# 26/26 - 0s - loss: 7.4060e-05 - val_loss: 4.3586e-05 - 79ms/epoch - 3ms/step
# Epoch 234/300
# 26/26 - 0s - loss: 7.4792e-05 - val_loss: 6.1923e-05 - 78ms/epoch - 3ms/step
# Epoch 235/300
# 26/26 - 0s - loss: 7.3537e-05 - val_loss: 6.6441e-05 - 78ms/epoch - 3ms/step
# Epoch 236/300
# 26/26 - 0s - loss: 7.4619e-05 - val_loss: 4.7369e-05 - 78ms/epoch - 3ms/step
# Epoch 237/300
# 26/26 - 0s - loss: 7.3436e-05 - val_loss: 6.5738e-05 - 78ms/epoch - 3ms/step
# Epoch 238/300
# 26/26 - 0s - loss: 7.6257e-05 - val_loss: 3.7714e-05 - 78ms/epoch - 3ms/step
# Epoch 239/300
# 26/26 - 0s - loss: 7.3795e-05 - val_loss: 4.1742e-05 - 80ms/epoch - 3ms/step
# Epoch 240/300
# 26/26 - 0s - loss: 7.4049e-05 - val_loss: 3.8853e-05 - 78ms/epoch - 3ms/step
# Epoch 241/300
# 26/26 - 0s - loss: 7.4512e-05 - val_loss: 5.2384e-05 - 80ms/epoch - 3ms/step
# Epoch 242/300
# 26/26 - 0s - loss: 7.5977e-05 - val_loss: 7.8034e-05 - 78ms/epoch - 3ms/step
# Epoch 243/300
# 26/26 - 0s - loss: 7.5363e-05 - val_loss: 5.2883e-05 - 77ms/epoch - 3ms/step
# Epoch 244/300
# 26/26 - 0s - loss: 7.3985e-05 - val_loss: 5.3238e-05 - 78ms/epoch - 3ms/step
# Epoch 245/300
# 26/26 - 0s - loss: 7.3464e-05 - val_loss: 4.0720e-05 - 76ms/epoch - 3ms/step
# Epoch 246/300
# 26/26 - 0s - loss: 7.3728e-05 - val_loss: 7.2851e-05 - 76ms/epoch - 3ms/step
# Epoch 247/300
# 26/26 - 0s - loss: 7.8211e-05 - val_loss: 7.2614e-05 - 78ms/epoch - 3ms/step
# Epoch 248/300
# 26/26 - 0s - loss: 8.1104e-05 - val_loss: 3.1683e-05 - 78ms/epoch - 3ms/step
# Epoch 249/300
# 26/26 - 0s - loss: 7.5036e-05 - val_loss: 3.5699e-05 - 77ms/epoch - 3ms/step
# Epoch 250/300
# 26/26 - 0s - loss: 7.4433e-05 - val_loss: 7.5344e-05 - 77ms/epoch - 3ms/step
# Epoch 251/300
# 26/26 - 0s - loss: 7.4275e-05 - val_loss: 3.8789e-05 - 79ms/epoch - 3ms/step
# Epoch 252/300
# 26/26 - 0s - loss: 7.7293e-05 - val_loss: 7.4577e-05 - 77ms/epoch - 3ms/step
# Epoch 253/300
# 26/26 - 0s - loss: 7.4047e-05 - val_loss: 3.0535e-05 - 80ms/epoch - 3ms/step
# Epoch 254/300
# 26/26 - 0s - loss: 7.4301e-05 - val_loss: 6.2203e-05 - 79ms/epoch - 3ms/step
# Epoch 255/300
# 26/26 - 0s - loss: 7.5813e-05 - val_loss: 4.0574e-05 - 79ms/epoch - 3ms/step
# Epoch 256/300
# 26/26 - 0s - loss: 7.3608e-05 - val_loss: 5.9599e-05 - 79ms/epoch - 3ms/step
# Epoch 257/300
# 26/26 - 0s - loss: 7.5185e-05 - val_loss: 3.5419e-05 - 79ms/epoch - 3ms/step
# Epoch 258/300
# 26/26 - 0s - loss: 7.3007e-05 - val_loss: 4.3246e-05 - 78ms/epoch - 3ms/step
# Epoch 259/300
# 26/26 - 0s - loss: 7.4263e-05 - val_loss: 4.6799e-05 - 80ms/epoch - 3ms/step
# Epoch 260/300
# 26/26 - 0s - loss: 7.4939e-05 - val_loss: 4.7274e-05 - 79ms/epoch - 3ms/step
# Epoch 261/300
# 26/26 - 0s - loss: 7.4808e-05 - val_loss: 4.4047e-05 - 78ms/epoch - 3ms/step
# Epoch 262/300
# 26/26 - 0s - loss: 7.5825e-05 - val_loss: 7.2557e-05 - 77ms/epoch - 3ms/step
# Epoch 263/300
# 26/26 - 0s - loss: 7.6527e-05 - val_loss: 8.6746e-05 - 77ms/epoch - 3ms/step
# Epoch 264/300
# 26/26 - 0s - loss: 7.6901e-05 - val_loss: 3.8560e-05 - 79ms/epoch - 3ms/step
# Epoch 265/300
# 26/26 - 0s - loss: 7.5802e-05 - val_loss: 2.4676e-05 - 78ms/epoch - 3ms/step
# Epoch 266/300
# 26/26 - 0s - loss: 7.6887e-05 - val_loss: 6.7748e-05 - 79ms/epoch - 3ms/step
# Epoch 267/300
# 26/26 - 0s - loss: 7.4321e-05 - val_loss: 4.1540e-05 - 80ms/epoch - 3ms/step
# Epoch 268/300
# 26/26 - 0s - loss: 7.6408e-05 - val_loss: 5.2677e-05 - 77ms/epoch - 3ms/step
# Epoch 269/300
# 26/26 - 0s - loss: 7.4861e-05 - val_loss: 4.9066e-05 - 91ms/epoch - 3ms/step
# Epoch 270/300
# 26/26 - 0s - loss: 7.5264e-05 - val_loss: 3.8917e-05 - 80ms/epoch - 3ms/step
# Epoch 271/300
# 26/26 - 0s - loss: 7.4301e-05 - val_loss: 3.8631e-05 - 80ms/epoch - 3ms/step
# Epoch 272/300
# 26/26 - 0s - loss: 7.4675e-05 - val_loss: 5.4427e-05 - 78ms/epoch - 3ms/step
# Epoch 273/300
# 26/26 - 0s - loss: 7.4007e-05 - val_loss: 5.7769e-05 - 80ms/epoch - 3ms/step
# Epoch 274/300
# 26/26 - 0s - loss: 7.4200e-05 - val_loss: 3.7473e-05 - 78ms/epoch - 3ms/step
# Epoch 275/300
# 26/26 - 0s - loss: 7.4654e-05 - val_loss: 7.5760e-05 - 78ms/epoch - 3ms/step
# Epoch 276/300
# 26/26 - 0s - loss: 7.5956e-05 - val_loss: 6.2149e-05 - 77ms/epoch - 3ms/step
# Epoch 277/300
# 26/26 - 0s - loss: 7.5305e-05 - val_loss: 5.3879e-05 - 78ms/epoch - 3ms/step
# Epoch 278/300
# 26/26 - 0s - loss: 7.5115e-05 - val_loss: 2.7550e-05 - 79ms/epoch - 3ms/step
# Epoch 279/300
# 26/26 - 0s - loss: 7.4728e-05 - val_loss: 5.3950e-05 - 77ms/epoch - 3ms/step
# Epoch 280/300
# 26/26 - 0s - loss: 7.3319e-05 - val_loss: 3.0312e-05 - 77ms/epoch - 3ms/step
# Epoch 281/300
# 26/26 - 0s - loss: 7.5176e-05 - val_loss: 4.9317e-05 - 79ms/epoch - 3ms/step
# Epoch 282/300
# 26/26 - 0s - loss: 7.6125e-05 - val_loss: 2.7835e-05 - 78ms/epoch - 3ms/step
# Epoch 283/300
# 26/26 - 0s - loss: 7.6912e-05 - val_loss: 2.9961e-05 - 77ms/epoch - 3ms/step
# Epoch 284/300
# 26/26 - 0s - loss: 7.6589e-05 - val_loss: 3.5408e-05 - 95ms/epoch - 4ms/step
# Epoch 285/300
# 26/26 - 0s - loss: 7.4600e-05 - val_loss: 6.6197e-05 - 78ms/epoch - 3ms/step
# Epoch 286/300
# 26/26 - 0s - loss: 7.3889e-05 - val_loss: 5.5717e-05 - 77ms/epoch - 3ms/step
# Epoch 287/300
# 26/26 - 0s - loss: 7.6415e-05 - val_loss: 7.1923e-05 - 75ms/epoch - 3ms/step
# Epoch 288/300
# 26/26 - 0s - loss: 7.7678e-05 - val_loss: 3.7409e-05 - 78ms/epoch - 3ms/step
# Epoch 289/300
# 26/26 - 0s - loss: 7.3963e-05 - val_loss: 3.9736e-05 - 79ms/epoch - 3ms/step
# Epoch 290/300
# 26/26 - 0s - loss: 7.3865e-05 - val_loss: 5.7575e-05 - 77ms/epoch - 3ms/step
# Epoch 291/300
# 26/26 - 0s - loss: 7.3650e-05 - val_loss: 5.1124e-05 - 78ms/epoch - 3ms/step
# Epoch 292/300
# 26/26 - 0s - loss: 7.6474e-05 - val_loss: 5.5483e-05 - 78ms/epoch - 3ms/step
# Epoch 293/300
# 26/26 - 0s - loss: 7.4768e-05 - val_loss: 5.3679e-05 - 78ms/epoch - 3ms/step
# Epoch 294/300
# 26/26 - 0s - loss: 7.4033e-05 - val_loss: 5.3457e-05 - 78ms/epoch - 3ms/step
# Epoch 295/300
# 26/26 - 0s - loss: 7.9166e-05 - val_loss: 3.8225e-05 - 80ms/epoch - 3ms/step
# Epoch 296/300
# 26/26 - 0s - loss: 7.9548e-05 - val_loss: 3.9593e-05 - 78ms/epoch - 3ms/step
# Epoch 297/300
# 26/26 - 0s - loss: 7.7716e-05 - val_loss: 2.7468e-05 - 79ms/epoch - 3ms/step
# Epoch 298/300
# 26/26 - 0s - loss: 7.7052e-05 - val_loss: 1.9662e-05 - 78ms/epoch - 3ms/step
# Epoch 299/300
# 26/26 - 0s - loss: 7.7832e-05 - val_loss: 3.2224e-05 - 78ms/epoch - 3ms/step
# Epoch 300/300
# 26/26 - 0s - loss: 7.4901e-05 - val_loss: 4.8775e-05 - 77ms/epoch - 3ms/step

# %% [markdown]
# Relu model converges better than sigmoid

# %%
model3 = Sequential()
model3.add(InputLayer(input_shape=(5,8)))
model3.add(LSTM(64))
model3.add(Dense(8, 'sigmoid'))
model3.add(Dense(1, 'linear'))
model3.compile(loss='mse', optimizer='adam')

# %%
model3.fit(X, y, epochs=100, validation_data=(valX, valy), verbose=2)
# Out:
# Epoch 1/100
# 26/26 - 2s - loss: 0.0133 - val_loss: 8.8853e-04 - 2s/epoch - 58ms/step
# Epoch 2/100
# 26/26 - 0s - loss: 3.4651e-04 - val_loss: 6.7406e-05 - 81ms/epoch - 3ms/step
# Epoch 3/100
# 26/26 - 0s - loss: 9.5798e-05 - val_loss: 8.8732e-05 - 79ms/epoch - 3ms/step
# Epoch 4/100
# 26/26 - 0s - loss: 7.5933e-05 - val_loss: 5.8197e-05 - 79ms/epoch - 3ms/step
# Epoch 5/100
# 26/26 - 0s - loss: 7.3392e-05 - val_loss: 4.3726e-05 - 79ms/epoch - 3ms/step
# Epoch 6/100
# 26/26 - 0s - loss: 7.3077e-05 - val_loss: 4.6650e-05 - 79ms/epoch - 3ms/step
# Epoch 7/100
# 26/26 - 0s - loss: 7.2774e-05 - val_loss: 5.3914e-05 - 78ms/epoch - 3ms/step
# Epoch 8/100
# 26/26 - 0s - loss: 7.4300e-05 - val_loss: 4.9132e-05 - 80ms/epoch - 3ms/step
# Epoch 9/100
# 26/26 - 0s - loss: 7.3731e-05 - val_loss: 5.2712e-05 - 89ms/epoch - 3ms/step
# Epoch 10/100
# 26/26 - 0s - loss: 7.3661e-05 - val_loss: 4.4852e-05 - 79ms/epoch - 3ms/step
# Epoch 11/100
# 26/26 - 0s - loss: 7.4325e-05 - val_loss: 5.5432e-05 - 80ms/epoch - 3ms/step
# Epoch 12/100
# 26/26 - 0s - loss: 7.3869e-05 - val_loss: 3.8307e-05 - 80ms/epoch - 3ms/step
# Epoch 13/100
# 26/26 - 0s - loss: 7.3497e-05 - val_loss: 4.5235e-05 - 81ms/epoch - 3ms/step
# Epoch 14/100
# 26/26 - 0s - loss: 7.3689e-05 - val_loss: 5.9265e-05 - 81ms/epoch - 3ms/step
# Epoch 15/100
# 26/26 - 0s - loss: 7.4196e-05 - val_loss: 4.9367e-05 - 83ms/epoch - 3ms/step
# Epoch 16/100
# 26/26 - 0s - loss: 7.3729e-05 - val_loss: 4.3330e-05 - 82ms/epoch - 3ms/step
# Epoch 17/100
# 26/26 - 0s - loss: 7.3258e-05 - val_loss: 4.9587e-05 - 78ms/epoch - 3ms/step
# Epoch 18/100
# 26/26 - 0s - loss: 7.3605e-05 - val_loss: 3.5829e-05 - 78ms/epoch - 3ms/step
# Epoch 19/100
# 26/26 - 0s - loss: 7.3756e-05 - val_loss: 5.8432e-05 - 78ms/epoch - 3ms/step
# Epoch 20/100
# 26/26 - 0s - loss: 7.3311e-05 - val_loss: 3.9056e-05 - 77ms/epoch - 3ms/step
# Epoch 21/100
# 26/26 - 0s - loss: 7.4198e-05 - val_loss: 3.7955e-05 - 77ms/epoch - 3ms/step
# Epoch 22/100
# 26/26 - 0s - loss: 7.4228e-05 - val_loss: 4.1770e-05 - 78ms/epoch - 3ms/step
# Epoch 23/100
# 26/26 - 0s - loss: 7.3627e-05 - val_loss: 5.2341e-05 - 78ms/epoch - 3ms/step
# Epoch 24/100
# 26/26 - 0s - loss: 7.4636e-05 - val_loss: 3.8842e-05 - 78ms/epoch - 3ms/step
# Epoch 25/100
# 26/26 - 0s - loss: 7.4579e-05 - val_loss: 5.4060e-05 - 80ms/epoch - 3ms/step
# Epoch 26/100
# 26/26 - 0s - loss: 7.4110e-05 - val_loss: 5.1574e-05 - 78ms/epoch - 3ms/step
# Epoch 27/100
# 26/26 - 0s - loss: 7.3798e-05 - val_loss: 5.9256e-05 - 77ms/epoch - 3ms/step
# Epoch 28/100
# 26/26 - 0s - loss: 7.3273e-05 - val_loss: 4.2398e-05 - 79ms/epoch - 3ms/step
# Epoch 29/100
# 26/26 - 0s - loss: 7.4012e-05 - val_loss: 4.4503e-05 - 80ms/epoch - 3ms/step
# Epoch 30/100
# 26/26 - 0s - loss: 7.3760e-05 - val_loss: 3.3486e-05 - 80ms/epoch - 3ms/step
# Epoch 31/100
# 26/26 - 0s - loss: 7.3842e-05 - val_loss: 6.0215e-05 - 79ms/epoch - 3ms/step
# Epoch 32/100
# 26/26 - 0s - loss: 7.5012e-05 - val_loss: 3.3233e-05 - 78ms/epoch - 3ms/step
# Epoch 33/100
# 26/26 - 0s - loss: 7.4490e-05 - val_loss: 4.3429e-05 - 80ms/epoch - 3ms/step
# Epoch 34/100
# 26/26 - 0s - loss: 7.3720e-05 - val_loss: 5.1943e-05 - 78ms/epoch - 3ms/step
# Epoch 35/100
# 26/26 - 0s - loss: 7.4554e-05 - val_loss: 5.4209e-05 - 78ms/epoch - 3ms/step
# Epoch 36/100
# 26/26 - 0s - loss: 7.4126e-05 - val_loss: 3.2952e-05 - 78ms/epoch - 3ms/step
# Epoch 37/100
# 26/26 - 0s - loss: 7.4896e-05 - val_loss: 2.7314e-05 - 75ms/epoch - 3ms/step
# Epoch 38/100
# 26/26 - 0s - loss: 7.8988e-05 - val_loss: 7.8297e-05 - 77ms/epoch - 3ms/step
# Epoch 39/100
# 26/26 - 0s - loss: 7.5131e-05 - val_loss: 4.0551e-05 - 78ms/epoch - 3ms/step
# Epoch 40/100
# 26/26 - 0s - loss: 7.9604e-05 - val_loss: 4.4578e-05 - 77ms/epoch - 3ms/step
# Epoch 41/100
# 26/26 - 0s - loss: 7.4476e-05 - val_loss: 6.1127e-05 - 78ms/epoch - 3ms/step
# Epoch 42/100
# 26/26 - 0s - loss: 7.6582e-05 - val_loss: 9.4154e-05 - 80ms/epoch - 3ms/step
# Epoch 43/100
# 26/26 - 0s - loss: 7.5355e-05 - val_loss: 4.5157e-05 - 80ms/epoch - 3ms/step
# Epoch 44/100
# 26/26 - 0s - loss: 7.4591e-05 - val_loss: 4.0020e-05 - 79ms/epoch - 3ms/step
# Epoch 45/100
# 26/26 - 0s - loss: 7.4760e-05 - val_loss: 4.7524e-05 - 77ms/epoch - 3ms/step
# Epoch 46/100
# 26/26 - 0s - loss: 7.3553e-05 - val_loss: 6.8406e-05 - 78ms/epoch - 3ms/step
# Epoch 47/100
# 26/26 - 0s - loss: 7.3706e-05 - val_loss: 2.8620e-05 - 78ms/epoch - 3ms/step
# Epoch 48/100
# 26/26 - 0s - loss: 7.5416e-05 - val_loss: 9.9072e-05 - 77ms/epoch - 3ms/step
# Epoch 49/100
# 26/26 - 0s - loss: 7.6716e-05 - val_loss: 3.9337e-05 - 76ms/epoch - 3ms/step
# Epoch 50/100
# 26/26 - 0s - loss: 7.4692e-05 - val_loss: 4.8043e-05 - 77ms/epoch - 3ms/step
# Epoch 51/100
# 26/26 - 0s - loss: 7.4312e-05 - val_loss: 4.0912e-05 - 77ms/epoch - 3ms/step
# Epoch 52/100
# 26/26 - 0s - loss: 7.5222e-05 - val_loss: 5.4878e-05 - 78ms/epoch - 3ms/step
# Epoch 53/100
# 26/26 - 0s - loss: 7.5777e-05 - val_loss: 4.0022e-05 - 76ms/epoch - 3ms/step
# Epoch 54/100
# 26/26 - 0s - loss: 7.9194e-05 - val_loss: 8.4114e-05 - 79ms/epoch - 3ms/step
# Epoch 55/100
# 26/26 - 0s - loss: 7.6500e-05 - val_loss: 6.5246e-05 - 78ms/epoch - 3ms/step
# Epoch 56/100
# 26/26 - 0s - loss: 7.4489e-05 - val_loss: 6.5349e-05 - 78ms/epoch - 3ms/step
# Epoch 57/100
# 26/26 - 0s - loss: 7.4827e-05 - val_loss: 5.0809e-05 - 79ms/epoch - 3ms/step
# Epoch 58/100
# 26/26 - 0s - loss: 7.6351e-05 - val_loss: 5.3396e-05 - 81ms/epoch - 3ms/step
# Epoch 59/100
# 26/26 - 0s - loss: 7.5182e-05 - val_loss: 5.9303e-05 - 76ms/epoch - 3ms/step
# Epoch 60/100
# 26/26 - 0s - loss: 7.4669e-05 - val_loss: 6.9318e-05 - 79ms/epoch - 3ms/step
# Epoch 61/100
# 26/26 - 0s - loss: 7.3084e-05 - val_loss: 2.1918e-05 - 80ms/epoch - 3ms/step
# Epoch 62/100
# 26/26 - 0s - loss: 8.0699e-05 - val_loss: 4.2285e-05 - 80ms/epoch - 3ms/step
# Epoch 63/100
# 26/26 - 0s - loss: 7.4133e-05 - val_loss: 7.2566e-05 - 79ms/epoch - 3ms/step
# Epoch 64/100
# 26/26 - 0s - loss: 7.5016e-05 - val_loss: 4.0585e-05 - 77ms/epoch - 3ms/step
# Epoch 65/100
# 26/26 - 0s - loss: 7.3464e-05 - val_loss: 7.5220e-05 - 76ms/epoch - 3ms/step
# Epoch 66/100
# 26/26 - 0s - loss: 7.4780e-05 - val_loss: 3.5395e-05 - 76ms/epoch - 3ms/step
# Epoch 67/100
# 26/26 - 0s - loss: 7.6446e-05 - val_loss: 2.8301e-05 - 77ms/epoch - 3ms/step
# Epoch 68/100
# 26/26 - 0s - loss: 7.8311e-05 - val_loss: 6.5592e-05 - 79ms/epoch - 3ms/step
# Epoch 69/100
# 26/26 - 0s - loss: 7.4007e-05 - val_loss: 3.7581e-05 - 79ms/epoch - 3ms/step
# Epoch 70/100
# 26/26 - 0s - loss: 7.5016e-05 - val_loss: 6.0059e-05 - 77ms/epoch - 3ms/step
# Epoch 71/100
# 26/26 - 0s - loss: 7.9012e-05 - val_loss: 4.7362e-05 - 79ms/epoch - 3ms/step
# Epoch 72/100
# 26/26 - 0s - loss: 7.4935e-05 - val_loss: 5.6222e-05 - 79ms/epoch - 3ms/step
# Epoch 73/100
# 26/26 - 0s - loss: 7.4860e-05 - val_loss: 6.0990e-05 - 79ms/epoch - 3ms/step
# Epoch 74/100
# 26/26 - 0s - loss: 7.6362e-05 - val_loss: 2.8938e-05 - 78ms/epoch - 3ms/step
# Epoch 75/100
# 26/26 - 0s - loss: 7.4402e-05 - val_loss: 4.6880e-05 - 80ms/epoch - 3ms/step
# Epoch 76/100
# 26/26 - 0s - loss: 7.4293e-05 - val_loss: 5.0587e-05 - 77ms/epoch - 3ms/step
# Epoch 77/100
# 26/26 - 0s - loss: 7.5003e-05 - val_loss: 3.8947e-05 - 77ms/epoch - 3ms/step
# Epoch 78/100
# 26/26 - 0s - loss: 7.5527e-05 - val_loss: 3.9580e-05 - 78ms/epoch - 3ms/step
# Epoch 79/100
# 26/26 - 0s - loss: 8.6356e-05 - val_loss: 3.1864e-05 - 76ms/epoch - 3ms/step
# Epoch 80/100
# 26/26 - 0s - loss: 7.6517e-05 - val_loss: 3.2221e-05 - 76ms/epoch - 3ms/step
# Epoch 81/100
# 26/26 - 0s - loss: 7.7330e-05 - val_loss: 7.1835e-05 - 78ms/epoch - 3ms/step
# Epoch 82/100
# 26/26 - 0s - loss: 7.4594e-05 - val_loss: 4.2148e-05 - 79ms/epoch - 3ms/step
# Epoch 83/100
# 26/26 - 0s - loss: 7.5544e-05 - val_loss: 2.4812e-05 - 79ms/epoch - 3ms/step
# Epoch 84/100
# 26/26 - 0s - loss: 7.6310e-05 - val_loss: 2.3010e-05 - 79ms/epoch - 3ms/step
# Epoch 85/100
# 26/26 - 0s - loss: 7.9236e-05 - val_loss: 4.6047e-05 - 78ms/epoch - 3ms/step
# Epoch 86/100
# 26/26 - 0s - loss: 7.5364e-05 - val_loss: 4.6825e-05 - 77ms/epoch - 3ms/step
# Epoch 87/100
# 26/26 - 0s - loss: 7.4237e-05 - val_loss: 2.9096e-05 - 77ms/epoch - 3ms/step
# Epoch 88/100
# 26/26 - 0s - loss: 7.6937e-05 - val_loss: 7.5288e-05 - 79ms/epoch - 3ms/step
# Epoch 89/100
# 26/26 - 0s - loss: 7.5798e-05 - val_loss: 1.2046e-04 - 79ms/epoch - 3ms/step
# Epoch 90/100
# 26/26 - 0s - loss: 8.2821e-05 - val_loss: 2.9454e-05 - 77ms/epoch - 3ms/step
# Epoch 91/100
# 26/26 - 0s - loss: 7.9870e-05 - val_loss: 2.8961e-05 - 77ms/epoch - 3ms/step
# Epoch 92/100
# 26/26 - 0s - loss: 8.0163e-05 - val_loss: 1.4967e-04 - 79ms/epoch - 3ms/step
# Epoch 93/100
# 26/26 - 0s - loss: 8.2821e-05 - val_loss: 3.1016e-05 - 77ms/epoch - 3ms/step
# Epoch 94/100
# 26/26 - 0s - loss: 8.1853e-05 - val_loss: 2.4728e-05 - 77ms/epoch - 3ms/step
# Epoch 95/100
# 26/26 - 0s - loss: 7.8066e-05 - val_loss: 5.4831e-05 - 78ms/epoch - 3ms/step
# Epoch 96/100
# 26/26 - 0s - loss: 7.3836e-05 - val_loss: 7.8798e-05 - 80ms/epoch - 3ms/step
# Epoch 97/100
# 26/26 - 0s - loss: 7.6796e-05 - val_loss: 4.2568e-05 - 79ms/epoch - 3ms/step
# Epoch 98/100
# 26/26 - 0s - loss: 7.9730e-05 - val_loss: 4.6952e-05 - 79ms/epoch - 3ms/step
# Epoch 99/100
# 26/26 - 0s - loss: 7.7891e-05 - val_loss: 5.7764e-05 - 78ms/epoch - 3ms/step
# Epoch 100/100
# 26/26 - 0s - loss: 7.5506e-05 - val_loss: 6.6566e-05 - 78ms/epoch - 3ms/step

# %%
import matplotlib.pyplot as plt

def plot_predictions(model, X, y):
    predictions = model.predict(X)
    fig, ax = plt.subplots()
    plt.plot(predictions, color = 'red')
    plt.plot(y, color = 'blue')
    plt.legend(['predicted','actual'])
    plt.show()
    return

# %%
plot_predictions(model, X, y)
# Out:
# 26/26 [==============================] - 0s 964us/step

# %%
plot_predictions(model2, X, y)
# Out:
# 26/26 [==============================] - 0s 904us/step

# %%
plot_predictions(model3, X, y)
# Out:
# 26/26 [==============================] - 0s 987us/step

# %% [markdown]
# ### Adding scaling

# %%
def np_to_X_y(array, window_size=5):
    X=[]
    y=[]
    for i in range(len(array)-window_size):
        row = [r for r in array[i:i+window_size]]
        X.append(row)
        label = array[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

scaler = MinMaxScaler(feature_range=(0,1))

train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

window_size = 5
X_scaled, y_scaled = np_to_X_y(train_scaled, window_size)
valX_scaled, valy_scaled = np_to_X_y(test_scaled, window_size)

# %%
model4 = Sequential()
model4.add(LSTM(64, input_shape=(5,8)))
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))
model4.compile(loss='mse', optimizer='adam')

# %%
history = model4.fit(X_scaled, y_scaled, epochs=50, validation_data=(valX_scaled, valy_scaled), verbose=2)
# Out:
# Epoch 1/50
# 26/26 - 1s - loss: 0.0415 - val_loss: 0.0168 - 1s/epoch - 51ms/step
# Epoch 2/50
# 26/26 - 0s - loss: 0.0253 - val_loss: 0.0114 - 80ms/epoch - 3ms/step
# Epoch 3/50
# 26/26 - 0s - loss: 0.0232 - val_loss: 0.0096 - 82ms/epoch - 3ms/step
# Epoch 4/50
# 26/26 - 0s - loss: 0.0227 - val_loss: 0.0114 - 81ms/epoch - 3ms/step
# Epoch 5/50
# 26/26 - 0s - loss: 0.0220 - val_loss: 0.0087 - 78ms/epoch - 3ms/step
# Epoch 6/50
# 26/26 - 0s - loss: 0.0207 - val_loss: 0.0082 - 79ms/epoch - 3ms/step
# Epoch 7/50
# 26/26 - 0s - loss: 0.0201 - val_loss: 0.0102 - 80ms/epoch - 3ms/step
# Epoch 8/50
# 26/26 - 0s - loss: 0.0196 - val_loss: 0.0089 - 83ms/epoch - 3ms/step
# Epoch 9/50
# 26/26 - 0s - loss: 0.0185 - val_loss: 0.0070 - 77ms/epoch - 3ms/step
# Epoch 10/50
# 26/26 - 0s - loss: 0.0178 - val_loss: 0.0099 - 81ms/epoch - 3ms/step
# Epoch 11/50
# 26/26 - 0s - loss: 0.0179 - val_loss: 0.0066 - 80ms/epoch - 3ms/step
# Epoch 12/50
# 26/26 - 0s - loss: 0.0172 - val_loss: 0.0063 - 78ms/epoch - 3ms/step
# Epoch 13/50
# 26/26 - 0s - loss: 0.0169 - val_loss: 0.0063 - 80ms/epoch - 3ms/step
# Epoch 14/50
# 26/26 - 0s - loss: 0.0170 - val_loss: 0.0061 - 79ms/epoch - 3ms/step
# Epoch 15/50
# 26/26 - 0s - loss: 0.0164 - val_loss: 0.0072 - 79ms/epoch - 3ms/step
# Epoch 16/50
# 26/26 - 0s - loss: 0.0163 - val_loss: 0.0073 - 79ms/epoch - 3ms/step
# Epoch 17/50
# 26/26 - 0s - loss: 0.0162 - val_loss: 0.0075 - 117ms/epoch - 5ms/step
# Epoch 18/50
# 26/26 - 0s - loss: 0.0163 - val_loss: 0.0061 - 79ms/epoch - 3ms/step
# Epoch 19/50
# 26/26 - 0s - loss: 0.0156 - val_loss: 0.0063 - 80ms/epoch - 3ms/step
# Epoch 20/50
# 26/26 - 0s - loss: 0.0158 - val_loss: 0.0064 - 80ms/epoch - 3ms/step
# Epoch 21/50
# 26/26 - 0s - loss: 0.0158 - val_loss: 0.0060 - 78ms/epoch - 3ms/step
# Epoch 22/50
# 26/26 - 0s - loss: 0.0158 - val_loss: 0.0058 - 78ms/epoch - 3ms/step
# Epoch 23/50
# 26/26 - 0s - loss: 0.0157 - val_loss: 0.0069 - 77ms/epoch - 3ms/step
# Epoch 24/50
# 26/26 - 0s - loss: 0.0158 - val_loss: 0.0061 - 79ms/epoch - 3ms/step
# Epoch 25/50
# 26/26 - 0s - loss: 0.0164 - val_loss: 0.0060 - 80ms/epoch - 3ms/step
# Epoch 26/50
# 26/26 - 0s - loss: 0.0155 - val_loss: 0.0065 - 78ms/epoch - 3ms/step
# Epoch 27/50
# 26/26 - 0s - loss: 0.0156 - val_loss: 0.0055 - 80ms/epoch - 3ms/step
# Epoch 28/50
# 26/26 - 0s - loss: 0.0154 - val_loss: 0.0072 - 79ms/epoch - 3ms/step
# Epoch 29/50
# 26/26 - 0s - loss: 0.0148 - val_loss: 0.0059 - 80ms/epoch - 3ms/step
# Epoch 30/50
# 26/26 - 0s - loss: 0.0149 - val_loss: 0.0062 - 83ms/epoch - 3ms/step
# Epoch 31/50
# 26/26 - 0s - loss: 0.0148 - val_loss: 0.0071 - 78ms/epoch - 3ms/step
# Epoch 32/50
# 26/26 - 0s - loss: 0.0149 - val_loss: 0.0060 - 77ms/epoch - 3ms/step
# Epoch 33/50
# 26/26 - 0s - loss: 0.0152 - val_loss: 0.0059 - 79ms/epoch - 3ms/step
# Epoch 34/50
# 26/26 - 0s - loss: 0.0148 - val_loss: 0.0066 - 77ms/epoch - 3ms/step
# Epoch 35/50
# 26/26 - 0s - loss: 0.0146 - val_loss: 0.0070 - 78ms/epoch - 3ms/step
# Epoch 36/50
# 26/26 - 0s - loss: 0.0146 - val_loss: 0.0056 - 80ms/epoch - 3ms/step
# Epoch 37/50
# 26/26 - 0s - loss: 0.0143 - val_loss: 0.0055 - 78ms/epoch - 3ms/step
# Epoch 38/50
# 26/26 - 0s - loss: 0.0150 - val_loss: 0.0083 - 80ms/epoch - 3ms/step
# Epoch 39/50
# 26/26 - 0s - loss: 0.0144 - val_loss: 0.0055 - 79ms/epoch - 3ms/step
# Epoch 40/50
# 26/26 - 0s - loss: 0.0145 - val_loss: 0.0057 - 80ms/epoch - 3ms/step
# Epoch 41/50
# 26/26 - 0s - loss: 0.0142 - val_loss: 0.0055 - 79ms/epoch - 3ms/step
# Epoch 42/50
# 26/26 - 0s - loss: 0.0145 - val_loss: 0.0074 - 80ms/epoch - 3ms/step
# Epoch 43/50
# 26/26 - 0s - loss: 0.0145 - val_loss: 0.0061 - 108ms/epoch - 4ms/step
# Epoch 44/50
# 26/26 - 0s - loss: 0.0141 - val_loss: 0.0069 - 81ms/epoch - 3ms/step
# Epoch 45/50
# 26/26 - 0s - loss: 0.0142 - val_loss: 0.0054 - 79ms/epoch - 3ms/step
# Epoch 46/50
# 26/26 - 0s - loss: 0.0142 - val_loss: 0.0063 - 78ms/epoch - 3ms/step
# Epoch 47/50
# 26/26 - 0s - loss: 0.0139 - val_loss: 0.0055 - 79ms/epoch - 3ms/step
# Epoch 48/50
# 26/26 - 0s - loss: 0.0139 - val_loss: 0.0069 - 80ms/epoch - 3ms/step
# Epoch 49/50
# 26/26 - 0s - loss: 0.0142 - val_loss: 0.0071 - 79ms/epoch - 3ms/step
# Epoch 50/50
# 26/26 - 0s - loss: 0.0141 - val_loss: 0.0060 - 79ms/epoch - 3ms/step

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("NO2 LSTM Loss Curve")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','test'])
plot_predictions(model4, X_scaled, y_scaled)
# Out:
# 26/26 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import mean_squared_error
#unscaling output
yhat = model4.predict(X_scaled)
for i in range(5):
    yhat = np.insert(yhat, 0, np.nan)
train_copy = train
train_copy.head()
train_copy['output'] = yhat
train_copy.drop('value', axis = 1, inplace = True)
train_copy = train_copy[['output','stp','wind_speed','max_sustained_wind','max_temp','min_temp','temperature','dewpoint']]
train_copy.head()
# Out:
# 26/26 [==============================] - 0s 965us/step
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_231684\2283424937.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_copy['output'] = yhat
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_231684\2283424937.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_copy.drop('value', axis = 1, inplace = True)
#             output    stp  wind_speed  max_sustained_wind  max_temp  min_temp  \
# utc
# 2020-01-02     NaN  986.8         4.5                12.0      68.0      43.0
# 2020-01-03     NaN  994.0         1.6                 6.0      73.0      45.0
# 2020-01-04     NaN  999.1         1.1                 6.0      73.0      42.1
# 2020-01-05     NaN  998.0         2.8                11.1      73.0      42.1
# 2020-01-06     NaN  997.6         2.5                 6.0      75.0      42.1
#
#             temperature  dewpoint
# utc
# 2020-01-02         56.6      42.1
# 2020-01-03         56.7      39.3
# 2020-01-04         55.5      38.4
# 2020-01-05         54.7      36.3
# 2020-01-06         57.6      29.1

# %%
extracted_output = train_copy.to_numpy()
extracted_output = scaler.inverse_transform(extracted_output[5:])
extracted_output = [i[0] for i in extracted_output]

# %%
print(f'Mean squared error is {mean_squared_error(extracted_output, y)}')
# Out:
# Mean squared error is 2.3767297421981332e-05

# %%
fig, ax = plt.subplots()
plt.title("Scaled LSTM Model of NO2 Performance on Train Set") 
plt.plot(extracted_output, color = 'red')
plt.plot(y, color = 'blue')
plt.legend(['predicted','actual'])
plt.show()

# %%
sum(y)/len(y)
# Out:
# 0.014301733557195252

# %%
#unscaling output
yhat = model4.predict(valX_scaled)
for i in range(5):
    yhat = np.insert(yhat, 0, np.nan)
test_copy = test
test_copy['output'] = yhat
test_copy.drop('value', axis = 1, inplace = True)
test_copy = test_copy[['output','stp','wind_speed','max_sustained_wind','max_temp','min_temp','temperature','dewpoint']]

extracted_output = test_copy.to_numpy()
extracted_output = scaler.inverse_transform(extracted_output[5:])
extracted_output = [i[0] for i in extracted_output]

print(f'Mean squared error is {mean_squared_error(extracted_output, valy)}')
fig, ax = plt.subplots()
plt.plot(extracted_output, color = 'red')
plt.plot(valy, color = 'blue')
plt.legend(['predicted','actual'])
plt.show()
# Out:
# 7/7 [==============================] - 0s 1ms/step
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_231684\682039158.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_copy['output'] = yhat
# Mean squared error is 1.0432841348477027e-05
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_231684\682039158.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_copy.drop('value', axis = 1, inplace = True)

# %%
fig, ax = plt.subplots()
plt.title("Scaled LSTM Model of Nitrogen Dioxide Performance on Validation Set")
plt.plot(extracted_output, color = 'red')
plt.plot(valy, color = 'blue')
plt.legend(['predicted','actual'])
plt.show()
