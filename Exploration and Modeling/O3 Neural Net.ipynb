# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
tf.random.set_seed(123)

# %%
df = pd.read_csv('LA O3.csv', parse_dates=['date', 'utc','local'], index_col='utc')
df = df.resample('d').mean()
df = df.interpolate(method='time')
df.head()
# Out:
#                value  mobile   latitude  longitude  url  averaging_time  \
# utc
# 2020-01-02  0.032111     0.0  34.181976 -118.36304  NaN             1.0
# 2020-01-03  0.008792     0.0  34.181976 -118.36304  NaN             1.0
# 2020-01-04  0.009125     0.0  34.181976 -118.36304  NaN             1.0
# 2020-01-05  0.012125     0.0  34.181976 -118.36304  NaN             1.0
# 2020-01-06  0.020143     0.0  34.181976 -118.36304  NaN             1.0
#
#                  station  latitude-2  longitude-2  elevation  ...     slp  \
# utc                                                           ...
# 2020-01-02  7.228802e+10    34.20056    -118.3575      225.9  ...  1012.5
# 2020-01-03  7.228802e+10    34.20056    -118.3575      225.9  ...  1019.9
# 2020-01-04  7.228802e+10    34.20056    -118.3575      225.9  ...  1025.1
# 2020-01-05  7.228802e+10    34.20056    -118.3575      225.9  ...  1024.2
# 2020-01-06  7.228802e+10    34.20056    -118.3575      225.9  ...  1023.5
#
#               stp  visibility  wind_speed  max_sustained_wind       gust  \
# utc
# 2020-01-02  986.8        10.0         4.5                12.0        NaN
# 2020-01-03  994.0        10.0         1.6                 6.0        NaN
# 2020-01-04  999.1        10.0         1.1                 6.0        NaN
# 2020-01-05  998.0        10.0         2.8                11.1  18.100000
# 2020-01-06  997.6        10.0         2.5                 6.0  16.733333
#
#             max_temp  min_temp  precipitation  snow_depth
# utc
# 2020-01-02      68.0      43.0            0.0         0.0
# 2020-01-03      73.0      45.0            0.0         0.0
# 2020-01-04      73.0      42.1            0.0         0.0
# 2020-01-05      73.0      42.1            0.0         0.0
# 2020-01-06      75.0      42.1            0.0         0.0
#
# [5 rows x 22 columns]

# %%
min_date = df.index.values.min()
max_date = df.index.values.max()
train_percent = 0.80
interval = max_date - min_date
train_cutoff = min_date + train_percent*interval

train_df = df[df.index.values <= train_cutoff]
test_df = df[df.index.values > train_cutoff]

# %%
train = train_df[['value', 'stp', 'wind_speed', 'max_sustained_wind', 'max_temp', 'min_temp','temperature', 'dewpoint']]
test = test_df[['value', 'stp', 'wind_speed', 'max_sustained_wind', 'max_temp', 'min_temp','temperature', 'dewpoint']]

# %%
train
#look_back = 1
#trainX, trainY = create_dataset(train, look_back)
#testX, testY = create_dataset(test, look_back)
# Out:
#                value    stp  wind_speed  max_sustained_wind  max_temp  \
# utc
# 2020-01-02  0.032111  986.8         4.5                12.0      68.0
# 2020-01-03  0.008792  994.0         1.6                 6.0      73.0
# 2020-01-04  0.009125  999.1         1.1                 6.0      73.0
# 2020-01-05  0.012125  998.0         2.8                11.1      73.0
# 2020-01-06  0.020143  997.6         2.5                 6.0      75.0
# ...              ...    ...         ...                 ...       ...
# 2022-04-01  0.028434  984.8         4.0                 8.9      73.0
# 2022-04-02  0.035459  988.4         4.0                 8.0      73.0
# 2022-04-03  0.040215  988.1         4.5                 8.9      69.1
# 2022-04-04  0.034867  986.1         5.0                 8.9      73.9
# 2022-04-05  0.034336  985.8         7.3                15.0      89.1
#
#             min_temp  temperature  dewpoint
# utc
# 2020-01-02      43.0         56.6      42.1
# 2020-01-03      45.0         56.7      39.3
# 2020-01-04      42.1         55.5      38.4
# 2020-01-05      42.1         54.7      36.3
# 2020-01-06      42.1         57.6      29.1
# ...              ...          ...       ...
# 2022-04-01      53.1         61.2      49.2
# 2022-04-02      53.1         59.7      50.3
# 2022-04-03      54.0         62.2      50.3
# 2022-04-04      54.0         62.2      50.2
# 2022-04-05      54.0         71.8      47.7
#
# [825 rows x 8 columns]

# %%
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X=[]
    y=[]
    for i in range(len(df_as_np)-window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %%
window_size = 5
X, y = df_to_X_y(train, window_size)
valX, valy = df_to_X_y(test, window_size)

# %%
X.shape, y.shape
# Out:
# ((820, 5, 8), (820,))

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import InputLayer

model = Sequential()
model.add(LSTM(64, input_shape=(5,8)))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))
model.compile(loss='mse', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                18688
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 19,217
# Trainable params: 19,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, y, epochs=100, validation_data=(valX, valy), verbose=2)
# Out:
# Epoch 1/100
# 26/26 - 2s - loss: 0.0206 - val_loss: 5.5718e-05 - 2s/epoch - 60ms/step
# Epoch 2/100
# 26/26 - 0s - loss: 8.1228e-04 - val_loss: 2.6713e-04 - 83ms/epoch - 3ms/step
# Epoch 3/100
# 26/26 - 0s - loss: 2.2402e-04 - val_loss: 3.9701e-05 - 82ms/epoch - 3ms/step
# Epoch 4/100
# 26/26 - 0s - loss: 1.6773e-04 - val_loss: 4.5003e-05 - 81ms/epoch - 3ms/step
# Epoch 5/100
# 26/26 - 0s - loss: 1.6425e-04 - val_loss: 4.3434e-05 - 79ms/epoch - 3ms/step
# Epoch 6/100
# 26/26 - 0s - loss: 1.6378e-04 - val_loss: 5.5211e-05 - 77ms/epoch - 3ms/step
# Epoch 7/100
# 26/26 - 0s - loss: 1.6426e-04 - val_loss: 5.7865e-05 - 77ms/epoch - 3ms/step
# Epoch 8/100
# 26/26 - 0s - loss: 1.6495e-04 - val_loss: 4.1266e-05 - 79ms/epoch - 3ms/step
# Epoch 9/100
# 26/26 - 0s - loss: 1.6638e-04 - val_loss: 5.1136e-05 - 76ms/epoch - 3ms/step
# Epoch 10/100
# 26/26 - 0s - loss: 1.6822e-04 - val_loss: 3.8714e-05 - 77ms/epoch - 3ms/step
# Epoch 11/100
# 26/26 - 0s - loss: 1.6689e-04 - val_loss: 4.8925e-05 - 77ms/epoch - 3ms/step
# Epoch 12/100
# 26/26 - 0s - loss: 1.6462e-04 - val_loss: 4.3976e-05 - 78ms/epoch - 3ms/step
# Epoch 13/100
# 26/26 - 0s - loss: 1.6670e-04 - val_loss: 3.9145e-05 - 79ms/epoch - 3ms/step
# Epoch 14/100
# 26/26 - 0s - loss: 1.7029e-04 - val_loss: 4.5727e-05 - 90ms/epoch - 3ms/step
# Epoch 15/100
# 26/26 - 0s - loss: 1.6464e-04 - val_loss: 4.7124e-05 - 77ms/epoch - 3ms/step
# Epoch 16/100
# 26/26 - 0s - loss: 1.6470e-04 - val_loss: 4.1638e-05 - 76ms/epoch - 3ms/step
# Epoch 17/100
# 26/26 - 0s - loss: 1.6498e-04 - val_loss: 4.7293e-05 - 77ms/epoch - 3ms/step
# Epoch 18/100
# 26/26 - 0s - loss: 1.6613e-04 - val_loss: 4.7320e-05 - 77ms/epoch - 3ms/step
# Epoch 19/100
# 26/26 - 0s - loss: 1.6600e-04 - val_loss: 4.1765e-05 - 103ms/epoch - 4ms/step
# Epoch 20/100
# 26/26 - 0s - loss: 1.6608e-04 - val_loss: 3.8463e-05 - 78ms/epoch - 3ms/step
# Epoch 21/100
# 26/26 - 0s - loss: 1.7158e-04 - val_loss: 3.8867e-05 - 76ms/epoch - 3ms/step
# Epoch 22/100
# 26/26 - 0s - loss: 1.6700e-04 - val_loss: 5.1258e-05 - 95ms/epoch - 4ms/step
# Epoch 23/100
# 26/26 - 0s - loss: 1.6762e-04 - val_loss: 7.1705e-05 - 105ms/epoch - 4ms/step
# Epoch 24/100
# 26/26 - 0s - loss: 1.6932e-04 - val_loss: 4.5330e-05 - 77ms/epoch - 3ms/step
# Epoch 25/100
# 26/26 - 0s - loss: 1.7239e-04 - val_loss: 4.0995e-05 - 86ms/epoch - 3ms/step
# Epoch 26/100
# 26/26 - 0s - loss: 1.6486e-04 - val_loss: 5.9496e-05 - 95ms/epoch - 4ms/step
# Epoch 27/100
# 26/26 - 0s - loss: 1.6718e-04 - val_loss: 4.8783e-05 - 76ms/epoch - 3ms/step
# Epoch 28/100
# 26/26 - 0s - loss: 1.6506e-04 - val_loss: 3.8972e-05 - 75ms/epoch - 3ms/step
# Epoch 29/100
# 26/26 - 0s - loss: 1.6643e-04 - val_loss: 5.2068e-05 - 76ms/epoch - 3ms/step
# Epoch 30/100
# 26/26 - 0s - loss: 1.6569e-04 - val_loss: 4.1594e-05 - 76ms/epoch - 3ms/step
# Epoch 31/100
# 26/26 - 0s - loss: 1.6443e-04 - val_loss: 6.7246e-05 - 78ms/epoch - 3ms/step
# Epoch 32/100
# 26/26 - 0s - loss: 1.6915e-04 - val_loss: 3.8568e-05 - 79ms/epoch - 3ms/step
# Epoch 33/100
# 26/26 - 0s - loss: 1.6631e-04 - val_loss: 3.8443e-05 - 77ms/epoch - 3ms/step
# Epoch 34/100
# 26/26 - 0s - loss: 1.6520e-04 - val_loss: 4.7066e-05 - 82ms/epoch - 3ms/step
# Epoch 35/100
# 26/26 - 0s - loss: 1.7185e-04 - val_loss: 4.5336e-05 - 78ms/epoch - 3ms/step
# Epoch 36/100
# 26/26 - 0s - loss: 1.6873e-04 - val_loss: 3.8931e-05 - 77ms/epoch - 3ms/step
# Epoch 37/100
# 26/26 - 0s - loss: 1.7795e-04 - val_loss: 3.8562e-05 - 77ms/epoch - 3ms/step
# Epoch 38/100
# 26/26 - 0s - loss: 1.6666e-04 - val_loss: 4.1068e-05 - 76ms/epoch - 3ms/step
# Epoch 39/100
# 26/26 - 0s - loss: 1.6905e-04 - val_loss: 3.8447e-05 - 110ms/epoch - 4ms/step
# Epoch 40/100
# 26/26 - 0s - loss: 1.7225e-04 - val_loss: 4.0402e-05 - 89ms/epoch - 3ms/step
# Epoch 41/100
# 26/26 - 0s - loss: 1.6985e-04 - val_loss: 5.7358e-05 - 78ms/epoch - 3ms/step
# Epoch 42/100
# 26/26 - 0s - loss: 1.7357e-04 - val_loss: 3.8490e-05 - 78ms/epoch - 3ms/step
# Epoch 43/100
# 26/26 - 0s - loss: 1.7829e-04 - val_loss: 3.8810e-05 - 78ms/epoch - 3ms/step
# Epoch 44/100
# 26/26 - 0s - loss: 1.6968e-04 - val_loss: 4.6120e-05 - 77ms/epoch - 3ms/step
# Epoch 45/100
# 26/26 - 0s - loss: 1.7912e-04 - val_loss: 6.2748e-05 - 76ms/epoch - 3ms/step
# Epoch 46/100
# 26/26 - 0s - loss: 1.7314e-04 - val_loss: 1.1566e-04 - 78ms/epoch - 3ms/step
# Epoch 47/100
# 26/26 - 0s - loss: 1.7961e-04 - val_loss: 3.8465e-05 - 77ms/epoch - 3ms/step
# Epoch 48/100
# 26/26 - 0s - loss: 1.7176e-04 - val_loss: 1.0472e-04 - 78ms/epoch - 3ms/step
# Epoch 49/100
# 26/26 - 0s - loss: 1.8828e-04 - val_loss: 4.3894e-05 - 77ms/epoch - 3ms/step
# Epoch 50/100
# 26/26 - 0s - loss: 1.6648e-04 - val_loss: 5.7877e-05 - 76ms/epoch - 3ms/step
# Epoch 51/100
# 26/26 - 0s - loss: 1.7160e-04 - val_loss: 5.2564e-05 - 79ms/epoch - 3ms/step
# Epoch 52/100
# 26/26 - 0s - loss: 1.7061e-04 - val_loss: 4.5991e-05 - 77ms/epoch - 3ms/step
# Epoch 53/100
# 26/26 - 0s - loss: 1.7153e-04 - val_loss: 6.0736e-05 - 76ms/epoch - 3ms/step
# Epoch 54/100
# 26/26 - 0s - loss: 1.7557e-04 - val_loss: 5.7158e-05 - 76ms/epoch - 3ms/step
# Epoch 55/100
# 26/26 - 0s - loss: 1.6883e-04 - val_loss: 4.2455e-05 - 75ms/epoch - 3ms/step
# Epoch 56/100
# 26/26 - 0s - loss: 1.6542e-04 - val_loss: 5.8464e-05 - 76ms/epoch - 3ms/step
# Epoch 57/100
# 26/26 - 0s - loss: 1.7044e-04 - val_loss: 4.2010e-05 - 77ms/epoch - 3ms/step
# Epoch 58/100
# 26/26 - 0s - loss: 1.6873e-04 - val_loss: 4.4083e-05 - 76ms/epoch - 3ms/step
# Epoch 59/100
# 26/26 - 0s - loss: 1.7053e-04 - val_loss: 7.2932e-05 - 113ms/epoch - 4ms/step
# Epoch 60/100
# 26/26 - 0s - loss: 1.6936e-04 - val_loss: 4.1964e-05 - 91ms/epoch - 3ms/step
# Epoch 61/100
# 26/26 - 0s - loss: 1.7182e-04 - val_loss: 4.2520e-05 - 77ms/epoch - 3ms/step
# Epoch 62/100
# 26/26 - 0s - loss: 1.7439e-04 - val_loss: 1.1180e-04 - 77ms/epoch - 3ms/step
# Epoch 63/100
# 26/26 - 0s - loss: 1.7512e-04 - val_loss: 4.2032e-05 - 76ms/epoch - 3ms/step
# Epoch 64/100
# 26/26 - 0s - loss: 1.6750e-04 - val_loss: 3.8522e-05 - 75ms/epoch - 3ms/step
# Epoch 65/100
# 26/26 - 0s - loss: 1.6754e-04 - val_loss: 1.1177e-04 - 76ms/epoch - 3ms/step
# Epoch 66/100
# 26/26 - 0s - loss: 1.9119e-04 - val_loss: 4.3930e-05 - 79ms/epoch - 3ms/step
# Epoch 67/100
# 26/26 - 0s - loss: 1.7033e-04 - val_loss: 6.7328e-05 - 76ms/epoch - 3ms/step
# Epoch 68/100
# 26/26 - 0s - loss: 1.6902e-04 - val_loss: 6.5202e-05 - 76ms/epoch - 3ms/step
# Epoch 69/100
# 26/26 - 0s - loss: 1.7595e-04 - val_loss: 4.7309e-05 - 77ms/epoch - 3ms/step
# Epoch 70/100
# 26/26 - 0s - loss: 1.8231e-04 - val_loss: 3.9974e-05 - 82ms/epoch - 3ms/step
# Epoch 71/100
# 26/26 - 0s - loss: 1.6823e-04 - val_loss: 4.6693e-05 - 108ms/epoch - 4ms/step
# Epoch 72/100
# 26/26 - 0s - loss: 1.8317e-04 - val_loss: 1.0401e-04 - 78ms/epoch - 3ms/step
# Epoch 73/100
# 26/26 - 0s - loss: 1.8820e-04 - val_loss: 5.5606e-05 - 76ms/epoch - 3ms/step
# Epoch 74/100
# 26/26 - 0s - loss: 1.7168e-04 - val_loss: 5.2626e-05 - 78ms/epoch - 3ms/step
# Epoch 75/100
# 26/26 - 0s - loss: 1.6572e-04 - val_loss: 6.4833e-05 - 78ms/epoch - 3ms/step
# Epoch 76/100
# 26/26 - 0s - loss: 1.7542e-04 - val_loss: 4.7908e-05 - 76ms/epoch - 3ms/step
# Epoch 77/100
# 26/26 - 0s - loss: 1.6554e-04 - val_loss: 5.0779e-05 - 76ms/epoch - 3ms/step
# Epoch 78/100
# 26/26 - 0s - loss: 1.6796e-04 - val_loss: 3.9121e-05 - 77ms/epoch - 3ms/step
# Epoch 79/100
# 26/26 - 0s - loss: 1.7552e-04 - val_loss: 6.9377e-05 - 77ms/epoch - 3ms/step
# Epoch 80/100
# 26/26 - 0s - loss: 1.6883e-04 - val_loss: 3.9107e-05 - 75ms/epoch - 3ms/step
# Epoch 81/100
# 26/26 - 0s - loss: 1.6733e-04 - val_loss: 4.2674e-05 - 75ms/epoch - 3ms/step
# Epoch 82/100
# 26/26 - 0s - loss: 1.7807e-04 - val_loss: 4.6857e-05 - 75ms/epoch - 3ms/step
# Epoch 83/100
# 26/26 - 0s - loss: 1.6736e-04 - val_loss: 3.8500e-05 - 75ms/epoch - 3ms/step
# Epoch 84/100
# 26/26 - 0s - loss: 1.6978e-04 - val_loss: 3.9509e-05 - 84ms/epoch - 3ms/step
# Epoch 85/100
# 26/26 - 0s - loss: 1.8695e-04 - val_loss: 1.0245e-04 - 78ms/epoch - 3ms/step
# Epoch 86/100
# 26/26 - 0s - loss: 1.8214e-04 - val_loss: 4.0399e-05 - 79ms/epoch - 3ms/step
# Epoch 87/100
# 26/26 - 0s - loss: 1.7859e-04 - val_loss: 7.4096e-05 - 77ms/epoch - 3ms/step
# Epoch 88/100
# 26/26 - 0s - loss: 1.6962e-04 - val_loss: 3.9397e-05 - 76ms/epoch - 3ms/step
# Epoch 89/100
# 26/26 - 0s - loss: 1.7978e-04 - val_loss: 6.6350e-05 - 77ms/epoch - 3ms/step
# Epoch 90/100
# 26/26 - 0s - loss: 1.6810e-04 - val_loss: 4.0683e-05 - 76ms/epoch - 3ms/step
# Epoch 91/100
# 26/26 - 0s - loss: 1.7322e-04 - val_loss: 4.2217e-05 - 91ms/epoch - 4ms/step
# Epoch 92/100
# 26/26 - 0s - loss: 1.7173e-04 - val_loss: 7.0801e-05 - 77ms/epoch - 3ms/step
# Epoch 93/100
# 26/26 - 0s - loss: 1.7833e-04 - val_loss: 7.1426e-05 - 79ms/epoch - 3ms/step
# Epoch 94/100
# 26/26 - 0s - loss: 1.7149e-04 - val_loss: 6.4558e-05 - 78ms/epoch - 3ms/step
# Epoch 95/100
# 26/26 - 0s - loss: 2.0263e-04 - val_loss: 3.8687e-05 - 77ms/epoch - 3ms/step
# Epoch 96/100
# 26/26 - 0s - loss: 1.7943e-04 - val_loss: 5.7268e-05 - 79ms/epoch - 3ms/step
# Epoch 97/100
# 26/26 - 0s - loss: 1.8216e-04 - val_loss: 5.6567e-05 - 77ms/epoch - 3ms/step
# Epoch 98/100
# 26/26 - 0s - loss: 1.7502e-04 - val_loss: 3.9392e-05 - 77ms/epoch - 3ms/step
# Epoch 99/100
# 26/26 - 0s - loss: 1.7125e-04 - val_loss: 3.8501e-05 - 78ms/epoch - 3ms/step
# Epoch 100/100
# 26/26 - 0s - loss: 1.8848e-04 - val_loss: 7.1304e-05 - 77ms/epoch - 3ms/step

# %%
model2 = Sequential()
model2.add(LSTM(64, input_shape=(5,8)))
model2.add(Dense(8, 'sigmoid'))
model2.add(Dense(1, 'linear'))
model2.compile(loss='mse', optimizer='adam')

# %%
model2.fit(X, y, epochs=300, validation_data=(valX, valy), verbose=2)
# Out:
# Epoch 1/300
# 26/26 - 1s - loss: 1.2458 - val_loss: 0.6315 - 1s/epoch - 51ms/step
# Epoch 2/300
# 26/26 - 0s - loss: 0.3796 - val_loss: 0.1982 - 80ms/epoch - 3ms/step
# Epoch 3/300
# 26/26 - 0s - loss: 0.1145 - val_loss: 0.0545 - 80ms/epoch - 3ms/step
# Epoch 4/300
# 26/26 - 0s - loss: 0.0296 - val_loss: 0.0131 - 80ms/epoch - 3ms/step
# Epoch 5/300
# 26/26 - 0s - loss: 0.0066 - val_loss: 0.0028 - 81ms/epoch - 3ms/step
# Epoch 6/300
# 26/26 - 0s - loss: 0.0014 - val_loss: 5.3440e-04 - 81ms/epoch - 3ms/step
# Epoch 7/300
# 26/26 - 0s - loss: 3.3444e-04 - val_loss: 1.2899e-04 - 80ms/epoch - 3ms/step
# Epoch 8/300
# 26/26 - 0s - loss: 1.8041e-04 - val_loss: 6.2300e-05 - 79ms/epoch - 3ms/step
# Epoch 9/300
# 26/26 - 0s - loss: 1.6530e-04 - val_loss: 4.8457e-05 - 79ms/epoch - 3ms/step
# Epoch 10/300
# 26/26 - 0s - loss: 1.6392e-04 - val_loss: 4.6624e-05 - 82ms/epoch - 3ms/step
# Epoch 11/300
# 26/26 - 0s - loss: 1.6384e-04 - val_loss: 4.6247e-05 - 79ms/epoch - 3ms/step
# Epoch 12/300
# 26/26 - 0s - loss: 1.6383e-04 - val_loss: 4.6977e-05 - 79ms/epoch - 3ms/step
# Epoch 13/300
# 26/26 - 0s - loss: 1.6386e-04 - val_loss: 4.6543e-05 - 78ms/epoch - 3ms/step
# Epoch 14/300
# 26/26 - 0s - loss: 1.6386e-04 - val_loss: 4.5801e-05 - 81ms/epoch - 3ms/step
# Epoch 15/300
# 26/26 - 0s - loss: 1.6379e-04 - val_loss: 4.6636e-05 - 79ms/epoch - 3ms/step
# Epoch 16/300
# 26/26 - 0s - loss: 1.6387e-04 - val_loss: 4.7022e-05 - 78ms/epoch - 3ms/step
# Epoch 17/300
# 26/26 - 0s - loss: 1.6383e-04 - val_loss: 4.5927e-05 - 78ms/epoch - 3ms/step
# Epoch 18/300
# 26/26 - 0s - loss: 1.6384e-04 - val_loss: 4.5401e-05 - 78ms/epoch - 3ms/step
# Epoch 19/300
# 26/26 - 0s - loss: 1.6383e-04 - val_loss: 4.5977e-05 - 80ms/epoch - 3ms/step
# Epoch 20/300
# 26/26 - 0s - loss: 1.6407e-04 - val_loss: 4.7582e-05 - 79ms/epoch - 3ms/step
# Epoch 21/300
# 26/26 - 0s - loss: 1.6401e-04 - val_loss: 4.5375e-05 - 79ms/epoch - 3ms/step
# Epoch 22/300
# 26/26 - 0s - loss: 1.6386e-04 - val_loss: 4.6565e-05 - 76ms/epoch - 3ms/step
# Epoch 23/300
# 26/26 - 0s - loss: 1.6398e-04 - val_loss: 4.5334e-05 - 77ms/epoch - 3ms/step
# Epoch 24/300
# 26/26 - 0s - loss: 1.6404e-04 - val_loss: 4.8301e-05 - 80ms/epoch - 3ms/step
# Epoch 25/300
# 26/26 - 0s - loss: 1.6385e-04 - val_loss: 4.5836e-05 - 77ms/epoch - 3ms/step
# Epoch 26/300
# 26/26 - 0s - loss: 1.6388e-04 - val_loss: 4.5545e-05 - 83ms/epoch - 3ms/step
# Epoch 27/300
# 26/26 - 0s - loss: 1.6383e-04 - val_loss: 4.5917e-05 - 104ms/epoch - 4ms/step
# Epoch 28/300
# 26/26 - 0s - loss: 1.6399e-04 - val_loss: 4.7201e-05 - 86ms/epoch - 3ms/step
# Epoch 29/300
# 26/26 - 0s - loss: 1.6387e-04 - val_loss: 4.5240e-05 - 77ms/epoch - 3ms/step
# Epoch 30/300
# 26/26 - 0s - loss: 1.6387e-04 - val_loss: 4.7120e-05 - 79ms/epoch - 3ms/step
# Epoch 31/300
# 26/26 - 0s - loss: 1.6389e-04 - val_loss: 4.5647e-05 - 80ms/epoch - 3ms/step
# Epoch 32/300
# 26/26 - 0s - loss: 1.6391e-04 - val_loss: 4.7614e-05 - 78ms/epoch - 3ms/step
# Epoch 33/300
# 26/26 - 0s - loss: 1.6391e-04 - val_loss: 4.6911e-05 - 78ms/epoch - 3ms/step
# Epoch 34/300
# 26/26 - 0s - loss: 1.6386e-04 - val_loss: 4.6569e-05 - 78ms/epoch - 3ms/step
# Epoch 35/300
# 26/26 - 0s - loss: 1.6387e-04 - val_loss: 4.6302e-05 - 77ms/epoch - 3ms/step
# Epoch 36/300
# 26/26 - 0s - loss: 1.6396e-04 - val_loss: 4.6516e-05 - 80ms/epoch - 3ms/step
# Epoch 37/300
# 26/26 - 0s - loss: 1.6398e-04 - val_loss: 4.6506e-05 - 79ms/epoch - 3ms/step
# Epoch 38/300
# 26/26 - 0s - loss: 1.6393e-04 - val_loss: 4.6154e-05 - 78ms/epoch - 3ms/step
# Epoch 39/300
# 26/26 - 0s - loss: 1.6393e-04 - val_loss: 4.5356e-05 - 108ms/epoch - 4ms/step
# Epoch 40/300
# 26/26 - 0s - loss: 1.6398e-04 - val_loss: 4.6839e-05 - 78ms/epoch - 3ms/step
# Epoch 41/300
# 26/26 - 0s - loss: 1.6447e-04 - val_loss: 4.5344e-05 - 79ms/epoch - 3ms/step
# Epoch 42/300
# 26/26 - 0s - loss: 1.6400e-04 - val_loss: 4.7669e-05 - 80ms/epoch - 3ms/step
# Epoch 43/300
# 26/26 - 0s - loss: 1.6393e-04 - val_loss: 4.6602e-05 - 79ms/epoch - 3ms/step
# Epoch 44/300
# 26/26 - 0s - loss: 1.6384e-04 - val_loss: 4.5496e-05 - 108ms/epoch - 4ms/step
# Epoch 45/300
# 26/26 - 0s - loss: 1.6403e-04 - val_loss: 4.6953e-05 - 77ms/epoch - 3ms/step
# Epoch 46/300
# 26/26 - 0s - loss: 1.6399e-04 - val_loss: 4.5484e-05 - 80ms/epoch - 3ms/step
# Epoch 47/300
# 26/26 - 0s - loss: 1.6387e-04 - val_loss: 4.6953e-05 - 79ms/epoch - 3ms/step
# Epoch 48/300
# 26/26 - 0s - loss: 1.6452e-04 - val_loss: 4.4793e-05 - 76ms/epoch - 3ms/step
# Epoch 49/300
# 26/26 - 0s - loss: 1.6405e-04 - val_loss: 4.6520e-05 - 77ms/epoch - 3ms/step
# Epoch 50/300
# 26/26 - 0s - loss: 1.6396e-04 - val_loss: 4.6069e-05 - 76ms/epoch - 3ms/step
# Epoch 51/300
# 26/26 - 0s - loss: 1.6393e-04 - val_loss: 4.5794e-05 - 77ms/epoch - 3ms/step
# Epoch 52/300
# 26/26 - 0s - loss: 1.6401e-04 - val_loss: 4.5864e-05 - 77ms/epoch - 3ms/step
# Epoch 53/300
# 26/26 - 0s - loss: 1.6416e-04 - val_loss: 4.6224e-05 - 76ms/epoch - 3ms/step
# Epoch 54/300
# 26/26 - 0s - loss: 1.6385e-04 - val_loss: 4.6673e-05 - 76ms/epoch - 3ms/step
# Epoch 55/300
# 26/26 - 0s - loss: 1.6393e-04 - val_loss: 4.6152e-05 - 76ms/epoch - 3ms/step
# Epoch 56/300
# 26/26 - 0s - loss: 1.6413e-04 - val_loss: 4.5055e-05 - 75ms/epoch - 3ms/step
# Epoch 57/300
# 26/26 - 0s - loss: 1.6410e-04 - val_loss: 4.8017e-05 - 77ms/epoch - 3ms/step
# Epoch 58/300
# 26/26 - 0s - loss: 1.6410e-04 - val_loss: 4.5174e-05 - 75ms/epoch - 3ms/step
# Epoch 59/300
# 26/26 - 0s - loss: 1.6440e-04 - val_loss: 4.6382e-05 - 77ms/epoch - 3ms/step
# Epoch 60/300
# 26/26 - 0s - loss: 1.6435e-04 - val_loss: 4.7102e-05 - 77ms/epoch - 3ms/step
# Epoch 61/300
# 26/26 - 0s - loss: 1.6396e-04 - val_loss: 4.6790e-05 - 80ms/epoch - 3ms/step
# Epoch 62/300
# 26/26 - 0s - loss: 1.6424e-04 - val_loss: 4.5191e-05 - 86ms/epoch - 3ms/step
# Epoch 63/300
# 26/26 - 0s - loss: 1.6443e-04 - val_loss: 4.6378e-05 - 76ms/epoch - 3ms/step
# Epoch 64/300
# 26/26 - 0s - loss: 1.6407e-04 - val_loss: 4.5482e-05 - 76ms/epoch - 3ms/step
# Epoch 65/300
# 26/26 - 0s - loss: 1.6470e-04 - val_loss: 4.5418e-05 - 103ms/epoch - 4ms/step
# Epoch 66/300
# 26/26 - 0s - loss: 1.6394e-04 - val_loss: 4.6430e-05 - 77ms/epoch - 3ms/step
# Epoch 67/300
# 26/26 - 0s - loss: 1.6407e-04 - val_loss: 4.7490e-05 - 78ms/epoch - 3ms/step
# Epoch 68/300
# 26/26 - 0s - loss: 1.6392e-04 - val_loss: 4.5668e-05 - 78ms/epoch - 3ms/step
# Epoch 69/300
# 26/26 - 0s - loss: 1.6412e-04 - val_loss: 4.8305e-05 - 79ms/epoch - 3ms/step
# Epoch 70/300
# 26/26 - 0s - loss: 1.6455e-04 - val_loss: 4.5720e-05 - 77ms/epoch - 3ms/step
# Epoch 71/300
# 26/26 - 0s - loss: 1.6385e-04 - val_loss: 4.6941e-05 - 77ms/epoch - 3ms/step
# Epoch 72/300
# 26/26 - 0s - loss: 1.6402e-04 - val_loss: 4.5739e-05 - 81ms/epoch - 3ms/step
# Epoch 73/300
# 26/26 - 0s - loss: 1.6410e-04 - val_loss: 4.6466e-05 - 85ms/epoch - 3ms/step
# Epoch 74/300
# 26/26 - 0s - loss: 1.6392e-04 - val_loss: 4.5942e-05 - 120ms/epoch - 5ms/step
# Epoch 75/300
# 26/26 - 0s - loss: 1.6425e-04 - val_loss: 4.6122e-05 - 76ms/epoch - 3ms/step
# Epoch 76/300
# 26/26 - 0s - loss: 1.6417e-04 - val_loss: 4.8058e-05 - 78ms/epoch - 3ms/step
# Epoch 77/300
# 26/26 - 0s - loss: 1.6417e-04 - val_loss: 4.3701e-05 - 83ms/epoch - 3ms/step
# Epoch 78/300
# 26/26 - 0s - loss: 1.6409e-04 - val_loss: 4.7300e-05 - 77ms/epoch - 3ms/step
# Epoch 79/300
# 26/26 - 0s - loss: 1.6410e-04 - val_loss: 4.6806e-05 - 77ms/epoch - 3ms/step
# Epoch 80/300
# 26/26 - 0s - loss: 1.6414e-04 - val_loss: 4.6481e-05 - 79ms/epoch - 3ms/step
# Epoch 81/300
# 26/26 - 0s - loss: 1.6426e-04 - val_loss: 4.9917e-05 - 77ms/epoch - 3ms/step
# Epoch 82/300
# 26/26 - 0s - loss: 1.6504e-04 - val_loss: 4.3613e-05 - 76ms/epoch - 3ms/step
# Epoch 83/300
# 26/26 - 0s - loss: 1.6436e-04 - val_loss: 4.6239e-05 - 77ms/epoch - 3ms/step
# Epoch 84/300
# 26/26 - 0s - loss: 1.6414e-04 - val_loss: 4.8584e-05 - 77ms/epoch - 3ms/step
# Epoch 85/300
# 26/26 - 0s - loss: 1.6427e-04 - val_loss: 4.4487e-05 - 78ms/epoch - 3ms/step
# Epoch 86/300
# 26/26 - 0s - loss: 1.6412e-04 - val_loss: 4.9295e-05 - 77ms/epoch - 3ms/step
# Epoch 87/300
# 26/26 - 0s - loss: 1.6408e-04 - val_loss: 4.4349e-05 - 76ms/epoch - 3ms/step
# Epoch 88/300
# 26/26 - 0s - loss: 1.6424e-04 - val_loss: 4.6492e-05 - 78ms/epoch - 3ms/step
# Epoch 89/300
# 26/26 - 0s - loss: 1.6400e-04 - val_loss: 4.5754e-05 - 87ms/epoch - 3ms/step
# Epoch 90/300
# 26/26 - 0s - loss: 1.6393e-04 - val_loss: 4.6880e-05 - 84ms/epoch - 3ms/step
# Epoch 91/300
# 26/26 - 0s - loss: 1.6429e-04 - val_loss: 4.8521e-05 - 80ms/epoch - 3ms/step
# Epoch 92/300
# 26/26 - 0s - loss: 1.6422e-04 - val_loss: 4.7238e-05 - 77ms/epoch - 3ms/step
# Epoch 93/300
# 26/26 - 0s - loss: 1.6398e-04 - val_loss: 4.5641e-05 - 77ms/epoch - 3ms/step
# Epoch 94/300
# 26/26 - 0s - loss: 1.6457e-04 - val_loss: 4.6338e-05 - 77ms/epoch - 3ms/step
# Epoch 95/300
# 26/26 - 0s - loss: 1.6421e-04 - val_loss: 4.5867e-05 - 77ms/epoch - 3ms/step
# Epoch 96/300
# 26/26 - 0s - loss: 1.6427e-04 - val_loss: 4.4648e-05 - 77ms/epoch - 3ms/step
# Epoch 97/300
# 26/26 - 0s - loss: 1.6429e-04 - val_loss: 4.7391e-05 - 79ms/epoch - 3ms/step
# Epoch 98/300
# 26/26 - 0s - loss: 1.6462e-04 - val_loss: 4.7996e-05 - 76ms/epoch - 3ms/step
# Epoch 99/300
# 26/26 - 0s - loss: 1.6436e-04 - val_loss: 4.9666e-05 - 105ms/epoch - 4ms/step
# Epoch 100/300
# 26/26 - 0s - loss: 1.6427e-04 - val_loss: 4.3216e-05 - 80ms/epoch - 3ms/step
# Epoch 101/300
# 26/26 - 0s - loss: 1.6452e-04 - val_loss: 4.8040e-05 - 94ms/epoch - 4ms/step
# Epoch 102/300
# 26/26 - 0s - loss: 1.6400e-04 - val_loss: 4.2994e-05 - 87ms/epoch - 3ms/step
# Epoch 103/300
# 26/26 - 0s - loss: 1.6444e-04 - val_loss: 4.6543e-05 - 81ms/epoch - 3ms/step
# Epoch 104/300
# 26/26 - 0s - loss: 1.6394e-04 - val_loss: 4.5438e-05 - 77ms/epoch - 3ms/step
# Epoch 105/300
# 26/26 - 0s - loss: 1.6487e-04 - val_loss: 4.1698e-05 - 78ms/epoch - 3ms/step
# Epoch 106/300
# 26/26 - 0s - loss: 1.6434e-04 - val_loss: 5.1470e-05 - 79ms/epoch - 3ms/step
# Epoch 107/300
# 26/26 - 0s - loss: 1.6470e-04 - val_loss: 4.0992e-05 - 77ms/epoch - 3ms/step
# Epoch 108/300
# 26/26 - 0s - loss: 1.6430e-04 - val_loss: 4.8646e-05 - 77ms/epoch - 3ms/step
# Epoch 109/300
# 26/26 - 0s - loss: 1.6401e-04 - val_loss: 4.5734e-05 - 78ms/epoch - 3ms/step
# Epoch 110/300
# 26/26 - 0s - loss: 1.6442e-04 - val_loss: 4.6581e-05 - 77ms/epoch - 3ms/step
# Epoch 111/300
# 26/26 - 0s - loss: 1.6560e-04 - val_loss: 5.1925e-05 - 77ms/epoch - 3ms/step
# Epoch 112/300
# 26/26 - 0s - loss: 1.6480e-04 - val_loss: 4.7773e-05 - 77ms/epoch - 3ms/step
# Epoch 113/300
# 26/26 - 0s - loss: 1.6395e-04 - val_loss: 4.4727e-05 - 77ms/epoch - 3ms/step
# Epoch 114/300
# 26/26 - 0s - loss: 1.6453e-04 - val_loss: 5.1639e-05 - 112ms/epoch - 4ms/step
# Epoch 115/300
# 26/26 - 0s - loss: 1.6420e-04 - val_loss: 4.5981e-05 - 86ms/epoch - 3ms/step
# Epoch 116/300
# 26/26 - 0s - loss: 1.6416e-04 - val_loss: 4.7350e-05 - 77ms/epoch - 3ms/step
# Epoch 117/300
# 26/26 - 0s - loss: 1.6412e-04 - val_loss: 4.5477e-05 - 81ms/epoch - 3ms/step
# Epoch 118/300
# 26/26 - 0s - loss: 1.6389e-04 - val_loss: 4.6755e-05 - 77ms/epoch - 3ms/step
# Epoch 119/300
# 26/26 - 0s - loss: 1.6490e-04 - val_loss: 5.3562e-05 - 92ms/epoch - 4ms/step
# Epoch 120/300
# 26/26 - 0s - loss: 1.6587e-04 - val_loss: 5.0166e-05 - 78ms/epoch - 3ms/step
# Epoch 121/300
# 26/26 - 0s - loss: 1.6639e-04 - val_loss: 4.3392e-05 - 78ms/epoch - 3ms/step
# Epoch 122/300
# 26/26 - 0s - loss: 1.6504e-04 - val_loss: 4.9584e-05 - 78ms/epoch - 3ms/step
# Epoch 123/300
# 26/26 - 0s - loss: 1.6574e-04 - val_loss: 4.0856e-05 - 79ms/epoch - 3ms/step
# Epoch 124/300
# 26/26 - 0s - loss: 1.6541e-04 - val_loss: 4.1857e-05 - 79ms/epoch - 3ms/step
# Epoch 125/300
# 26/26 - 0s - loss: 1.6544e-04 - val_loss: 5.4979e-05 - 96ms/epoch - 4ms/step
# Epoch 126/300
# 26/26 - 0s - loss: 1.6445e-04 - val_loss: 4.3610e-05 - 78ms/epoch - 3ms/step
# Epoch 127/300
# 26/26 - 0s - loss: 1.6416e-04 - val_loss: 4.6156e-05 - 94ms/epoch - 4ms/step
# Epoch 128/300
# 26/26 - 0s - loss: 1.6524e-04 - val_loss: 5.9626e-05 - 99ms/epoch - 4ms/step
# Epoch 129/300
# 26/26 - 0s - loss: 1.6524e-04 - val_loss: 4.5614e-05 - 78ms/epoch - 3ms/step
# Epoch 130/300
# 26/26 - 0s - loss: 1.6433e-04 - val_loss: 4.5259e-05 - 78ms/epoch - 3ms/step
# Epoch 131/300
# 26/26 - 0s - loss: 1.6434e-04 - val_loss: 4.8503e-05 - 79ms/epoch - 3ms/step
# Epoch 132/300
# 26/26 - 0s - loss: 1.6408e-04 - val_loss: 5.0464e-05 - 79ms/epoch - 3ms/step
# Epoch 133/300
# 26/26 - 0s - loss: 1.6500e-04 - val_loss: 4.7343e-05 - 77ms/epoch - 3ms/step
# Epoch 134/300
# 26/26 - 0s - loss: 1.6438e-04 - val_loss: 4.2731e-05 - 77ms/epoch - 3ms/step
# Epoch 135/300
# 26/26 - 0s - loss: 1.6532e-04 - val_loss: 4.0561e-05 - 78ms/epoch - 3ms/step
# Epoch 136/300
# 26/26 - 0s - loss: 1.6545e-04 - val_loss: 4.8846e-05 - 77ms/epoch - 3ms/step
# Epoch 137/300
# 26/26 - 0s - loss: 1.6530e-04 - val_loss: 4.5650e-05 - 76ms/epoch - 3ms/step
# Epoch 138/300
# 26/26 - 0s - loss: 1.6462e-04 - val_loss: 6.1993e-05 - 78ms/epoch - 3ms/step
# Epoch 139/300
# 26/26 - 0s - loss: 1.6645e-04 - val_loss: 5.0186e-05 - 78ms/epoch - 3ms/step
# Epoch 140/300
# 26/26 - 0s - loss: 1.6482e-04 - val_loss: 4.2744e-05 - 77ms/epoch - 3ms/step
# Epoch 141/300
# 26/26 - 0s - loss: 1.6407e-04 - val_loss: 4.8918e-05 - 79ms/epoch - 3ms/step
# Epoch 142/300
# 26/26 - 0s - loss: 1.6488e-04 - val_loss: 5.2680e-05 - 77ms/epoch - 3ms/step
# Epoch 143/300
# 26/26 - 0s - loss: 1.6427e-04 - val_loss: 4.4747e-05 - 78ms/epoch - 3ms/step
# Epoch 144/300
# 26/26 - 0s - loss: 1.6474e-04 - val_loss: 4.7850e-05 - 93ms/epoch - 4ms/step
# Epoch 145/300
# 26/26 - 0s - loss: 1.6560e-04 - val_loss: 3.9504e-05 - 77ms/epoch - 3ms/step
# Epoch 146/300
# 26/26 - 0s - loss: 1.6412e-04 - val_loss: 4.8240e-05 - 78ms/epoch - 3ms/step
# Epoch 147/300
# 26/26 - 0s - loss: 1.6513e-04 - val_loss: 5.3571e-05 - 78ms/epoch - 3ms/step
# Epoch 148/300
# 26/26 - 0s - loss: 1.6448e-04 - val_loss: 4.6366e-05 - 76ms/epoch - 3ms/step
# Epoch 149/300
# 26/26 - 0s - loss: 1.6430e-04 - val_loss: 4.9678e-05 - 77ms/epoch - 3ms/step
# Epoch 150/300
# 26/26 - 0s - loss: 1.6712e-04 - val_loss: 4.6400e-05 - 77ms/epoch - 3ms/step
# Epoch 151/300
# 26/26 - 0s - loss: 1.6415e-04 - val_loss: 4.3320e-05 - 78ms/epoch - 3ms/step
# Epoch 152/300
# 26/26 - 0s - loss: 1.6464e-04 - val_loss: 5.0924e-05 - 78ms/epoch - 3ms/step
# Epoch 153/300
# 26/26 - 0s - loss: 1.6597e-04 - val_loss: 4.5114e-05 - 77ms/epoch - 3ms/step
# Epoch 154/300
# 26/26 - 0s - loss: 1.6611e-04 - val_loss: 4.1999e-05 - 75ms/epoch - 3ms/step
# Epoch 155/300
# 26/26 - 0s - loss: 1.6634e-04 - val_loss: 4.2406e-05 - 77ms/epoch - 3ms/step
# Epoch 156/300
# 26/26 - 0s - loss: 1.6438e-04 - val_loss: 4.2619e-05 - 76ms/epoch - 3ms/step
# Epoch 157/300
# 26/26 - 0s - loss: 1.6572e-04 - val_loss: 4.4076e-05 - 83ms/epoch - 3ms/step
# Epoch 158/300
# 26/26 - 0s - loss: 1.6479e-04 - val_loss: 4.9025e-05 - 76ms/epoch - 3ms/step
# Epoch 159/300
# 26/26 - 0s - loss: 1.6421e-04 - val_loss: 4.3648e-05 - 75ms/epoch - 3ms/step
# Epoch 160/300
# 26/26 - 0s - loss: 1.6479e-04 - val_loss: 4.6931e-05 - 76ms/epoch - 3ms/step
# Epoch 161/300
# 26/26 - 0s - loss: 1.6420e-04 - val_loss: 4.6756e-05 - 75ms/epoch - 3ms/step
# Epoch 162/300
# 26/26 - 0s - loss: 1.6467e-04 - val_loss: 5.5552e-05 - 75ms/epoch - 3ms/step
# Epoch 163/300
# 26/26 - 0s - loss: 1.6591e-04 - val_loss: 4.5343e-05 - 75ms/epoch - 3ms/step
# Epoch 164/300
# 26/26 - 0s - loss: 1.6348e-04 - val_loss: 6.7708e-05 - 77ms/epoch - 3ms/step
# Epoch 165/300
# 26/26 - 0s - loss: 1.6728e-04 - val_loss: 4.4903e-05 - 77ms/epoch - 3ms/step
# Epoch 166/300
# 26/26 - 0s - loss: 1.6881e-04 - val_loss: 5.2810e-05 - 77ms/epoch - 3ms/step
# Epoch 167/300
# 26/26 - 0s - loss: 1.6716e-04 - val_loss: 5.6492e-05 - 78ms/epoch - 3ms/step
# Epoch 168/300
# 26/26 - 0s - loss: 1.6568e-04 - val_loss: 5.4924e-05 - 76ms/epoch - 3ms/step
# Epoch 169/300
# 26/26 - 0s - loss: 1.6552e-04 - val_loss: 4.4646e-05 - 77ms/epoch - 3ms/step
# Epoch 170/300
# 26/26 - 0s - loss: 1.6457e-04 - val_loss: 4.1265e-05 - 78ms/epoch - 3ms/step
# Epoch 171/300
# 26/26 - 0s - loss: 1.6575e-04 - val_loss: 4.7201e-05 - 78ms/epoch - 3ms/step
# Epoch 172/300
# 26/26 - 0s - loss: 1.6771e-04 - val_loss: 5.5643e-05 - 78ms/epoch - 3ms/step
# Epoch 173/300
# 26/26 - 0s - loss: 1.6559e-04 - val_loss: 4.1907e-05 - 76ms/epoch - 3ms/step
# Epoch 174/300
# 26/26 - 0s - loss: 1.6439e-04 - val_loss: 4.2320e-05 - 76ms/epoch - 3ms/step
# Epoch 175/300
# 26/26 - 0s - loss: 1.6552e-04 - val_loss: 4.0039e-05 - 76ms/epoch - 3ms/step
# Epoch 176/300
# 26/26 - 0s - loss: 1.6287e-04 - val_loss: 6.6937e-05 - 77ms/epoch - 3ms/step
# Epoch 177/300
# 26/26 - 0s - loss: 1.6668e-04 - val_loss: 4.9478e-05 - 78ms/epoch - 3ms/step
# Epoch 178/300
# 26/26 - 0s - loss: 1.6635e-04 - val_loss: 5.5250e-05 - 77ms/epoch - 3ms/step
# Epoch 179/300
# 26/26 - 0s - loss: 1.6464e-04 - val_loss: 4.6010e-05 - 78ms/epoch - 3ms/step
# Epoch 180/300
# 26/26 - 0s - loss: 1.6661e-04 - val_loss: 3.8566e-05 - 76ms/epoch - 3ms/step
# Epoch 181/300
# 26/26 - 0s - loss: 1.6733e-04 - val_loss: 3.9676e-05 - 83ms/epoch - 3ms/step
# Epoch 182/300
# 26/26 - 0s - loss: 1.6540e-04 - val_loss: 4.5464e-05 - 77ms/epoch - 3ms/step
# Epoch 183/300
# 26/26 - 0s - loss: 1.6655e-04 - val_loss: 5.0162e-05 - 76ms/epoch - 3ms/step
# Epoch 184/300
# 26/26 - 0s - loss: 1.6450e-04 - val_loss: 4.0317e-05 - 111ms/epoch - 4ms/step
# Epoch 185/300
# 26/26 - 0s - loss: 1.6450e-04 - val_loss: 4.2578e-05 - 84ms/epoch - 3ms/step
# Epoch 186/300
# 26/26 - 0s - loss: 1.6930e-04 - val_loss: 3.9168e-05 - 76ms/epoch - 3ms/step
# Epoch 187/300
# 26/26 - 0s - loss: 1.6763e-04 - val_loss: 4.4963e-05 - 76ms/epoch - 3ms/step
# Epoch 188/300
# 26/26 - 0s - loss: 1.6847e-04 - val_loss: 6.2256e-05 - 76ms/epoch - 3ms/step
# Epoch 189/300
# 26/26 - 0s - loss: 1.6852e-04 - val_loss: 5.2650e-05 - 76ms/epoch - 3ms/step
# Epoch 190/300
# 26/26 - 0s - loss: 1.6512e-04 - val_loss: 5.0501e-05 - 77ms/epoch - 3ms/step
# Epoch 191/300
# 26/26 - 0s - loss: 1.6504e-04 - val_loss: 4.7899e-05 - 76ms/epoch - 3ms/step
# Epoch 192/300
# 26/26 - 0s - loss: 1.6506e-04 - val_loss: 4.0511e-05 - 79ms/epoch - 3ms/step
# Epoch 193/300
# 26/26 - 0s - loss: 1.6570e-04 - val_loss: 3.9679e-05 - 78ms/epoch - 3ms/step
# Epoch 194/300
# 26/26 - 0s - loss: 1.6453e-04 - val_loss: 4.9119e-05 - 78ms/epoch - 3ms/step
# Epoch 195/300
# 26/26 - 0s - loss: 1.6582e-04 - val_loss: 4.4264e-05 - 77ms/epoch - 3ms/step
# Epoch 196/300
# 26/26 - 0s - loss: 1.6453e-04 - val_loss: 4.1646e-05 - 76ms/epoch - 3ms/step
# Epoch 197/300
# 26/26 - 0s - loss: 1.6601e-04 - val_loss: 3.8459e-05 - 76ms/epoch - 3ms/step
# Epoch 198/300
# 26/26 - 0s - loss: 1.6700e-04 - val_loss: 4.7126e-05 - 99ms/epoch - 4ms/step
# Epoch 199/300
# 26/26 - 0s - loss: 1.6743e-04 - val_loss: 4.0950e-05 - 76ms/epoch - 3ms/step
# Epoch 200/300
# 26/26 - 0s - loss: 1.6638e-04 - val_loss: 4.1188e-05 - 74ms/epoch - 3ms/step
# Epoch 201/300
# 26/26 - 0s - loss: 1.6475e-04 - val_loss: 4.8769e-05 - 77ms/epoch - 3ms/step
# Epoch 202/300
# 26/26 - 0s - loss: 1.6611e-04 - val_loss: 6.1081e-05 - 77ms/epoch - 3ms/step
# Epoch 203/300
# 26/26 - 0s - loss: 1.6697e-04 - val_loss: 4.0117e-05 - 78ms/epoch - 3ms/step
# Epoch 204/300
# 26/26 - 0s - loss: 1.6472e-04 - val_loss: 4.4598e-05 - 77ms/epoch - 3ms/step
# Epoch 205/300
# 26/26 - 0s - loss: 1.6628e-04 - val_loss: 5.0947e-05 - 78ms/epoch - 3ms/step
# Epoch 206/300
# 26/26 - 0s - loss: 1.6934e-04 - val_loss: 4.0138e-05 - 76ms/epoch - 3ms/step
# Epoch 207/300
# 26/26 - 0s - loss: 1.6740e-04 - val_loss: 3.9593e-05 - 80ms/epoch - 3ms/step
# Epoch 208/300
# 26/26 - 0s - loss: 1.7003e-04 - val_loss: 4.0144e-05 - 75ms/epoch - 3ms/step
# Epoch 209/300
# 26/26 - 0s - loss: 1.6773e-04 - val_loss: 5.7280e-05 - 76ms/epoch - 3ms/step
# Epoch 210/300
# 26/26 - 0s - loss: 1.6782e-04 - val_loss: 4.1345e-05 - 76ms/epoch - 3ms/step
# Epoch 211/300
# 26/26 - 0s - loss: 1.6831e-04 - val_loss: 4.8075e-05 - 77ms/epoch - 3ms/step
# Epoch 212/300
# 26/26 - 0s - loss: 1.6519e-04 - val_loss: 4.7781e-05 - 78ms/epoch - 3ms/step
# Epoch 213/300
# 26/26 - 0s - loss: 1.6596e-04 - val_loss: 6.8077e-05 - 77ms/epoch - 3ms/step
# Epoch 214/300
# 26/26 - 0s - loss: 1.6978e-04 - val_loss: 4.0230e-05 - 105ms/epoch - 4ms/step
# Epoch 215/300
# 26/26 - 0s - loss: 1.6634e-04 - val_loss: 4.0179e-05 - 100ms/epoch - 4ms/step
# Epoch 216/300
# 26/26 - 0s - loss: 1.6436e-04 - val_loss: 3.8457e-05 - 79ms/epoch - 3ms/step
# Epoch 217/300
# 26/26 - 0s - loss: 1.6683e-04 - val_loss: 3.8611e-05 - 76ms/epoch - 3ms/step
# Epoch 218/300
# 26/26 - 0s - loss: 1.6609e-04 - val_loss: 4.2195e-05 - 78ms/epoch - 3ms/step
# Epoch 219/300
# 26/26 - 0s - loss: 1.6487e-04 - val_loss: 4.0416e-05 - 77ms/epoch - 3ms/step
# Epoch 220/300
# 26/26 - 0s - loss: 1.6467e-04 - val_loss: 6.2393e-05 - 76ms/epoch - 3ms/step
# Epoch 221/300
# 26/26 - 0s - loss: 1.6576e-04 - val_loss: 5.3556e-05 - 79ms/epoch - 3ms/step
# Epoch 222/300
# 26/26 - 0s - loss: 1.6617e-04 - val_loss: 4.2303e-05 - 77ms/epoch - 3ms/step
# Epoch 223/300
# 26/26 - 0s - loss: 1.6512e-04 - val_loss: 5.1243e-05 - 78ms/epoch - 3ms/step
# Epoch 224/300
# 26/26 - 0s - loss: 1.6534e-04 - val_loss: 5.1338e-05 - 80ms/epoch - 3ms/step
# Epoch 225/300
# 26/26 - 0s - loss: 1.6542e-04 - val_loss: 5.4416e-05 - 76ms/epoch - 3ms/step
# Epoch 226/300
# 26/26 - 0s - loss: 1.6429e-04 - val_loss: 7.0739e-05 - 77ms/epoch - 3ms/step
# Epoch 227/300
# 26/26 - 0s - loss: 1.6948e-04 - val_loss: 4.0706e-05 - 80ms/epoch - 3ms/step
# Epoch 228/300
# 26/26 - 0s - loss: 1.6630e-04 - val_loss: 4.2264e-05 - 78ms/epoch - 3ms/step
# Epoch 229/300
# 26/26 - 0s - loss: 1.6691e-04 - val_loss: 4.4241e-05 - 77ms/epoch - 3ms/step
# Epoch 230/300
# 26/26 - 0s - loss: 1.6748e-04 - val_loss: 6.6546e-05 - 77ms/epoch - 3ms/step
# Epoch 231/300
# 26/26 - 0s - loss: 1.6798e-04 - val_loss: 4.4050e-05 - 77ms/epoch - 3ms/step
# Epoch 232/300
# 26/26 - 0s - loss: 1.6619e-04 - val_loss: 6.1195e-05 - 79ms/epoch - 3ms/step
# Epoch 233/300
# 26/26 - 0s - loss: 1.6623e-04 - val_loss: 3.8880e-05 - 77ms/epoch - 3ms/step
# Epoch 234/300
# 26/26 - 0s - loss: 1.6888e-04 - val_loss: 5.1381e-05 - 78ms/epoch - 3ms/step
# Epoch 235/300
# 26/26 - 0s - loss: 1.6563e-04 - val_loss: 5.6174e-05 - 87ms/epoch - 3ms/step
# Epoch 236/300
# 26/26 - 0s - loss: 1.6517e-04 - val_loss: 3.9983e-05 - 79ms/epoch - 3ms/step
# Epoch 237/300
# 26/26 - 0s - loss: 1.6560e-04 - val_loss: 5.0192e-05 - 77ms/epoch - 3ms/step
# Epoch 238/300
# 26/26 - 0s - loss: 1.6621e-04 - val_loss: 4.4192e-05 - 76ms/epoch - 3ms/step
# Epoch 239/300
# 26/26 - 0s - loss: 1.6489e-04 - val_loss: 4.2010e-05 - 78ms/epoch - 3ms/step
# Epoch 240/300
# 26/26 - 0s - loss: 1.6559e-04 - val_loss: 3.9083e-05 - 76ms/epoch - 3ms/step
# Epoch 241/300
# 26/26 - 0s - loss: 1.6587e-04 - val_loss: 5.2139e-05 - 77ms/epoch - 3ms/step
# Epoch 242/300
# 26/26 - 0s - loss: 1.6909e-04 - val_loss: 6.9103e-05 - 78ms/epoch - 3ms/step
# Epoch 243/300
# 26/26 - 0s - loss: 1.6563e-04 - val_loss: 4.5079e-05 - 76ms/epoch - 3ms/step
# Epoch 244/300
# 26/26 - 0s - loss: 1.6556e-04 - val_loss: 3.9220e-05 - 78ms/epoch - 3ms/step
# Epoch 245/300
# 26/26 - 0s - loss: 1.6560e-04 - val_loss: 6.5232e-05 - 78ms/epoch - 3ms/step
# Epoch 246/300
# 26/26 - 0s - loss: 1.6800e-04 - val_loss: 6.0789e-05 - 78ms/epoch - 3ms/step
# Epoch 247/300
# 26/26 - 0s - loss: 1.6991e-04 - val_loss: 4.7916e-05 - 78ms/epoch - 3ms/step
# Epoch 248/300
# 26/26 - 0s - loss: 1.6999e-04 - val_loss: 3.8970e-05 - 104ms/epoch - 4ms/step
# Epoch 249/300
# 26/26 - 0s - loss: 1.6575e-04 - val_loss: 3.9528e-05 - 80ms/epoch - 3ms/step
# Epoch 250/300
# 26/26 - 0s - loss: 1.6849e-04 - val_loss: 5.2359e-05 - 76ms/epoch - 3ms/step
# Epoch 251/300
# 26/26 - 0s - loss: 1.7138e-04 - val_loss: 3.8698e-05 - 76ms/epoch - 3ms/step
# Epoch 252/300
# 26/26 - 0s - loss: 1.7244e-04 - val_loss: 8.6389e-05 - 77ms/epoch - 3ms/step
# Epoch 253/300
# 26/26 - 0s - loss: 1.7004e-04 - val_loss: 3.8695e-05 - 76ms/epoch - 3ms/step
# Epoch 254/300
# 26/26 - 0s - loss: 1.6488e-04 - val_loss: 5.1994e-05 - 76ms/epoch - 3ms/step
# Epoch 255/300
# 26/26 - 0s - loss: 1.6618e-04 - val_loss: 4.3730e-05 - 77ms/epoch - 3ms/step
# Epoch 256/300
# 26/26 - 0s - loss: 1.6486e-04 - val_loss: 7.8408e-05 - 78ms/epoch - 3ms/step
# Epoch 257/300
# 26/26 - 0s - loss: 1.6945e-04 - val_loss: 3.9588e-05 - 76ms/epoch - 3ms/step
# Epoch 258/300
# 26/26 - 0s - loss: 1.6753e-04 - val_loss: 4.3424e-05 - 76ms/epoch - 3ms/step
# Epoch 259/300
# 26/26 - 0s - loss: 1.6903e-04 - val_loss: 4.6379e-05 - 77ms/epoch - 3ms/step
# Epoch 260/300
# 26/26 - 0s - loss: 1.6727e-04 - val_loss: 4.1570e-05 - 76ms/epoch - 3ms/step
# Epoch 261/300
# 26/26 - 0s - loss: 1.7622e-04 - val_loss: 3.8538e-05 - 113ms/epoch - 4ms/step
# Epoch 262/300
# 26/26 - 0s - loss: 1.6597e-04 - val_loss: 4.9337e-05 - 77ms/epoch - 3ms/step
# Epoch 263/300
# 26/26 - 0s - loss: 1.6939e-04 - val_loss: 9.1684e-05 - 76ms/epoch - 3ms/step
# Epoch 264/300
# 26/26 - 0s - loss: 1.7205e-04 - val_loss: 3.8452e-05 - 76ms/epoch - 3ms/step
# Epoch 265/300
# 26/26 - 0s - loss: 1.6875e-04 - val_loss: 5.5409e-05 - 76ms/epoch - 3ms/step
# Epoch 266/300
# 26/26 - 0s - loss: 1.6952e-04 - val_loss: 7.7936e-05 - 80ms/epoch - 3ms/step
# Epoch 267/300
# 26/26 - 0s - loss: 1.6599e-04 - val_loss: 3.9566e-05 - 77ms/epoch - 3ms/step
# Epoch 268/300
# 26/26 - 0s - loss: 1.7348e-04 - val_loss: 3.9483e-05 - 76ms/epoch - 3ms/step
# Epoch 269/300
# 26/26 - 0s - loss: 1.6607e-04 - val_loss: 6.0863e-05 - 77ms/epoch - 3ms/step
# Epoch 270/300
# 26/26 - 0s - loss: 1.6901e-04 - val_loss: 4.2827e-05 - 77ms/epoch - 3ms/step
# Epoch 271/300
# 26/26 - 0s - loss: 1.6901e-04 - val_loss: 3.8767e-05 - 77ms/epoch - 3ms/step
# Epoch 272/300
# 26/26 - 0s - loss: 1.6556e-04 - val_loss: 7.3773e-05 - 76ms/epoch - 3ms/step
# Epoch 273/300
# 26/26 - 0s - loss: 1.6901e-04 - val_loss: 4.9126e-05 - 119ms/epoch - 5ms/step
# Epoch 274/300
# 26/26 - 0s - loss: 1.6735e-04 - val_loss: 4.7342e-05 - 104ms/epoch - 4ms/step
# Epoch 275/300
# 26/26 - 0s - loss: 1.7140e-04 - val_loss: 8.4762e-05 - 76ms/epoch - 3ms/step
# Epoch 276/300
# 26/26 - 0s - loss: 1.7480e-04 - val_loss: 5.8613e-05 - 76ms/epoch - 3ms/step
# Epoch 277/300
# 26/26 - 0s - loss: 1.6929e-04 - val_loss: 4.1745e-05 - 78ms/epoch - 3ms/step
# Epoch 278/300
# 26/26 - 0s - loss: 1.7410e-04 - val_loss: 4.2343e-05 - 78ms/epoch - 3ms/step
# Epoch 279/300
# 26/26 - 0s - loss: 1.6603e-04 - val_loss: 4.8946e-05 - 77ms/epoch - 3ms/step
# Epoch 280/300
# 26/26 - 0s - loss: 1.6765e-04 - val_loss: 6.6831e-05 - 77ms/epoch - 3ms/step
# Epoch 281/300
# 26/26 - 0s - loss: 1.6740e-04 - val_loss: 5.2201e-05 - 86ms/epoch - 3ms/step
# Epoch 282/300
# 26/26 - 0s - loss: 1.6478e-04 - val_loss: 3.9149e-05 - 76ms/epoch - 3ms/step
# Epoch 283/300
# 26/26 - 0s - loss: 1.6635e-04 - val_loss: 4.1490e-05 - 76ms/epoch - 3ms/step
# Epoch 284/300
# 26/26 - 0s - loss: 1.6777e-04 - val_loss: 4.0966e-05 - 76ms/epoch - 3ms/step
# Epoch 285/300
# 26/26 - 0s - loss: 1.6784e-04 - val_loss: 7.8681e-05 - 77ms/epoch - 3ms/step
# Epoch 286/300
# 26/26 - 0s - loss: 1.6915e-04 - val_loss: 6.6766e-05 - 77ms/epoch - 3ms/step
# Epoch 287/300
# 26/26 - 0s - loss: 1.6646e-04 - val_loss: 4.7008e-05 - 119ms/epoch - 5ms/step
# Epoch 288/300
# 26/26 - 0s - loss: 1.6968e-04 - val_loss: 4.6565e-05 - 77ms/epoch - 3ms/step
# Epoch 289/300
# 26/26 - 0s - loss: 1.6468e-04 - val_loss: 4.6268e-05 - 77ms/epoch - 3ms/step
# Epoch 290/300
# 26/26 - 0s - loss: 1.6956e-04 - val_loss: 7.3863e-05 - 81ms/epoch - 3ms/step
# Epoch 291/300
# 26/26 - 0s - loss: 1.7244e-04 - val_loss: 6.9437e-05 - 79ms/epoch - 3ms/step
# Epoch 292/300
# 26/26 - 0s - loss: 1.7315e-04 - val_loss: 5.1859e-05 - 82ms/epoch - 3ms/step
# Epoch 293/300
# 26/26 - 0s - loss: 1.6913e-04 - val_loss: 9.8305e-05 - 75ms/epoch - 3ms/step
# Epoch 294/300
# 26/26 - 0s - loss: 1.6760e-04 - val_loss: 4.1409e-05 - 78ms/epoch - 3ms/step
# Epoch 295/300
# 26/26 - 0s - loss: 1.6964e-04 - val_loss: 4.0538e-05 - 77ms/epoch - 3ms/step
# Epoch 296/300
# 26/26 - 0s - loss: 1.6923e-04 - val_loss: 3.8719e-05 - 77ms/epoch - 3ms/step
# Epoch 297/300
# 26/26 - 0s - loss: 1.6798e-04 - val_loss: 5.1594e-05 - 79ms/epoch - 3ms/step
# Epoch 298/300
# 26/26 - 0s - loss: 1.7425e-04 - val_loss: 3.9623e-05 - 77ms/epoch - 3ms/step
# Epoch 299/300
# 26/26 - 0s - loss: 1.7344e-04 - val_loss: 4.0716e-05 - 114ms/epoch - 4ms/step
# Epoch 300/300
# 26/26 - 0s - loss: 1.6584e-04 - val_loss: 4.3788e-05 - 79ms/epoch - 3ms/step

# %% [markdown]
# Relu model converges better than sigmoid

# %%
model3 = Sequential()
model3.add(InputLayer(input_shape=(5,8)))
model3.add(LSTM(64))
model3.add(Dense(8, 'sigmoid'))
model3.add(Dense(1, 'linear'))
model3.compile(loss='mse', optimizer='adam')

# %%
model3.fit(X, y, epochs=100, validation_data=(valX, valy), verbose=2)
# Out:
# Epoch 1/100
# 26/26 - 1s - loss: 0.0118 - val_loss: 8.9766e-04 - 1s/epoch - 56ms/step
# Epoch 2/100
# 26/26 - 0s - loss: 3.3496e-04 - val_loss: 5.8015e-05 - 79ms/epoch - 3ms/step
# Epoch 3/100
# 26/26 - 0s - loss: 1.7934e-04 - val_loss: 3.8916e-05 - 79ms/epoch - 3ms/step
# Epoch 4/100
# 26/26 - 0s - loss: 1.6450e-04 - val_loss: 4.7329e-05 - 78ms/epoch - 3ms/step
# Epoch 5/100
# 26/26 - 0s - loss: 1.6401e-04 - val_loss: 4.2898e-05 - 78ms/epoch - 3ms/step
# Epoch 6/100
# 26/26 - 0s - loss: 1.6367e-04 - val_loss: 5.5568e-05 - 80ms/epoch - 3ms/step
# Epoch 7/100
# 26/26 - 0s - loss: 1.6486e-04 - val_loss: 5.1507e-05 - 78ms/epoch - 3ms/step
# Epoch 8/100
# 26/26 - 0s - loss: 1.6533e-04 - val_loss: 3.8783e-05 - 84ms/epoch - 3ms/step
# Epoch 9/100
# 26/26 - 0s - loss: 1.6571e-04 - val_loss: 5.0935e-05 - 78ms/epoch - 3ms/step
# Epoch 10/100
# 26/26 - 0s - loss: 1.6693e-04 - val_loss: 3.9724e-05 - 77ms/epoch - 3ms/step
# Epoch 11/100
# 26/26 - 0s - loss: 1.6531e-04 - val_loss: 4.6716e-05 - 108ms/epoch - 4ms/step
# Epoch 12/100
# 26/26 - 0s - loss: 1.6447e-04 - val_loss: 4.2867e-05 - 77ms/epoch - 3ms/step
# Epoch 13/100
# 26/26 - 0s - loss: 1.6635e-04 - val_loss: 3.8461e-05 - 78ms/epoch - 3ms/step
# Epoch 14/100
# 26/26 - 0s - loss: 1.6789e-04 - val_loss: 4.3991e-05 - 76ms/epoch - 3ms/step
# Epoch 15/100
# 26/26 - 0s - loss: 1.6463e-04 - val_loss: 5.0575e-05 - 78ms/epoch - 3ms/step
# Epoch 16/100
# 26/26 - 0s - loss: 1.6438e-04 - val_loss: 3.9973e-05 - 76ms/epoch - 3ms/step
# Epoch 17/100
# 26/26 - 0s - loss: 1.6516e-04 - val_loss: 4.4143e-05 - 76ms/epoch - 3ms/step
# Epoch 18/100
# 26/26 - 0s - loss: 1.6551e-04 - val_loss: 4.8428e-05 - 77ms/epoch - 3ms/step
# Epoch 19/100
# 26/26 - 0s - loss: 1.6566e-04 - val_loss: 4.6368e-05 - 76ms/epoch - 3ms/step
# Epoch 20/100
# 26/26 - 0s - loss: 1.6439e-04 - val_loss: 3.9131e-05 - 77ms/epoch - 3ms/step
# Epoch 21/100
# 26/26 - 0s - loss: 1.6831e-04 - val_loss: 3.8575e-05 - 77ms/epoch - 3ms/step
# Epoch 22/100
# 26/26 - 0s - loss: 1.6746e-04 - val_loss: 4.4268e-05 - 76ms/epoch - 3ms/step
# Epoch 23/100
# 26/26 - 0s - loss: 1.6504e-04 - val_loss: 5.5573e-05 - 77ms/epoch - 3ms/step
# Epoch 24/100
# 26/26 - 0s - loss: 1.6680e-04 - val_loss: 4.0504e-05 - 79ms/epoch - 3ms/step
# Epoch 25/100
# 26/26 - 0s - loss: 1.6850e-04 - val_loss: 4.7800e-05 - 80ms/epoch - 3ms/step
# Epoch 26/100
# 26/26 - 0s - loss: 1.6453e-04 - val_loss: 5.3903e-05 - 77ms/epoch - 3ms/step
# Epoch 27/100
# 26/26 - 0s - loss: 1.6575e-04 - val_loss: 4.7237e-05 - 77ms/epoch - 3ms/step
# Epoch 28/100
# 26/26 - 0s - loss: 1.6457e-04 - val_loss: 4.2184e-05 - 77ms/epoch - 3ms/step
# Epoch 29/100
# 26/26 - 0s - loss: 1.6516e-04 - val_loss: 4.9735e-05 - 77ms/epoch - 3ms/step
# Epoch 30/100
# 26/26 - 0s - loss: 1.6540e-04 - val_loss: 3.8822e-05 - 78ms/epoch - 3ms/step
# Epoch 31/100
# 26/26 - 0s - loss: 1.6500e-04 - val_loss: 6.8734e-05 - 78ms/epoch - 3ms/step
# Epoch 32/100
# 26/26 - 0s - loss: 1.7146e-04 - val_loss: 4.1846e-05 - 106ms/epoch - 4ms/step
# Epoch 33/100
# 26/26 - 0s - loss: 1.6830e-04 - val_loss: 4.3455e-05 - 92ms/epoch - 4ms/step
# Epoch 34/100
# 26/26 - 0s - loss: 1.6611e-04 - val_loss: 4.7947e-05 - 78ms/epoch - 3ms/step
# Epoch 35/100
# 26/26 - 0s - loss: 1.6713e-04 - val_loss: 5.2996e-05 - 78ms/epoch - 3ms/step
# Epoch 36/100
# 26/26 - 0s - loss: 1.6671e-04 - val_loss: 3.8611e-05 - 78ms/epoch - 3ms/step
# Epoch 37/100
# 26/26 - 0s - loss: 1.7344e-04 - val_loss: 3.9015e-05 - 76ms/epoch - 3ms/step
# Epoch 38/100
# 26/26 - 0s - loss: 1.6766e-04 - val_loss: 4.8346e-05 - 79ms/epoch - 3ms/step
# Epoch 39/100
# 26/26 - 0s - loss: 1.6695e-04 - val_loss: 4.4368e-05 - 77ms/epoch - 3ms/step
# Epoch 40/100
# 26/26 - 0s - loss: 1.6755e-04 - val_loss: 4.1563e-05 - 78ms/epoch - 3ms/step
# Epoch 41/100
# 26/26 - 0s - loss: 1.6894e-04 - val_loss: 8.5209e-05 - 77ms/epoch - 3ms/step
# Epoch 42/100
# 26/26 - 0s - loss: 1.7101e-04 - val_loss: 5.4320e-05 - 76ms/epoch - 3ms/step
# Epoch 43/100
# 26/26 - 0s - loss: 1.6866e-04 - val_loss: 4.3923e-05 - 76ms/epoch - 3ms/step
# Epoch 44/100
# 26/26 - 0s - loss: 1.7168e-04 - val_loss: 3.8502e-05 - 78ms/epoch - 3ms/step
# Epoch 45/100
# 26/26 - 0s - loss: 1.8099e-04 - val_loss: 3.9451e-05 - 87ms/epoch - 3ms/step
# Epoch 46/100
# 26/26 - 0s - loss: 1.6818e-04 - val_loss: 7.8300e-05 - 104ms/epoch - 4ms/step
# Epoch 47/100
# 26/26 - 0s - loss: 1.6798e-04 - val_loss: 4.1342e-05 - 77ms/epoch - 3ms/step
# Epoch 48/100
# 26/26 - 0s - loss: 1.6748e-04 - val_loss: 9.8822e-05 - 78ms/epoch - 3ms/step
# Epoch 49/100
# 26/26 - 0s - loss: 1.8222e-04 - val_loss: 5.8401e-05 - 76ms/epoch - 3ms/step
# Epoch 50/100
# 26/26 - 0s - loss: 1.6938e-04 - val_loss: 7.0063e-05 - 77ms/epoch - 3ms/step
# Epoch 51/100
# 26/26 - 0s - loss: 1.6924e-04 - val_loss: 5.0746e-05 - 77ms/epoch - 3ms/step
# Epoch 52/100
# 26/26 - 0s - loss: 1.6661e-04 - val_loss: 6.9547e-05 - 78ms/epoch - 3ms/step
# Epoch 53/100
# 26/26 - 0s - loss: 1.6637e-04 - val_loss: 4.7027e-05 - 76ms/epoch - 3ms/step
# Epoch 54/100
# 26/26 - 0s - loss: 1.6710e-04 - val_loss: 7.3180e-05 - 76ms/epoch - 3ms/step
# Epoch 55/100
# 26/26 - 0s - loss: 1.6880e-04 - val_loss: 6.7831e-05 - 78ms/epoch - 3ms/step
# Epoch 56/100
# 26/26 - 0s - loss: 1.6679e-04 - val_loss: 8.4381e-05 - 78ms/epoch - 3ms/step
# Epoch 57/100
# 26/26 - 0s - loss: 1.6849e-04 - val_loss: 4.2839e-05 - 76ms/epoch - 3ms/step
# Epoch 58/100
# 26/26 - 0s - loss: 1.6686e-04 - val_loss: 4.0112e-05 - 83ms/epoch - 3ms/step
# Epoch 59/100
# 26/26 - 0s - loss: 1.7080e-04 - val_loss: 3.9485e-05 - 77ms/epoch - 3ms/step
# Epoch 60/100
# 26/26 - 0s - loss: 1.6699e-04 - val_loss: 3.8571e-05 - 77ms/epoch - 3ms/step
# Epoch 61/100
# 26/26 - 0s - loss: 1.6705e-04 - val_loss: 3.8599e-05 - 76ms/epoch - 3ms/step
# Epoch 62/100
# 26/26 - 0s - loss: 1.7277e-04 - val_loss: 5.2232e-05 - 77ms/epoch - 3ms/step
# Epoch 63/100
# 26/26 - 0s - loss: 1.6625e-04 - val_loss: 5.1421e-05 - 76ms/epoch - 3ms/step
# Epoch 64/100
# 26/26 - 0s - loss: 1.6593e-04 - val_loss: 4.1320e-05 - 78ms/epoch - 3ms/step
# Epoch 65/100
# 26/26 - 0s - loss: 1.6721e-04 - val_loss: 7.1581e-05 - 80ms/epoch - 3ms/step
# Epoch 66/100
# 26/26 - 0s - loss: 1.7222e-04 - val_loss: 3.9866e-05 - 78ms/epoch - 3ms/step
# Epoch 67/100
# 26/26 - 0s - loss: 1.6965e-04 - val_loss: 3.8603e-05 - 77ms/epoch - 3ms/step
# Epoch 68/100
# 26/26 - 0s - loss: 1.7416e-04 - val_loss: 6.9753e-05 - 78ms/epoch - 3ms/step
# Epoch 69/100
# 26/26 - 0s - loss: 1.7877e-04 - val_loss: 4.4890e-05 - 78ms/epoch - 3ms/step
# Epoch 70/100
# 26/26 - 0s - loss: 1.6490e-04 - val_loss: 4.1194e-05 - 77ms/epoch - 3ms/step
# Epoch 71/100
# 26/26 - 0s - loss: 1.6640e-04 - val_loss: 5.4895e-05 - 111ms/epoch - 4ms/step
# Epoch 72/100
# 26/26 - 0s - loss: 1.7335e-04 - val_loss: 6.6672e-05 - 84ms/epoch - 3ms/step
# Epoch 73/100
# 26/26 - 0s - loss: 1.7903e-04 - val_loss: 7.0324e-05 - 76ms/epoch - 3ms/step
# Epoch 74/100
# 26/26 - 0s - loss: 1.7076e-04 - val_loss: 4.0419e-05 - 77ms/epoch - 3ms/step
# Epoch 75/100
# 26/26 - 0s - loss: 1.6503e-04 - val_loss: 5.6056e-05 - 74ms/epoch - 3ms/step
# Epoch 76/100
# 26/26 - 0s - loss: 1.7023e-04 - val_loss: 5.0577e-05 - 77ms/epoch - 3ms/step
# Epoch 77/100
# 26/26 - 0s - loss: 1.6677e-04 - val_loss: 5.1434e-05 - 76ms/epoch - 3ms/step
# Epoch 78/100
# 26/26 - 0s - loss: 1.6895e-04 - val_loss: 4.2199e-05 - 78ms/epoch - 3ms/step
# Epoch 79/100
# 26/26 - 0s - loss: 1.7408e-04 - val_loss: 4.2694e-05 - 77ms/epoch - 3ms/step
# Epoch 80/100
# 26/26 - 0s - loss: 1.6749e-04 - val_loss: 4.4613e-05 - 78ms/epoch - 3ms/step
# Epoch 81/100
# 26/26 - 0s - loss: 1.7329e-04 - val_loss: 4.2193e-05 - 76ms/epoch - 3ms/step
# Epoch 82/100
# 26/26 - 0s - loss: 1.9348e-04 - val_loss: 8.1482e-05 - 78ms/epoch - 3ms/step
# Epoch 83/100
# 26/26 - 0s - loss: 1.7369e-04 - val_loss: 4.5276e-05 - 77ms/epoch - 3ms/step
# Epoch 84/100
# 26/26 - 0s - loss: 1.8248e-04 - val_loss: 3.8791e-05 - 78ms/epoch - 3ms/step
# Epoch 85/100
# 26/26 - 0s - loss: 1.7125e-04 - val_loss: 6.5314e-05 - 78ms/epoch - 3ms/step
# Epoch 86/100
# 26/26 - 0s - loss: 1.7337e-04 - val_loss: 4.3461e-05 - 77ms/epoch - 3ms/step
# Epoch 87/100
# 26/26 - 0s - loss: 1.9591e-04 - val_loss: 4.2275e-05 - 78ms/epoch - 3ms/step
# Epoch 88/100
# 26/26 - 0s - loss: 1.8282e-04 - val_loss: 8.3554e-05 - 78ms/epoch - 3ms/step
# Epoch 89/100
# 26/26 - 0s - loss: 1.6875e-04 - val_loss: 8.8099e-05 - 75ms/epoch - 3ms/step
# Epoch 90/100
# 26/26 - 0s - loss: 1.7818e-04 - val_loss: 3.9337e-05 - 75ms/epoch - 3ms/step
# Epoch 91/100
# 26/26 - 0s - loss: 1.8765e-04 - val_loss: 4.5057e-05 - 76ms/epoch - 3ms/step
# Epoch 92/100
# 26/26 - 0s - loss: 1.7678e-04 - val_loss: 8.5577e-05 - 77ms/epoch - 3ms/step
# Epoch 93/100
# 26/26 - 0s - loss: 1.7618e-04 - val_loss: 4.1759e-05 - 76ms/epoch - 3ms/step
# Epoch 94/100
# 26/26 - 0s - loss: 1.6706e-04 - val_loss: 4.3476e-05 - 103ms/epoch - 4ms/step
# Epoch 95/100
# 26/26 - 0s - loss: 1.7464e-04 - val_loss: 5.7121e-05 - 107ms/epoch - 4ms/step
# Epoch 96/100
# 26/26 - 0s - loss: 1.6655e-04 - val_loss: 6.0945e-05 - 99ms/epoch - 4ms/step
# Epoch 97/100
# 26/26 - 0s - loss: 1.7335e-04 - val_loss: 4.7810e-05 - 77ms/epoch - 3ms/step
# Epoch 98/100
# 26/26 - 0s - loss: 1.9038e-04 - val_loss: 9.1202e-05 - 75ms/epoch - 3ms/step
# Epoch 99/100
# 26/26 - 0s - loss: 1.8144e-04 - val_loss: 3.8486e-05 - 77ms/epoch - 3ms/step
# Epoch 100/100
# 26/26 - 0s - loss: 1.7024e-04 - val_loss: 5.3911e-05 - 80ms/epoch - 3ms/step

# %%
import matplotlib.pyplot as plt

def plot_predictions(model, X, y):
    predictions = model.predict(X)
    fig, ax = plt.subplots()
    plt.plot(predictions, color = 'red')
    plt.plot(y, color = 'blue')
    plt.legend(['predicted','actual'])
    plt.show()
    return

# %%
plot_predictions(model, X, y)
# Out:
# 26/26 [==============================] - 0s 985us/step

# %%
plot_predictions(model2, X, y)
# Out:
# 26/26 [==============================] - 0s 1ms/step

# %%
plot_predictions(model3, X, y)
# Out:
# 26/26 [==============================] - 0s 985us/step

# %% [markdown]
# ### Adding scaling

# %%
def np_to_X_y(array, window_size=5):
    X=[]
    y=[]
    for i in range(len(array)-window_size):
        row = [r for r in array[i:i+window_size]]
        X.append(row)
        label = array[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

scaler = MinMaxScaler(feature_range=(0,1))

train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

window_size = 5
X_scaled, y_scaled = np_to_X_y(train_scaled, window_size)
valX_scaled, valy_scaled = np_to_X_y(test_scaled, window_size)

# %%
model4 = Sequential()
model4.add(LSTM(64, input_shape=(5,8)))
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))
model4.compile(loss='mse', optimizer='adam')

# %%
history = model4.fit(X_scaled, y_scaled, epochs=50, validation_data=(valX_scaled, valy_scaled), verbose=2)
# Out:
# Epoch 1/50
# 26/26 - 1s - loss: 0.0190 - val_loss: 0.0080 - 1s/epoch - 51ms/step
# Epoch 2/50
# 26/26 - 0s - loss: 0.0123 - val_loss: 0.0153 - 78ms/epoch - 3ms/step
# Epoch 3/50
# 26/26 - 0s - loss: 0.0114 - val_loss: 0.0121 - 76ms/epoch - 3ms/step
# Epoch 4/50
# 26/26 - 0s - loss: 0.0111 - val_loss: 0.0083 - 77ms/epoch - 3ms/step
# Epoch 5/50
# 26/26 - 0s - loss: 0.0106 - val_loss: 0.0075 - 77ms/epoch - 3ms/step
# Epoch 6/50
# 26/26 - 0s - loss: 0.0105 - val_loss: 0.0061 - 79ms/epoch - 3ms/step
# Epoch 7/50
# 26/26 - 0s - loss: 0.0105 - val_loss: 0.0068 - 78ms/epoch - 3ms/step
# Epoch 8/50
# 26/26 - 0s - loss: 0.0102 - val_loss: 0.0090 - 78ms/epoch - 3ms/step
# Epoch 9/50
# 26/26 - 0s - loss: 0.0101 - val_loss: 0.0065 - 76ms/epoch - 3ms/step
# Epoch 10/50
# 26/26 - 0s - loss: 0.0100 - val_loss: 0.0062 - 74ms/epoch - 3ms/step
# Epoch 11/50
# 26/26 - 0s - loss: 0.0100 - val_loss: 0.0076 - 81ms/epoch - 3ms/step
# Epoch 12/50
# 26/26 - 0s - loss: 0.0097 - val_loss: 0.0073 - 80ms/epoch - 3ms/step
# Epoch 13/50
# 26/26 - 0s - loss: 0.0099 - val_loss: 0.0042 - 76ms/epoch - 3ms/step
# Epoch 14/50
# 26/26 - 0s - loss: 0.0098 - val_loss: 0.0070 - 78ms/epoch - 3ms/step
# Epoch 15/50
# 26/26 - 0s - loss: 0.0096 - val_loss: 0.0049 - 77ms/epoch - 3ms/step
# Epoch 16/50
# 26/26 - 0s - loss: 0.0096 - val_loss: 0.0052 - 78ms/epoch - 3ms/step
# Epoch 17/50
# 26/26 - 0s - loss: 0.0093 - val_loss: 0.0042 - 78ms/epoch - 3ms/step
# Epoch 18/50
# 26/26 - 0s - loss: 0.0092 - val_loss: 0.0040 - 76ms/epoch - 3ms/step
# Epoch 19/50
# 26/26 - 0s - loss: 0.0092 - val_loss: 0.0046 - 81ms/epoch - 3ms/step
# Epoch 20/50
# 26/26 - 0s - loss: 0.0092 - val_loss: 0.0061 - 78ms/epoch - 3ms/step
# Epoch 21/50
# 26/26 - 0s - loss: 0.0095 - val_loss: 0.0072 - 79ms/epoch - 3ms/step
# Epoch 22/50
# 26/26 - 0s - loss: 0.0091 - val_loss: 0.0047 - 84ms/epoch - 3ms/step
# Epoch 23/50
# 26/26 - 0s - loss: 0.0092 - val_loss: 0.0039 - 102ms/epoch - 4ms/step
# Epoch 24/50
# 26/26 - 0s - loss: 0.0092 - val_loss: 0.0056 - 78ms/epoch - 3ms/step
# Epoch 25/50
# 26/26 - 0s - loss: 0.0091 - val_loss: 0.0038 - 78ms/epoch - 3ms/step
# Epoch 26/50
# 26/26 - 0s - loss: 0.0093 - val_loss: 0.0046 - 78ms/epoch - 3ms/step
# Epoch 27/50
# 26/26 - 0s - loss: 0.0093 - val_loss: 0.0062 - 76ms/epoch - 3ms/step
# Epoch 28/50
# 26/26 - 0s - loss: 0.0090 - val_loss: 0.0044 - 75ms/epoch - 3ms/step
# Epoch 29/50
# 26/26 - 0s - loss: 0.0090 - val_loss: 0.0041 - 79ms/epoch - 3ms/step
# Epoch 30/50
# 26/26 - 0s - loss: 0.0089 - val_loss: 0.0046 - 78ms/epoch - 3ms/step
# Epoch 31/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0038 - 79ms/epoch - 3ms/step
# Epoch 32/50
# 26/26 - 0s - loss: 0.0091 - val_loss: 0.0101 - 79ms/epoch - 3ms/step
# Epoch 33/50
# 26/26 - 0s - loss: 0.0091 - val_loss: 0.0041 - 79ms/epoch - 3ms/step
# Epoch 34/50
# 26/26 - 0s - loss: 0.0089 - val_loss: 0.0040 - 77ms/epoch - 3ms/step
# Epoch 35/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0041 - 77ms/epoch - 3ms/step
# Epoch 36/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0050 - 80ms/epoch - 3ms/step
# Epoch 37/50
# 26/26 - 0s - loss: 0.0089 - val_loss: 0.0064 - 78ms/epoch - 3ms/step
# Epoch 38/50
# 26/26 - 0s - loss: 0.0089 - val_loss: 0.0039 - 77ms/epoch - 3ms/step
# Epoch 39/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0044 - 76ms/epoch - 3ms/step
# Epoch 40/50
# 26/26 - 0s - loss: 0.0087 - val_loss: 0.0059 - 77ms/epoch - 3ms/step
# Epoch 41/50
# 26/26 - 0s - loss: 0.0087 - val_loss: 0.0043 - 77ms/epoch - 3ms/step
# Epoch 42/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0044 - 77ms/epoch - 3ms/step
# Epoch 43/50
# 26/26 - 0s - loss: 0.0090 - val_loss: 0.0042 - 77ms/epoch - 3ms/step
# Epoch 44/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0040 - 77ms/epoch - 3ms/step
# Epoch 45/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0057 - 75ms/epoch - 3ms/step
# Epoch 46/50
# 26/26 - 0s - loss: 0.0087 - val_loss: 0.0039 - 80ms/epoch - 3ms/step
# Epoch 47/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0037 - 77ms/epoch - 3ms/step
# Epoch 48/50
# 26/26 - 0s - loss: 0.0089 - val_loss: 0.0051 - 77ms/epoch - 3ms/step
# Epoch 49/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0038 - 77ms/epoch - 3ms/step
# Epoch 50/50
# 26/26 - 0s - loss: 0.0088 - val_loss: 0.0039 - 86ms/epoch - 3ms/step

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Ozone LSTM Loss Curve")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','test'])
plot_predictions(model4, X_scaled, y_scaled)
# Out:
# 26/26 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import mean_squared_error
#unscaling output
yhat = model4.predict(X_scaled)
for i in range(5):
    yhat = np.insert(yhat, 0, np.nan)
train_copy = train
train_copy.head()
train_copy['output'] = yhat
train_copy.drop('value', axis = 1, inplace = True)
train_copy = train_copy[['output','stp','wind_speed','max_sustained_wind','max_temp','min_temp','temperature','dewpoint']]
train_copy.head()
# Out:
# 26/26 [==============================] - 0s 965us/step
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_228952\2283424937.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_copy['output'] = yhat
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_228952\2283424937.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_copy.drop('value', axis = 1, inplace = True)
#             output    stp  wind_speed  max_sustained_wind  max_temp  min_temp  \
# utc
# 2020-01-02     NaN  986.8         4.5                12.0      68.0      43.0
# 2020-01-03     NaN  994.0         1.6                 6.0      73.0      45.0
# 2020-01-04     NaN  999.1         1.1                 6.0      73.0      42.1
# 2020-01-05     NaN  998.0         2.8                11.1      73.0      42.1
# 2020-01-06     NaN  997.6         2.5                 6.0      75.0      42.1
#
#             temperature  dewpoint
# utc
# 2020-01-02         56.6      42.1
# 2020-01-03         56.7      39.3
# 2020-01-04         55.5      38.4
# 2020-01-05         54.7      36.3
# 2020-01-06         57.6      29.1

# %%
extracted_output = train_copy.to_numpy()
extracted_output = scaler.inverse_transform(extracted_output[5:])
extracted_output = [i[0] for i in extracted_output]

# %%
print(f'Mean squared error is {mean_squared_error(extracted_output, y)}')
# Out:
# Mean squared error is 7.114669773171984e-05

# %%
fig, ax = plt.subplots()
plt.title("Scaled LSTM Model of Ozone Performance on Train Set") 
plt.plot(extracted_output, color = 'red')
plt.plot(y, color = 'blue')
plt.legend(['predicted','actual'])
plt.show()

# %%
sum(y)/len(y)
# Out:
# 0.030997372471550374

# %%
#unscaling output
yhat = model4.predict(valX_scaled)
for i in range(5):
    yhat = np.insert(yhat, 0, np.nan)
test_copy = test
test_copy['output'] = yhat
test_copy.drop('value', axis = 1, inplace = True)
test_copy = test_copy[['output','stp','wind_speed','max_sustained_wind','max_temp','min_temp','temperature','dewpoint']]

extracted_output = test_copy.to_numpy()
extracted_output = scaler.inverse_transform(extracted_output[5:])
extracted_output = [i[0] for i in extracted_output]

print(f'Mean squared error is {mean_squared_error(extracted_output, valy)}')
fig, ax = plt.subplots()
plt.plot(extracted_output, color = 'red')
plt.plot(valy, color = 'blue')
plt.legend(['predicted','actual'])
plt.show()
# Out:
# 7/7 [==============================] - 0s 1ms/step
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_228952\682039158.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_copy['output'] = yhat
# Mean squared error is 3.1146855888527447e-05
# C:\Users\Matthew\AppData\Local\Temp\ipykernel_228952\682039158.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_copy.drop('value', axis = 1, inplace = True)

# %%
fig, ax = plt.subplots()
plt.title("Scaled Ozone Model of 2.5 Performance on Validation Set")
plt.plot(extracted_output, color = 'red')
plt.plot(valy, color = 'blue')
plt.legend(['predicted','actual'])
plt.show()

# %%
# Out:
# -1.4830399374223875
