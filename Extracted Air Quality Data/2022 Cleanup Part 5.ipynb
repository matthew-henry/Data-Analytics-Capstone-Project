# %%
import pandas as pd
import json as json
import ujson as ujson
df = pd.read_csv('2022 AQ Clean.csv')

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
# ...

# %%
df.drop(['attribution','averagingperiod'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#   country sourcename  sourcetype  mobile  \
# 0      US     AirNow  government   False
# 1      US     AirNow  government   False
# 2      US     AirNow  government   False
# 3      US     AirNow  government   False
# 4      US     AirNow  government   False
#
#                                   cleanedattribution  ...  longitude  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...  ...   -86.5917
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...  ...   -86.5917
# ...

# %%
df.drop('cleanedattribution', axis=1, inplace=True)

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#   country sourcename  sourcetype  mobile           cleanedaveragingperiod  \
# 0      US     AirNow  government   False  {"unit":"hours"," value":"1.0"}
# 1      US     AirNow  government   False  {"unit":"hours"," value":"1.0"}
# 2      US     AirNow  government   False  {"unit":"hours"," value":"1.0"}
# 3      US     AirNow  government   False  {"unit":"hours"," value":"1.0"}
# 4      US     AirNow  government   False  {"unit":"hours"," value":"1.0"}
#
#    ...   longitude                       utc                      local  \
# ...

# %%
df.drop('cleanedaveragingperiod', axis=1, inplace=True)

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#   country sourcename  sourcetype  mobile  latitude   longitude  \
# 0      US     AirNow  government   False   34.6917    -86.5917
# 1      US     AirNow  government   False   34.6917    -86.5917
# 2      US     AirNow  government   False   33.6292   -111.6769
# 3      US     AirNow  government   False   32.9783   -115.5383
# 4      US     AirNow  government   False   32.9783   -115.5383
#
#                         utc                      local         [{name   url  \
# ...

# %%
#df.columns.values[3]='concentration unit'

# %%
#df.head()

# %%
df.drop(df.columns[15], axis=1, inplace=True)

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#   country sourcename  sourcetype  mobile  latitude   longitude  \
# 0      US     AirNow  government   False   34.6917    -86.5917
# 1      US     AirNow  government   False   34.6917    -86.5917
# 2      US     AirNow  government   False   33.6292   -111.6769
# 3      US     AirNow  government   False   32.9783   -115.5383
# 4      US     AirNow  government   False   32.9783   -115.5383
#
#                         utc                      local         [{name   url  \
# ...

# %%
#df.columns

# %%
#backup = df

# %%
#df.columns.values[13]='source'

# %%
#df.head()

# %%
#df.columns.values[3]='c_unit'

# %%
#df.head()

# %%
#df['c_unit']

# %%
df.drop(df.columns[15], axis=1, inplace=True)

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#   country sourcename  sourcetype  mobile  latitude   longitude  \
# 0      US     AirNow  government   False   34.6917    -86.5917
# 1      US     AirNow  government   False   34.6917    -86.5917
# 2      US     AirNow  government   False   33.6292   -111.6769
# 3      US     AirNow  government   False   32.9783   -115.5383
# 4      US     AirNow  government   False   32.9783   -115.5383
#
#                         utc                      local         [{name   url  \
# ...

# %%
df.drop(df.columns[15], axis=1, inplace=True)

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#   country sourcename  sourcetype  mobile  latitude   longitude  \
# 0      US     AirNow  government   False   34.6917    -86.5917
# 1      US     AirNow  government   False   34.6917    -86.5917
# 2      US     AirNow  government   False   33.6292   -111.6769
# 3      US     AirNow  government   False   32.9783   -115.5383
# 4      US     AirNow  government   False   32.9783   -115.5383
#
#                         utc                      local         [{name   url  \
# ...

# %%
df.columns.values[13] = 'source'

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#   country sourcename  sourcetype  mobile  latitude   longitude  \
# 0      US     AirNow  government   False   34.6917    -86.5917
# 1      US     AirNow  government   False   34.6917    -86.5917
# 2      US     AirNow  government   False   33.6292   -111.6769
# 3      US     AirNow  government   False   32.9783   -115.5383
# 4      US     AirNow  government   False   32.9783   -115.5383
#
#                         utc                      local         source   url  \
# ...

# %%
df_backup = df

# %%
df.columns.values[15] = 'averaging time unit'

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#   country sourcename  sourcetype  mobile  latitude   longitude  \
# 0      US     AirNow  government   False   34.6917    -86.5917
# 1      US     AirNow  government   False   34.6917    -86.5917
# 2      US     AirNow  government   False   33.6292   -111.6769
# 3      US     AirNow  government   False   32.9783   -115.5383
# 4      US     AirNow  government   False   32.9783   -115.5383
#
#                         utc                      local         source   url  \
# ...

# %%
df.columns.values[16] = 'averaging time'

# %%
df.head()
# Out:
#   parameter              location  value   unit                     city  \
# 0        o3  Huntsville Old Airpo   0.04    ppm               Huntsville
# 1      pm25  Huntsville Old Airpo  10.50  µg/m³               Huntsville
# 2      pm10  Ft McD Yuma Frank-AZ  13.00  µg/m³  Phoenix-Mesa-Scottsdale
# 3      pm10  Brawley - 220 Main S  26.00  µg/m³                El Centro
# 4      pm25  Brawley - 220 Main S   4.80  µg/m³                El Centro
#
#   country sourcename  sourcetype  mobile  latitude   longitude  \
# 0      US     AirNow  government   False   34.6917    -86.5917
# 1      US     AirNow  government   False   34.6917    -86.5917
# 2      US     AirNow  government   False   33.6292   -111.6769
# 3      US     AirNow  government   False   32.9783   -115.5383
# 4      US     AirNow  government   False   32.9783   -115.5383
#
#                         utc                      local         source   url  \
# ...

# %%
df.columns.values[3] = 'concentration units'

# %%
df.head()
# Out:
#   parameter              location  value concentration units  \
# 0        o3  Huntsville Old Airpo   0.04                 ppm
# 1      pm25  Huntsville Old Airpo  10.50               µg/m³
# 2      pm10  Ft McD Yuma Frank-AZ  13.00               µg/m³
# 3      pm10  Brawley - 220 Main S  26.00               µg/m³
# 4      pm25  Brawley - 220 Main S   4.80               µg/m³
#
#                       city country sourcename  sourcetype  mobile  latitude  \
# 0               Huntsville      US     AirNow  government   False   34.6917
# 1               Huntsville      US     AirNow  government   False   34.6917
# 2  Phoenix-Mesa-Scottsdale      US     AirNow  government   False   33.6292
# 3                El Centro      US     AirNow  government   False   32.9783
# 4                El Centro      US     AirNow  government   False   32.9783
#
#     longitude                       utc                      local  \
# 0    -86.5917  2022-04-24T03:00:00.000Z  2022-04-23T21:00:00-06:00
# ...

# %%
df.to_csv('2022 AQ Clean.csv', index=False)
