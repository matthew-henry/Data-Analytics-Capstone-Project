# %% [markdown]
# # Cleanup and Exploration of 2017 AQ Data

# %%
import pandas as pd
import json as json

# %%
df = pd.read_csv('2017 AQ.csv')

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 1  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 2  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 3  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 4  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
#
#                location   value   unit    city  \
# 0  Fresno - Drummond St   0.063    ppm  Fresno
# 1                 Huron  21.000  µg/m³  FRESNO
# 2          Tranquillity   0.060    ppm  FRESNO
# 3          Tranquillity  21.000  µg/m³  FRESNO
# 4               Parlier   0.072    ppm  Fresno
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                                coordinates country sourcename  sourcetype  \
# 0  {latitude=36.7056, longitude=-119.7414}      US     AirNow  government
# 1  {latitude=36.1994, longitude=-120.0991}      US     AirNow  government
# 2  {latitude=36.6324, longitude=-120.3822}      US     AirNow  government
# 3  {latitude=36.6324, longitude=-120.3822}      US     AirNow  government
# 4  {latitude=36.5975, longitude=-119.5036}      US     AirNow  government
#
#    mobile
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False

# %% [markdown]
# The entry is not valid json.  The field will need processing code.

# %%
def validate_json_fields(field: str) -> bool:
    """This function validates a JSON entry is valid.  Returns True if so, False if otherwise."""
    try:
        json.loads(field)
        return True
    except ValueError:
        return False

# %%
def validate_json_column(series: pd.Series):
    temp_df = pd.DataFrame()
    temp_df['values'] = series
    temp_df['validity'] = series.apply(validate_json_fields)
    return temp_df

# %% [markdown]
# ## Validation of composite fields as json

# %%
output = validate_json_column(df['date'])

# %%
output.head()
# Out:
#                                               values  validity
# 0  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...     False
# 1  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...     False
# 2  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...     False
# 3  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...     False
# 4  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['attribution'])
output.head()
# Out:
#                                               values  validity
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...     False
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...     False
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...     False
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...     False
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['averagingperiod'])
output.head()
# Out:
#                     values  validity
# 0  {unit=hours, value=1.0}     False
# 1  {unit=hours, value=1.0}     False
# 2  {unit=hours, value=1.0}     False
# 3  {unit=hours, value=1.0}     False
# 4  {unit=hours, value=1.0}     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['coordinates'])
output.head()
# Out:
#                                     values  validity
# 0  {latitude=36.7056, longitude=-119.7414}     False
# 1  {latitude=36.1994, longitude=-120.0991}     False
# 2  {latitude=36.6324, longitude=-120.3822}     False
# 3  {latitude=36.6324, longitude=-120.3822}     False
# 4  {latitude=36.5975, longitude=-119.5036}     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %% [markdown]
# All of the composite fields are in a "JSON-like format"  need to convert to JSON.

# %% [markdown]
# ## Reprocessing the Multivalue Fields into Valid JSON

# %%
def correct_field_to_json(arg: str) -> str:
    string = arg.lstrip("{{")
    string = string.rstrip("]}")
    strings = string.split(",")
    new_strings = []
    for entry in strings:
        index = entry.find('=')
        entry = '"' + entry[0:index] + '"' + ':' + '"'+ entry[index+1:len(entry)]+'"'
        new_strings.append(entry)
    output_string = (',').join(entry for entry in new_strings)
    output_string = '{' + output_string + '}'
    return output_string

# %%
def correct_json_column(series: pd.Series, column_name: str) -> pd.DataFrame:
    temp_df = pd.DataFrame()
    temp_df[column_name] = series.apply(correct_field_to_json)
    return temp_df

# %%
test = correct_json_column(df['date'], 'test date conversion')
results = validate_json_column(test['test date conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleaneddate'] = test

# %%
test = correct_json_column(df['attribution'], 'test attribute conversion')
results = validate_json_column(test['test attribute conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
results.head()
# Out:
#                                               values  validity
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...      True
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...      True
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...      True
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...      True
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...      True

# %%
df['cleanedattribution'] = test

# %%
test = correct_json_column(df['averagingperiod'], 'test averaging period conversion')
results = validate_json_column(test['test averaging period conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleanedaveragingperiod'] = test

# %%
test = correct_json_column(df['coordinates'], 'test coordinate conversion')
results = validate_json_column(test['test coordinate conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleanedcoordinates'] = test

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 1  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 2  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 3  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 4  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
#
#                location   value   unit    city  \
# 0  Fresno - Drummond St   0.063    ppm  Fresno
# 1                 Huron  21.000  µg/m³  FRESNO
# 2          Tranquillity   0.060    ppm  FRESNO
# 3          Tranquillity  21.000  µg/m³  FRESNO
# 4               Parlier   0.072    ppm  Fresno
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                                coordinates country sourcename  sourcetype  \
# 0  {latitude=36.7056, longitude=-119.7414}      US     AirNow  government
# 1  {latitude=36.1994, longitude=-120.0991}      US     AirNow  government
# 2  {latitude=36.6324, longitude=-120.3822}      US     AirNow  government
# 3  {latitude=36.6324, longitude=-120.3822}      US     AirNow  government
# 4  {latitude=36.5975, longitude=-119.5036}      US     AirNow  government
#
#    mobile                                        cleaneddate  \
# 0   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 1   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 2   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 3   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 4   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                 cleanedcoordinates
# 0  {"latitude":"36.7056"," longitude":"-119.7414"}
# 1  {"latitude":"36.1994"," longitude":"-120.0991"}
# 2  {"latitude":"36.6324"," longitude":"-120.3822"}
# 3  {"latitude":"36.6324"," longitude":"-120.3822"}
# 4  {"latitude":"36.5975"," longitude":"-119.5036"}

# %%
df_trans = df
import ujson as ujson

# %%
#df_trans = pd.concat([df_trans, df_trans.cleanedcoordinates.apply(json.loads).apply(pd.Series)], axis = 1)
expanded_datascope = df_trans['cleanedcoordinates'].apply(ujson.loads)
expanded_datascope = pd.json_normalize(expanded_datascope)
df_trans = pd.concat([df_trans, expanded_datascope], axis =1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 1  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 2  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 3  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 4  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
#
#                location   value   unit    city  \
# 0  Fresno - Drummond St   0.063    ppm  Fresno
# 1                 Huron  21.000  µg/m³  FRESNO
# 2          Tranquillity   0.060    ppm  FRESNO
# 3          Tranquillity  21.000  µg/m³  FRESNO
# 4               Parlier   0.072    ppm  Fresno
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                                coordinates country sourcename  sourcetype  \
# 0  {latitude=36.7056, longitude=-119.7414}      US     AirNow  government
# 1  {latitude=36.1994, longitude=-120.0991}      US     AirNow  government
# 2  {latitude=36.6324, longitude=-120.3822}      US     AirNow  government
# 3  {latitude=36.6324, longitude=-120.3822}      US     AirNow  government
# 4  {latitude=36.5975, longitude=-119.5036}      US     AirNow  government
#
#    mobile                                        cleaneddate  \
# 0   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 1   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 2   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 3   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 4   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                 cleanedcoordinates latitude  longitude
# 0  {"latitude":"36.7056"," longitude":"-119.7414"}  36.7056  -119.7414
# 1  {"latitude":"36.1994"," longitude":"-120.0991"}  36.1994  -120.0991
# 2  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 3  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 4  {"latitude":"36.5975"," longitude":"-119.5036"}  36.5975  -119.5036

# %%
#df_trans = pd.concat([df_trans, df_trans.cleaneddate.apply(ujson.loads).apply(pd.Series)], axis = 1)
expanded_datascope = df_trans['cleaneddate'].apply(ujson.loads)
expanded_datascope = pd.json_normalize(expanded_datascope)
df_trans = pd.concat([df_trans, expanded_datascope], axis =1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 1  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 2  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 3  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 4  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
#
#                location   value   unit    city  \
# 0  Fresno - Drummond St   0.063    ppm  Fresno
# 1                 Huron  21.000  µg/m³  FRESNO
# 2          Tranquillity   0.060    ppm  FRESNO
# 3          Tranquillity  21.000  µg/m³  FRESNO
# 4               Parlier   0.072    ppm  Fresno
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                                coordinates country  ...  sourcetype mobile  \
# 0  {latitude=36.7056, longitude=-119.7414}      US  ...  government  False
# 1  {latitude=36.1994, longitude=-120.0991}      US  ...  government  False
# 2  {latitude=36.6324, longitude=-120.3822}      US  ...  government  False
# 3  {latitude=36.6324, longitude=-120.3822}      US  ...  government  False
# 4  {latitude=36.5975, longitude=-119.5036}      US  ...  government  False
#
#                                          cleaneddate  \
# 0  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 1  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 2  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 3  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 4  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                 cleanedcoordinates latitude  longitude  \
# 0  {"latitude":"36.7056"," longitude":"-119.7414"}  36.7056  -119.7414
# 1  {"latitude":"36.1994"," longitude":"-120.0991"}  36.1994  -120.0991
# 2  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 3  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 4  {"latitude":"36.5975"," longitude":"-119.5036"}  36.5975  -119.5036
#
#                         utc                      local
# 0  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00
# 1  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00
# 2  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00
# 3  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00
# 4  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00
#
# [5 rows x 21 columns]

# %%
#df_trans = pd.concat([df_trans, df_trans.cleanedattribution.apply(json.loads).apply(pd.Series)], axis = 1) This line is EXTREMELY SLOW TRYING TO OPTIMIZE.
expanded_datascope = df_trans['cleanedattribution'].apply(ujson.loads)
expanded_datascope = pd.json_normalize(expanded_datascope)
df_trans = pd.concat([df_trans, expanded_datascope], axis =1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 1  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 2  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 3  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 4  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
#
#                location   value   unit    city  \
# 0  Fresno - Drummond St   0.063    ppm  Fresno
# 1                 Huron  21.000  µg/m³  FRESNO
# 2          Tranquillity   0.060    ppm  FRESNO
# 3          Tranquillity  21.000  µg/m³  FRESNO
# 4               Parlier   0.072    ppm  Fresno
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                                coordinates country  ...  \
# 0  {latitude=36.7056, longitude=-119.7414}      US  ...
# 1  {latitude=36.1994, longitude=-120.0991}      US  ...
# 2  {latitude=36.6324, longitude=-120.3822}      US  ...
# 3  {latitude=36.6324, longitude=-120.3822}      US  ...
# 4  {latitude=36.5975, longitude=-119.5036}      US  ...
#
#                                   cleanedattribution  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                 cleanedcoordinates latitude  longitude  \
# 0  {"latitude":"36.7056"," longitude":"-119.7414"}  36.7056  -119.7414
# 1  {"latitude":"36.1994"," longitude":"-120.0991"}  36.1994  -120.0991
# 2  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 3  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 4  {"latitude":"36.5975"," longitude":"-119.5036"}  36.5975  -119.5036
#
#                         utc                      local         [{name   url  \
# 0  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 1  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 2  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 3  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 4  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
#
#                              {name
# 0  San Joaquin Valley Unified APCD
# 1  San Joaquin Valley Unified APCD
# 2  San Joaquin Valley Unified APCD
# 3  San Joaquin Valley Unified APCD
# 4  San Joaquin Valley Unified APCD
#
# [5 rows x 24 columns]

# %%
df_trans.drop(' {name', axis=1, inplace=True)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 1  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 2  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 3  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 4  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
#
#                location   value   unit    city  \
# 0  Fresno - Drummond St   0.063    ppm  Fresno
# 1                 Huron  21.000  µg/m³  FRESNO
# 2          Tranquillity   0.060    ppm  FRESNO
# 3          Tranquillity  21.000  µg/m³  FRESNO
# 4               Parlier   0.072    ppm  Fresno
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                                coordinates country  ...  \
# 0  {latitude=36.7056, longitude=-119.7414}      US  ...
# 1  {latitude=36.1994, longitude=-120.0991}      US  ...
# 2  {latitude=36.6324, longitude=-120.3822}      US  ...
# 3  {latitude=36.6324, longitude=-120.3822}      US  ...
# 4  {latitude=36.5975, longitude=-119.5036}      US  ...
#
#                                          cleaneddate  \
# 0  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 1  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 2  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 3  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 4  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                 cleanedcoordinates latitude  longitude  \
# 0  {"latitude":"36.7056"," longitude":"-119.7414"}  36.7056  -119.7414
# 1  {"latitude":"36.1994"," longitude":"-120.0991"}  36.1994  -120.0991
# 2  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 3  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 4  {"latitude":"36.5975"," longitude":"-119.5036"}  36.5975  -119.5036
#
#                         utc                      local         [{name   url
# 0  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 1  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 2  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 3  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 4  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
#
# [5 rows x 23 columns]

# %%
#df_trans = pd.concat([df_trans, df_trans.cleanedaveragingperiod.apply(json.loads).apply(pd.Series)], axis = 1)
expanded_datascope = df_trans['cleanedaveragingperiod'].apply(ujson.loads)
expanded_datascope = pd.json_normalize(expanded_datascope)
df_trans = pd.concat([df_trans, expanded_datascope], axis =1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 1  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 2  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
# 3  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...      pm25
# 4  {utc=2017-08-10T22:00:00.000Z, local=2017-08-1...        o3
#
#                location   value   unit    city  \
# 0  Fresno - Drummond St   0.063    ppm  Fresno
# 1                 Huron  21.000  µg/m³  FRESNO
# 2          Tranquillity   0.060    ppm  FRESNO
# 3          Tranquillity  21.000  µg/m³  FRESNO
# 4               Parlier   0.072    ppm  Fresno
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                                coordinates country  ...  \
# 0  {latitude=36.7056, longitude=-119.7414}      US  ...
# 1  {latitude=36.1994, longitude=-120.0991}      US  ...
# 2  {latitude=36.6324, longitude=-120.3822}      US  ...
# 3  {latitude=36.6324, longitude=-120.3822}      US  ...
# 4  {latitude=36.5975, longitude=-119.5036}      US  ...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                 cleanedcoordinates  latitude  longitude  \
# 0  {"latitude":"36.7056"," longitude":"-119.7414"}   36.7056  -119.7414
# 1  {"latitude":"36.1994"," longitude":"-120.0991"}   36.1994  -120.0991
# 2  {"latitude":"36.6324"," longitude":"-120.3822"}   36.6324  -120.3822
# 3  {"latitude":"36.6324"," longitude":"-120.3822"}   36.6324  -120.3822
# 4  {"latitude":"36.5975"," longitude":"-119.5036"}   36.5975  -119.5036
#
#                         utc                      local         [{name   url  \
# 0  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 1  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 2  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 3  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 4  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
#
#     unit  value
# 0  hours    1.0
# 1  hours    1.0
# 2  hours    1.0
# 3  hours    1.0
# 4  hours    1.0
#
# [5 rows x 25 columns]

# %%
df_trans.drop('date', axis =1, inplace=True)

# %%
df_trans.head()
# Out:
#   parameter              location   value   unit    city  \
# 0        o3  Fresno - Drummond St   0.063    ppm  Fresno
# 1      pm25                 Huron  21.000  µg/m³  FRESNO
# 2        o3          Tranquillity   0.060    ppm  FRESNO
# 3      pm25          Tranquillity  21.000  µg/m³  FRESNO
# 4        o3               Parlier   0.072    ppm  Fresno
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                                coordinates country sourcename  ...  \
# 0  {latitude=36.7056, longitude=-119.7414}      US     AirNow  ...
# 1  {latitude=36.1994, longitude=-120.0991}      US     AirNow  ...
# 2  {latitude=36.6324, longitude=-120.3822}      US     AirNow  ...
# 3  {latitude=36.6324, longitude=-120.3822}      US     AirNow  ...
# 4  {latitude=36.5975, longitude=-119.5036}      US     AirNow  ...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                 cleanedcoordinates latitude  longitude  \
# 0  {"latitude":"36.7056"," longitude":"-119.7414"}  36.7056  -119.7414
# 1  {"latitude":"36.1994"," longitude":"-120.0991"}  36.1994  -120.0991
# 2  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 3  {"latitude":"36.6324"," longitude":"-120.3822"}  36.6324  -120.3822
# 4  {"latitude":"36.5975"," longitude":"-119.5036"}  36.5975  -119.5036
#
#                         utc                      local         [{name   url  \
# 0  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 1  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 2  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 3  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 4  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
#
#     unit  value
# 0  hours    1.0
# 1  hours    1.0
# 2  hours    1.0
# 3  hours    1.0
# 4  hours    1.0
#
# [5 rows x 24 columns]

# %%
df_trans.drop(['attribution','averagingperiod','coordinates','cleanedaveragingperiod','cleanedcoordinates'], axis = 1, inplace = True)

# %%
df_trans.head()
# Out:
#   parameter              location   value   unit    city country sourcename  \
# 0        o3  Fresno - Drummond St   0.063    ppm  Fresno      US     AirNow
# 1      pm25                 Huron  21.000  µg/m³  FRESNO      US     AirNow
# 2        o3          Tranquillity   0.060    ppm  FRESNO      US     AirNow
# 3      pm25          Tranquillity  21.000  µg/m³  FRESNO      US     AirNow
# 4        o3               Parlier   0.072    ppm  Fresno      US     AirNow
#
#    sourcetype  mobile                                        cleaneddate  \
# 0  government   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 1  government   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 2  government   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 3  government   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
# 4  government   False  {"utc":"2017-08-10T22:00:00.000Z"," local":"20...
#
#                                   cleanedattribution latitude  longitude  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...  36.7056  -119.7414
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...  36.1994  -120.0991
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...  36.6324  -120.3822
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...  36.6324  -120.3822
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...  36.5975  -119.5036
#
#                         utc                      local         [{name   url  \
# 0  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 1  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 2  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 3  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 4  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
#
#     unit  value
# 0  hours    1.0
# 1  hours    1.0
# 2  hours    1.0
# 3  hours    1.0
# 4  hours    1.0

# %%
df_trans.drop(['cleaneddate','cleanedattribution'], axis = 1, inplace = True)

# %%
df_trans.head()
# Out:
#   parameter              location   value   unit    city country sourcename  \
# 0        o3  Fresno - Drummond St   0.063    ppm  Fresno      US     AirNow
# 1      pm25                 Huron  21.000  µg/m³  FRESNO      US     AirNow
# 2        o3          Tranquillity   0.060    ppm  FRESNO      US     AirNow
# 3      pm25          Tranquillity  21.000  µg/m³  FRESNO      US     AirNow
# 4        o3               Parlier   0.072    ppm  Fresno      US     AirNow
#
#    sourcetype  mobile latitude  longitude                       utc  \
# 0  government   False  36.7056  -119.7414  2017-08-10T22:00:00.000Z
# 1  government   False  36.1994  -120.0991  2017-08-10T22:00:00.000Z
# 2  government   False  36.6324  -120.3822  2017-08-10T22:00:00.000Z
# 3  government   False  36.6324  -120.3822  2017-08-10T22:00:00.000Z
# 4  government   False  36.5975  -119.5036  2017-08-10T22:00:00.000Z
#
#                        local         [{name   url   unit  value
# 0  2017-08-10T14:00:00-08:00  US EPA AirNow  null  hours    1.0
# 1  2017-08-10T14:00:00-08:00  US EPA AirNow  null  hours    1.0
# 2  2017-08-10T14:00:00-08:00  US EPA AirNow  null  hours    1.0
# 3  2017-08-10T14:00:00-08:00  US EPA AirNow  null  hours    1.0
# 4  2017-08-10T14:00:00-08:00  US EPA AirNow  null  hours    1.0

# %%
#df_trans.rename(columns={df_trans.columns[15]: 'averaging time unit'}, inplace=True)
df_trans.columns.values[3]='concentration unit'

# %%
df_trans.head()
# Out:
#   parameter              location   value concentration unit    city country  \
# 0        o3  Fresno - Drummond St   0.063                ppm  Fresno      US
# 1      pm25                 Huron  21.000              µg/m³  FRESNO      US
# 2        o3          Tranquillity   0.060                ppm  FRESNO      US
# 3      pm25          Tranquillity  21.000              µg/m³  FRESNO      US
# 4        o3               Parlier   0.072                ppm  Fresno      US
#
#   sourcename  sourcetype  mobile latitude  longitude  \
# 0     AirNow  government   False  36.7056  -119.7414
# 1     AirNow  government   False  36.1994  -120.0991
# 2     AirNow  government   False  36.6324  -120.3822
# 3     AirNow  government   False  36.6324  -120.3822
# 4     AirNow  government   False  36.5975  -119.5036
#
#                         utc                      local         [{name   url  \
# 0  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 1  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 2  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 3  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 4  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
#
#     unit  value
# 0  hours    1.0
# 1  hours    1.0
# 2  hours    1.0
# 3  hours    1.0
# 4  hours    1.0

# %%
#df_trans.rename(columns={df_trans.columns[15]: 'averaging time unit'}, inplace=True)
df_trans.columns.values[15] = 'averaging time unit'

# %%
#df_trans.rename(columns={df_trans.columns[13]: 'source'}, inplace=True)
df_trans.columns.values[13] = 'source'

# %%
df_trans.head()
# Out:
#   parameter              location   value concentration unit    city country  \
# 0        o3  Fresno - Drummond St   0.063                ppm  Fresno      US
# 1      pm25                 Huron  21.000              µg/m³  FRESNO      US
# 2        o3          Tranquillity   0.060                ppm  FRESNO      US
# 3      pm25          Tranquillity  21.000              µg/m³  FRESNO      US
# 4        o3               Parlier   0.072                ppm  Fresno      US
#
#   sourcename  sourcetype  mobile latitude  longitude  \
# 0     AirNow  government   False  36.7056  -119.7414
# 1     AirNow  government   False  36.1994  -120.0991
# 2     AirNow  government   False  36.6324  -120.3822
# 3     AirNow  government   False  36.6324  -120.3822
# 4     AirNow  government   False  36.5975  -119.5036
#
#                         utc                      local         source   url  \
# 0  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 1  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 2  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 3  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 4  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
#
#   averaging time unit  value
# 0               hours    1.0
# 1               hours    1.0
# 2               hours    1.0
# 3               hours    1.0
# 4               hours    1.0

# %%
#df_trans.rename(columns={df_trans.columns[16]: 'averaging time'},inplace=True)
df_trans.columns.values[16] = 'averaging time'

# %%
df_trans.head()
# Out:
#   parameter              location   value concentration unit    city country  \
# 0        o3  Fresno - Drummond St   0.063                ppm  Fresno      US
# 1      pm25                 Huron  21.000              µg/m³  FRESNO      US
# 2        o3          Tranquillity   0.060                ppm  FRESNO      US
# 3      pm25          Tranquillity  21.000              µg/m³  FRESNO      US
# 4        o3               Parlier   0.072                ppm  Fresno      US
#
#   sourcename  sourcetype  mobile latitude  longitude  \
# 0     AirNow  government   False  36.7056  -119.7414
# 1     AirNow  government   False  36.1994  -120.0991
# 2     AirNow  government   False  36.6324  -120.3822
# 3     AirNow  government   False  36.6324  -120.3822
# 4     AirNow  government   False  36.5975  -119.5036
#
#                         utc                      local         source   url  \
# 0  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 1  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 2  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 3  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
# 4  2017-08-10T22:00:00.000Z  2017-08-10T14:00:00-08:00  US EPA AirNow  null
#
#   averaging time unit averaging time
# 0               hours            1.0
# 1               hours            1.0
# 2               hours            1.0
# 3               hours            1.0
# 4               hours            1.0

# %%
df_trans.to_csv('2017 AQ Clean.csv', index=False)
