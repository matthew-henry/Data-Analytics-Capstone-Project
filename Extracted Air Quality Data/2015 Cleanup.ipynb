# %% [markdown]
# # Cleanup and Exploration of 2015 AQ Data

# %%
import pandas as pd
import json as json

# %%
df = pd.read_csv('2015 AQ.csv')

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2015-12-30T02:00:00.000Z, local=2015-12-2...       no2
# 1  {utc=2015-12-30T04:00:00.000Z, local=2015-12-2...        o3
# 2  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...        o3
# 3  {utc=2015-12-30T01:00:00.000Z, local=2015-12-2...       no2
# 4  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...       no2
#
#                        location   value unit     city  \
# 0          Houston East C1/G316  0.0118  ppm  Houston
# 1          Houston East C1/G316  0.0200  ppm  Houston
# 2          Houston East C1/G316  0.0180  ppm  Houston
# 3  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston
# 4          Houston East C1/G316  0.0137  ppm  Houston
#
#                                       attribution          averagingperiod  \
# 0  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 1  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 2  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 3  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 4  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
#
#                                  coordinates country sourcename  sourcetype  \
# 0  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
# 1  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
# 2  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
# 3  {latitude=29.901037, longitude=-95.32613}      US      Texas         NaN
# 4  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
#
#    mobile
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# The entry is not valid json.  The field will need processing code.

# %%
def validate_json_fields(field: str) -> bool:
    """This function validates a JSON entry is valid.  Returns True if so, False if otherwise."""
    try:
        json.loads(field)
        return True
    except ValueError:
        return False

# %%
def validate_json_column(series: pd.Series):
    temp_df = pd.DataFrame()
    temp_df['values'] = series
    temp_df['validity'] = series.apply(validate_json_fields)
    return temp_df

# %% [markdown]
# ## Validation of composite fields as json

# %%
output = validate_json_column(df['date'])

# %%
output.head()
# Out:
#                                               values  validity
# 0  {utc=2015-12-30T02:00:00.000Z, local=2015-12-2...     False
# 1  {utc=2015-12-30T04:00:00.000Z, local=2015-12-2...     False
# 2  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...     False
# 3  {utc=2015-12-30T01:00:00.000Z, local=2015-12-2...     False
# 4  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['attribution'])
output.head()
# Out:
#                                            values  validity
# 0  [{name=TCEQ, url=http://www.tceq.state.tx.us}]     False
# 1  [{name=TCEQ, url=http://www.tceq.state.tx.us}]     False
# 2  [{name=TCEQ, url=http://www.tceq.state.tx.us}]     False
# 3  [{name=TCEQ, url=http://www.tceq.state.tx.us}]     False
# 4  [{name=TCEQ, url=http://www.tceq.state.tx.us}]     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['averagingperiod'])
output.head()
# Out:
#                     values  validity
# 0  {unit=hours, value=1.0}     False
# 1  {unit=hours, value=1.0}     False
# 2  {unit=hours, value=1.0}     False
# 3  {unit=hours, value=1.0}     False
# 4  {unit=hours, value=1.0}     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['coordinates'])
output.head()
# Out:
#                                       values  validity
# 0  {latitude=29.767996, longitude=-95.22058}     False
# 1  {latitude=29.767996, longitude=-95.22058}     False
# 2  {latitude=29.767996, longitude=-95.22058}     False
# 3  {latitude=29.901037, longitude=-95.32613}     False
# 4  {latitude=29.767996, longitude=-95.22058}     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %% [markdown]
# All of the composite fields are in a "JSON-like format"  need to convert to JSON.

# %% [markdown]
# ## Reprocessing the Multivalue Fields into Valid JSON

# %%
def correct_field_to_json(arg: str) -> str:
    string = arg.lstrip("{{")
    string = string.rstrip("]}")
    strings = string.split(",")
    new_strings = []
    for entry in strings:
        index = entry.find('=')
        entry = '"' + entry[0:index] + '"' + ':' + '"'+ entry[index+1:len(entry)]+'"'
        new_strings.append(entry)
    output_string = (',').join(entry for entry in new_strings)
    output_string = '{' + output_string + '}'
    return output_string

# %%
def correct_json_column(series: pd.Series, column_name: str) -> pd.DataFrame:
    temp_df = pd.DataFrame()
    temp_df[column_name] = series.apply(correct_field_to_json)
    return temp_df

# %%
test = correct_json_column(df['date'], 'test date conversion')
results = validate_json_column(test['test date conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleaneddate'] = test

# %%
test = correct_json_column(df['attribution'], 'test attribute conversion')
results = validate_json_column(test['test attribute conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
results.head()
# Out:
#                                               values  validity
# 0  {"[{name":"TCEQ"," url":"http://www.tceq.state...      True
# 1  {"[{name":"TCEQ"," url":"http://www.tceq.state...      True
# 2  {"[{name":"TCEQ"," url":"http://www.tceq.state...      True
# 3  {"[{name":"TCEQ"," url":"http://www.tceq.state...      True
# 4  {"[{name":"TCEQ"," url":"http://www.tceq.state...      True

# %%
df['cleanedattribution'] = test

# %%
test = correct_json_column(df['averagingperiod'], 'test averaging period conversion')
results = validate_json_column(test['test averaging period conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleanedaveragingperiod'] = test

# %%
test = correct_json_column(df['coordinates'], 'test coordinate conversion')
results = validate_json_column(test['test coordinate conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleanedcoordinates'] = test

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2015-12-30T02:00:00.000Z, local=2015-12-2...       no2
# 1  {utc=2015-12-30T04:00:00.000Z, local=2015-12-2...        o3
# 2  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...        o3
# 3  {utc=2015-12-30T01:00:00.000Z, local=2015-12-2...       no2
# 4  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...       no2
#
#                        location   value unit     city  \
# 0          Houston East C1/G316  0.0118  ppm  Houston
# 1          Houston East C1/G316  0.0200  ppm  Houston
# 2          Houston East C1/G316  0.0180  ppm  Houston
# 3  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston
# 4          Houston East C1/G316  0.0137  ppm  Houston
#
#                                       attribution          averagingperiod  \
# 0  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 1  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 2  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 3  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 4  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
#
#                                  coordinates country sourcename  sourcetype  \
# 0  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
# 1  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
# 2  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
# 3  {latitude=29.901037, longitude=-95.32613}      US      Texas         NaN
# 4  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
#
#    mobile                                        cleaneddate  \
# 0     NaN  {"utc":"2015-12-30T02:00:00.000Z"," local":"20...
# 1     NaN  {"utc":"2015-12-30T04:00:00.000Z"," local":"20...
# 2     NaN  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
# 3     NaN  {"utc":"2015-12-30T01:00:00.000Z"," local":"20...
# 4     NaN  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 1  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 2  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 3  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 4  {"[{name":"TCEQ"," url":"http://www.tceq.state...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                   cleanedcoordinates
# 0  {"latitude":"29.767996"," longitude":"-95.22058"}
# 1  {"latitude":"29.767996"," longitude":"-95.22058"}
# 2  {"latitude":"29.767996"," longitude":"-95.22058"}
# 3  {"latitude":"29.901037"," longitude":"-95.32613"}
# 4  {"latitude":"29.767996"," longitude":"-95.22058"}

# %%
df_trans = df

# %%
df_trans = pd.concat([df_trans, df_trans.cleanedcoordinates.apply(json.loads).apply(pd.Series)], axis = 1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2015-12-30T02:00:00.000Z, local=2015-12-2...       no2
# 1  {utc=2015-12-30T04:00:00.000Z, local=2015-12-2...        o3
# 2  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...        o3
# 3  {utc=2015-12-30T01:00:00.000Z, local=2015-12-2...       no2
# 4  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...       no2
#
#                        location   value unit     city  \
# 0          Houston East C1/G316  0.0118  ppm  Houston
# 1          Houston East C1/G316  0.0200  ppm  Houston
# 2          Houston East C1/G316  0.0180  ppm  Houston
# 3  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston
# 4          Houston East C1/G316  0.0137  ppm  Houston
#
#                                       attribution          averagingperiod  \
# 0  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 1  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 2  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 3  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 4  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
#
#                                  coordinates country sourcename  sourcetype  \
# 0  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
# 1  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
# 2  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
# 3  {latitude=29.901037, longitude=-95.32613}      US      Texas         NaN
# 4  {latitude=29.767996, longitude=-95.22058}      US      Texas         NaN
#
#    mobile                                        cleaneddate  \
# 0     NaN  {"utc":"2015-12-30T02:00:00.000Z"," local":"20...
# 1     NaN  {"utc":"2015-12-30T04:00:00.000Z"," local":"20...
# 2     NaN  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
# 3     NaN  {"utc":"2015-12-30T01:00:00.000Z"," local":"20...
# 4     NaN  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 1  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 2  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 3  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 4  {"[{name":"TCEQ"," url":"http://www.tceq.state...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                   cleanedcoordinates   latitude  longitude
# 0  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 1  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 2  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 3  {"latitude":"29.901037"," longitude":"-95.32613"}  29.901037  -95.32613
# 4  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058

# %%
df_trans = pd.concat([df_trans, df_trans.cleaneddate.apply(json.loads).apply(pd.Series)], axis = 1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2015-12-30T02:00:00.000Z, local=2015-12-2...       no2
# 1  {utc=2015-12-30T04:00:00.000Z, local=2015-12-2...        o3
# 2  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...        o3
# 3  {utc=2015-12-30T01:00:00.000Z, local=2015-12-2...       no2
# 4  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...       no2
#
#                        location   value unit     city  \
# 0          Houston East C1/G316  0.0118  ppm  Houston
# 1          Houston East C1/G316  0.0200  ppm  Houston
# 2          Houston East C1/G316  0.0180  ppm  Houston
# 3  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston
# 4          Houston East C1/G316  0.0137  ppm  Houston
#
#                                       attribution          averagingperiod  \
# 0  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 1  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 2  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 3  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 4  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
#
#                                  coordinates country  ... sourcetype  mobile  \
# 0  {latitude=29.767996, longitude=-95.22058}      US  ...        NaN     NaN
# 1  {latitude=29.767996, longitude=-95.22058}      US  ...        NaN     NaN
# 2  {latitude=29.767996, longitude=-95.22058}      US  ...        NaN     NaN
# 3  {latitude=29.901037, longitude=-95.32613}      US  ...        NaN     NaN
# 4  {latitude=29.767996, longitude=-95.22058}      US  ...        NaN     NaN
#
#                                          cleaneddate  \
# 0  {"utc":"2015-12-30T02:00:00.000Z"," local":"20...
# 1  {"utc":"2015-12-30T04:00:00.000Z"," local":"20...
# 2  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
# 3  {"utc":"2015-12-30T01:00:00.000Z"," local":"20...
# 4  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 1  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 2  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 3  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 4  {"[{name":"TCEQ"," url":"http://www.tceq.state...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                   cleanedcoordinates   latitude  longitude  \
# 0  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 1  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 2  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 3  {"latitude":"29.901037"," longitude":"-95.32613"}  29.901037  -95.32613
# 4  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
#
#                         utc                      local
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00
#
# [5 rows x 21 columns]

# %%
df_trans = pd.concat([df_trans, df_trans.cleanedattribution.apply(json.loads).apply(pd.Series)], axis = 1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2015-12-30T02:00:00.000Z, local=2015-12-2...       no2
# 1  {utc=2015-12-30T04:00:00.000Z, local=2015-12-2...        o3
# 2  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...        o3
# 3  {utc=2015-12-30T01:00:00.000Z, local=2015-12-2...       no2
# 4  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...       no2
#
#                        location   value unit     city  \
# 0          Houston East C1/G316  0.0118  ppm  Houston
# 1          Houston East C1/G316  0.0200  ppm  Houston
# 2          Houston East C1/G316  0.0180  ppm  Houston
# 3  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston
# 4          Houston East C1/G316  0.0137  ppm  Houston
#
#                                       attribution          averagingperiod  \
# 0  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 1  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 2  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 3  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 4  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
#
#                                  coordinates country  ...  \
# 0  {latitude=29.767996, longitude=-95.22058}      US  ...
# 1  {latitude=29.767996, longitude=-95.22058}      US  ...
# 2  {latitude=29.767996, longitude=-95.22058}      US  ...
# 3  {latitude=29.901037, longitude=-95.32613}      US  ...
# 4  {latitude=29.767996, longitude=-95.22058}      US  ...
#
#                                   cleanedattribution  \
# 0  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 1  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 2  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 3  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 4  {"[{name":"TCEQ"," url":"http://www.tceq.state...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                   cleanedcoordinates   latitude  longitude  \
# 0  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 1  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 2  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 3  {"latitude":"29.901037"," longitude":"-95.32613"}  29.901037  -95.32613
# 4  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
#
#                         utc                      local [{name  \
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00   TCEQ
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00   TCEQ
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00   TCEQ
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
#
#                            url  {name
# 0  http://www.tceq.state.tx.us    NaN
# 1  http://www.tceq.state.tx.us    NaN
# 2  http://www.tceq.state.tx.us    NaN
# 3  http://www.tceq.state.tx.us    NaN
# 4  http://www.tceq.state.tx.us    NaN
#
# [5 rows x 24 columns]

# %%
df_trans.drop(' {name', axis=1, inplace=True)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2015-12-30T02:00:00.000Z, local=2015-12-2...       no2
# 1  {utc=2015-12-30T04:00:00.000Z, local=2015-12-2...        o3
# 2  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...        o3
# 3  {utc=2015-12-30T01:00:00.000Z, local=2015-12-2...       no2
# 4  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...       no2
#
#                        location   value unit     city  \
# 0          Houston East C1/G316  0.0118  ppm  Houston
# 1          Houston East C1/G316  0.0200  ppm  Houston
# 2          Houston East C1/G316  0.0180  ppm  Houston
# 3  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston
# 4          Houston East C1/G316  0.0137  ppm  Houston
#
#                                       attribution          averagingperiod  \
# 0  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 1  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 2  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 3  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 4  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
#
#                                  coordinates country  ...  \
# 0  {latitude=29.767996, longitude=-95.22058}      US  ...
# 1  {latitude=29.767996, longitude=-95.22058}      US  ...
# 2  {latitude=29.767996, longitude=-95.22058}      US  ...
# 3  {latitude=29.901037, longitude=-95.32613}      US  ...
# 4  {latitude=29.767996, longitude=-95.22058}      US  ...
#
#                                          cleaneddate  \
# 0  {"utc":"2015-12-30T02:00:00.000Z"," local":"20...
# 1  {"utc":"2015-12-30T04:00:00.000Z"," local":"20...
# 2  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
# 3  {"utc":"2015-12-30T01:00:00.000Z"," local":"20...
# 4  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 1  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 2  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 3  {"[{name":"TCEQ"," url":"http://www.tceq.state...
# 4  {"[{name":"TCEQ"," url":"http://www.tceq.state...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                   cleanedcoordinates   latitude  longitude  \
# 0  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 1  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 2  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 3  {"latitude":"29.901037"," longitude":"-95.32613"}  29.901037  -95.32613
# 4  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
#
#                         utc                      local [{name  \
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00   TCEQ
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00   TCEQ
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00   TCEQ
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
#
#                            url
# 0  http://www.tceq.state.tx.us
# 1  http://www.tceq.state.tx.us
# 2  http://www.tceq.state.tx.us
# 3  http://www.tceq.state.tx.us
# 4  http://www.tceq.state.tx.us
#
# [5 rows x 23 columns]

# %%
df_trans = pd.concat([df_trans, df_trans.cleanedaveragingperiod.apply(json.loads).apply(pd.Series)], axis = 1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2015-12-30T02:00:00.000Z, local=2015-12-2...       no2
# 1  {utc=2015-12-30T04:00:00.000Z, local=2015-12-2...        o3
# 2  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...        o3
# 3  {utc=2015-12-30T01:00:00.000Z, local=2015-12-2...       no2
# 4  {utc=2015-12-30T00:00:00.000Z, local=2015-12-2...       no2
#
#                        location   value unit     city  \
# 0          Houston East C1/G316  0.0118  ppm  Houston
# 1          Houston East C1/G316  0.0200  ppm  Houston
# 2          Houston East C1/G316  0.0180  ppm  Houston
# 3  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston
# 4          Houston East C1/G316  0.0137  ppm  Houston
#
#                                       attribution          averagingperiod  \
# 0  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 1  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 2  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 3  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 4  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
#
#                                  coordinates country  ...  \
# 0  {latitude=29.767996, longitude=-95.22058}      US  ...
# 1  {latitude=29.767996, longitude=-95.22058}      US  ...
# 2  {latitude=29.767996, longitude=-95.22058}      US  ...
# 3  {latitude=29.901037, longitude=-95.32613}      US  ...
# 4  {latitude=29.767996, longitude=-95.22058}      US  ...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                   cleanedcoordinates   latitude  longitude  \
# 0  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 1  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 2  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 3  {"latitude":"29.901037"," longitude":"-95.32613"}  29.901037  -95.32613
# 4  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
#
#                         utc                      local [{name  \
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00   TCEQ
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00   TCEQ
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00   TCEQ
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
#
#                            url   unit  value
# 0  http://www.tceq.state.tx.us  hours    1.0
# 1  http://www.tceq.state.tx.us  hours    1.0
# 2  http://www.tceq.state.tx.us  hours    1.0
# 3  http://www.tceq.state.tx.us  hours    1.0
# 4  http://www.tceq.state.tx.us  hours    1.0
#
# [5 rows x 25 columns]

# %%
df_trans.drop('date', axis =1, inplace=True)

# %%
df_trans.head()
# Out:
#   parameter                      location   value unit     city  \
# 0       no2          Houston East C1/G316  0.0118  ppm  Houston
# 1        o3          Houston East C1/G316  0.0200  ppm  Houston
# 2        o3          Houston East C1/G316  0.0180  ppm  Houston
# 3       no2  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston
# 4       no2          Houston East C1/G316  0.0137  ppm  Houston
#
#                                       attribution          averagingperiod  \
# 0  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 1  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 2  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 3  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
# 4  [{name=TCEQ, url=http://www.tceq.state.tx.us}]  {unit=hours, value=1.0}
#
#                                  coordinates country sourcename  ...  \
# 0  {latitude=29.767996, longitude=-95.22058}      US      Texas  ...
# 1  {latitude=29.767996, longitude=-95.22058}      US      Texas  ...
# 2  {latitude=29.767996, longitude=-95.22058}      US      Texas  ...
# 3  {latitude=29.901037, longitude=-95.32613}      US      Texas  ...
# 4  {latitude=29.767996, longitude=-95.22058}      US      Texas  ...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                   cleanedcoordinates   latitude  longitude  \
# 0  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 1  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 2  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
# 3  {"latitude":"29.901037"," longitude":"-95.32613"}  29.901037  -95.32613
# 4  {"latitude":"29.767996"," longitude":"-95.22058"}  29.767996  -95.22058
#
#                         utc                      local [{name  \
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00   TCEQ
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00   TCEQ
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00   TCEQ
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
#
#                            url   unit  value
# 0  http://www.tceq.state.tx.us  hours    1.0
# 1  http://www.tceq.state.tx.us  hours    1.0
# 2  http://www.tceq.state.tx.us  hours    1.0
# 3  http://www.tceq.state.tx.us  hours    1.0
# 4  http://www.tceq.state.tx.us  hours    1.0
#
# [5 rows x 24 columns]

# %%
df_trans.drop(['attribution','averagingperiod','coordinates','cleanedaveragingperiod','cleanedcoordinates'], axis = 1, inplace = True)

# %%
df_trans.head()
# Out:
#   parameter                      location   value unit     city country  \
# 0       no2          Houston East C1/G316  0.0118  ppm  Houston      US
# 1        o3          Houston East C1/G316  0.0200  ppm  Houston      US
# 2        o3          Houston East C1/G316  0.0180  ppm  Houston      US
# 3       no2  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston      US
# 4       no2          Houston East C1/G316  0.0137  ppm  Houston      US
#
#   sourcename  sourcetype  mobile  \
# 0      Texas         NaN     NaN
# 1      Texas         NaN     NaN
# 2      Texas         NaN     NaN
# 3      Texas         NaN     NaN
# 4      Texas         NaN     NaN
#
#                                          cleaneddate  \
# 0  {"utc":"2015-12-30T02:00:00.000Z"," local":"20...
# 1  {"utc":"2015-12-30T04:00:00.000Z"," local":"20...
# 2  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
# 3  {"utc":"2015-12-30T01:00:00.000Z"," local":"20...
# 4  {"utc":"2015-12-30T00:00:00.000Z"," local":"20...
#
#                                   cleanedattribution   latitude  longitude  \
# 0  {"[{name":"TCEQ"," url":"http://www.tceq.state...  29.767996  -95.22058
# 1  {"[{name":"TCEQ"," url":"http://www.tceq.state...  29.767996  -95.22058
# 2  {"[{name":"TCEQ"," url":"http://www.tceq.state...  29.767996  -95.22058
# 3  {"[{name":"TCEQ"," url":"http://www.tceq.state...  29.901037  -95.32613
# 4  {"[{name":"TCEQ"," url":"http://www.tceq.state...  29.767996  -95.22058
#
#                         utc                      local [{name  \
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00   TCEQ
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00   TCEQ
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00   TCEQ
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
#
#                            url   unit  value
# 0  http://www.tceq.state.tx.us  hours    1.0
# 1  http://www.tceq.state.tx.us  hours    1.0
# 2  http://www.tceq.state.tx.us  hours    1.0
# 3  http://www.tceq.state.tx.us  hours    1.0
# 4  http://www.tceq.state.tx.us  hours    1.0

# %%
df_trans.drop(['cleaneddate','cleanedattribution'], axis = 1, inplace = True)

# %%
df_trans.head()
# Out:
#   parameter                      location   value unit     city country  \
# 0       no2          Houston East C1/G316  0.0118  ppm  Houston      US
# 1        o3          Houston East C1/G316  0.0200  ppm  Houston      US
# 2        o3          Houston East C1/G316  0.0180  ppm  Houston      US
# 3       no2  Houston Aldine C8/AF108/X150  0.0007  ppm  Houston      US
# 4       no2          Houston East C1/G316  0.0137  ppm  Houston      US
#
#   sourcename  sourcetype  mobile   latitude  longitude  \
# 0      Texas         NaN     NaN  29.767996  -95.22058
# 1      Texas         NaN     NaN  29.767996  -95.22058
# 2      Texas         NaN     NaN  29.767996  -95.22058
# 3      Texas         NaN     NaN  29.901037  -95.32613
# 4      Texas         NaN     NaN  29.767996  -95.22058
#
#                         utc                      local [{name  \
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00   TCEQ
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00   TCEQ
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00   TCEQ
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
#
#                            url   unit  value
# 0  http://www.tceq.state.tx.us  hours    1.0
# 1  http://www.tceq.state.tx.us  hours    1.0
# 2  http://www.tceq.state.tx.us  hours    1.0
# 3  http://www.tceq.state.tx.us  hours    1.0
# 4  http://www.tceq.state.tx.us  hours    1.0

# %%
#df_trans.rename(columns={df_trans.columns[15]: 'averaging time unit'}, inplace=True)
df_trans.columns.values[3]='concentration unit'

# %%
df_trans.head()
# Out:
#   parameter                      location   value concentration unit     city  \
# 0       no2          Houston East C1/G316  0.0118                ppm  Houston
# 1        o3          Houston East C1/G316  0.0200                ppm  Houston
# 2        o3          Houston East C1/G316  0.0180                ppm  Houston
# 3       no2  Houston Aldine C8/AF108/X150  0.0007                ppm  Houston
# 4       no2          Houston East C1/G316  0.0137                ppm  Houston
#
#   country sourcename  sourcetype  mobile   latitude  longitude  \
# 0      US      Texas         NaN     NaN  29.767996  -95.22058
# 1      US      Texas         NaN     NaN  29.767996  -95.22058
# 2      US      Texas         NaN     NaN  29.767996  -95.22058
# 3      US      Texas         NaN     NaN  29.901037  -95.32613
# 4      US      Texas         NaN     NaN  29.767996  -95.22058
#
#                         utc                      local [{name  \
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00   TCEQ
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00   TCEQ
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00   TCEQ
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
#
#                            url   unit  value
# 0  http://www.tceq.state.tx.us  hours    1.0
# 1  http://www.tceq.state.tx.us  hours    1.0
# 2  http://www.tceq.state.tx.us  hours    1.0
# 3  http://www.tceq.state.tx.us  hours    1.0
# 4  http://www.tceq.state.tx.us  hours    1.0

# %%
#df_trans.rename(columns={df_trans.columns[15]: 'averaging time unit'}, inplace=True)
df_trans.columns.values[15] = 'averaging time unit'

# %%
#df_trans.rename(columns={df_trans.columns[13]: 'source'}, inplace=True)
df_trans.columns.values[13] = 'source'

# %%
df_trans.head()
# Out:
#   parameter                      location   value concentration unit     city  \
# 0       no2          Houston East C1/G316  0.0118                ppm  Houston
# 1        o3          Houston East C1/G316  0.0200                ppm  Houston
# 2        o3          Houston East C1/G316  0.0180                ppm  Houston
# 3       no2  Houston Aldine C8/AF108/X150  0.0007                ppm  Houston
# 4       no2          Houston East C1/G316  0.0137                ppm  Houston
#
#   country sourcename  sourcetype  mobile   latitude  longitude  \
# 0      US      Texas         NaN     NaN  29.767996  -95.22058
# 1      US      Texas         NaN     NaN  29.767996  -95.22058
# 2      US      Texas         NaN     NaN  29.767996  -95.22058
# 3      US      Texas         NaN     NaN  29.901037  -95.32613
# 4      US      Texas         NaN     NaN  29.767996  -95.22058
#
#                         utc                      local source  \
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00   TCEQ
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00   TCEQ
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00   TCEQ
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
#
#                            url averaging time unit  value
# 0  http://www.tceq.state.tx.us               hours    1.0
# 1  http://www.tceq.state.tx.us               hours    1.0
# 2  http://www.tceq.state.tx.us               hours    1.0
# 3  http://www.tceq.state.tx.us               hours    1.0
# 4  http://www.tceq.state.tx.us               hours    1.0

# %%
#df_trans.rename(columns={df_trans.columns[16]: 'averaging time'},inplace=True)
df_trans.columns.values[16] = 'averaging time'

# %%
df_trans.head()
# Out:
#   parameter                      location   value concentration unit     city  \
# 0       no2          Houston East C1/G316  0.0118                ppm  Houston
# 1        o3          Houston East C1/G316  0.0200                ppm  Houston
# 2        o3          Houston East C1/G316  0.0180                ppm  Houston
# 3       no2  Houston Aldine C8/AF108/X150  0.0007                ppm  Houston
# 4       no2          Houston East C1/G316  0.0137                ppm  Houston
#
#   country sourcename  sourcetype  mobile   latitude  longitude  \
# 0      US      Texas         NaN     NaN  29.767996  -95.22058
# 1      US      Texas         NaN     NaN  29.767996  -95.22058
# 2      US      Texas         NaN     NaN  29.767996  -95.22058
# 3      US      Texas         NaN     NaN  29.901037  -95.32613
# 4      US      Texas         NaN     NaN  29.767996  -95.22058
#
#                         utc                      local source  \
# 0  2015-12-30T02:00:00.000Z  2015-12-29T20:00:00-06:00   TCEQ
# 1  2015-12-30T04:00:00.000Z  2015-12-29T22:00:00-06:00   TCEQ
# 2  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
# 3  2015-12-30T01:00:00.000Z  2015-12-29T19:00:00-06:00   TCEQ
# 4  2015-12-30T00:00:00.000Z  2015-12-29T18:00:00-06:00   TCEQ
#
#                            url averaging time unit averaging time
# 0  http://www.tceq.state.tx.us               hours            1.0
# 1  http://www.tceq.state.tx.us               hours            1.0
# 2  http://www.tceq.state.tx.us               hours            1.0
# 3  http://www.tceq.state.tx.us               hours            1.0
# 4  http://www.tceq.state.tx.us               hours            1.0

# %%
df_trans.to_csv('2015 AQ Clean.csv', index=False)
