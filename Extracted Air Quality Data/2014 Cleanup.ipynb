# %% [markdown]
# # Cleanup and Exploration of 2014 AQ Data

# %% [markdown]
# As this is the smallest data file, it will be used for developing cleaning and integration functions for use for the rest of the dataset.  Some details of the json processing may need to be performed later, as the malformed json entries didn't start showing up until later in the process.

# %%
import pandas as pd
import json as json

# %%
df = pd.read_csv('2014 AQ.csv')

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2014-07-17T01:00:00.000Z, local=2014-07-1...      pm25
# 1  {utc=2014-07-17T02:00:00.000Z, local=2014-07-1...      pm25
# 2  {utc=2014-07-17T00:00:00.000Z, local=2014-07-1...      pm25
# 3  {utc=2014-07-16T22:00:00.000Z, local=2014-07-1...      pm25
# 4  {utc=2014-07-16T16:00:00.000Z, local=2014-07-1...      pm25
#
#                  location  value   unit             city  \
# 0  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
# 1  SPARTAN - Mammoth Cave    5.4  µg/m³  Mammoth Cave NP
# 2  SPARTAN - Mammoth Cave    5.1  µg/m³  Mammoth Cave NP
# 3  SPARTAN - Mammoth Cave    4.1  µg/m³  Mammoth Cave NP
# 4  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
#
#                                          attribution          averagingperiod  \
# 0  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 1  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 2  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 3  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 4  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
#
#                             coordinates country sourcename sourcetype  mobile
# 0  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 1  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 2  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 3  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 4  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False

# %%
test_dist = json.loads(df['date'][0]) #Seeing if I can load the date objects as json into dict or if they will need to be processed.
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 test_dist = json.loads(df['date'][0])
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\anaconda3\lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %% [markdown]
# The entry is not valid json.  The field will need processing code.

# %%
def validate_json_fields(field: str) -> bool:
    """This function validates a JSON entry is valid.  Returns True if so, False if otherwise."""
    try:
        json.loads(field)
        return True
    except ValueError:
        return False

# %%
def validate_json_column(series: pd.Series):
    temp_df = pd.DataFrame()
    temp_df['values'] = series
    temp_df['validity'] = series.apply(validate_json_fields)
    return temp_df

# %% [markdown]
# ## Validation of composite fields as json

# %%
output = validate_json_column(df['date'])

# %%
output.head()
# Out:
#                                               values  validity
# 0  {utc=2014-07-17T01:00:00.000Z, local=2014-07-1...     False
# 1  {utc=2014-07-17T02:00:00.000Z, local=2014-07-1...     False
# 2  {utc=2014-07-17T00:00:00.000Z, local=2014-07-1...     False
# 3  {utc=2014-07-16T22:00:00.000Z, local=2014-07-1...     False
# 4  {utc=2014-07-16T16:00:00.000Z, local=2014-07-1...     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['attribution'])
output.head()
# Out:
#                                               values  validity
# 0  [{name=SPARTAN Network, url=http://www.spartan...     False
# 1  [{name=SPARTAN Network, url=http://www.spartan...     False
# 2  [{name=SPARTAN Network, url=http://www.spartan...     False
# 3  [{name=SPARTAN Network, url=http://www.spartan...     False
# 4  [{name=SPARTAN Network, url=http://www.spartan...     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['averagingperiod'])
output.head()
# Out:
#                     values  validity
# 0  {unit=hours, value=1.0}     False
# 1  {unit=hours, value=1.0}     False
# 2  {unit=hours, value=1.0}     False
# 3  {unit=hours, value=1.0}     False
# 4  {unit=hours, value=1.0}     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['coordinates'])
output.head()
# Out:
#                                  values  validity
# 0  {latitude=37.132, longitude=-86.148}     False
# 1  {latitude=37.132, longitude=-86.148}     False
# 2  {latitude=37.132, longitude=-86.148}     False
# 3  {latitude=37.132, longitude=-86.148}     False
# 4  {latitude=37.132, longitude=-86.148}     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %% [markdown]
# All of the composite fields are in a "JSON-like format"  need to convert to JSON.

# %% [markdown]
# ## Reprocessing the Multivalue Fields into Valid JSON

# %%
def correct_field_to_json(arg: str) -> str:
    string = arg.lstrip("{{")
    string = string.rstrip("]}")
    strings = string.split(",")
    new_strings = []
    for entry in strings:
        index = entry.find('=')
        entry = '"' + entry[0:index] + '"' + ':' + '"'+ entry[index+1:len(entry)]+'"'
        new_strings.append(entry)
    output_string = (',').join(entry for entry in new_strings)
    output_string = '{' + output_string + '}'
    return output_string

# %%
def correct_json_column(series: pd.Series, column_name: str) -> pd.DataFrame:
    temp_df = pd.DataFrame()
    temp_df[column_name] = series.apply(correct_field_to_json)
    return temp_df

# %%
test = correct_json_column(df['date'], 'test date conversion')
results = validate_json_column(test['test date conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleaneddate'] = test

# %%
test = correct_json_column(df['attribution'], 'test attribute conversion')
results = validate_json_column(test['test attribute conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
results.head()
# Out:
#                                               values  validity
# 0  {"[{name":"SPARTAN Network"," url":"http://www...      True
# 1  {"[{name":"SPARTAN Network"," url":"http://www...      True
# 2  {"[{name":"SPARTAN Network"," url":"http://www...      True
# 3  {"[{name":"SPARTAN Network"," url":"http://www...      True
# 4  {"[{name":"SPARTAN Network"," url":"http://www...      True

# %%
df['cleanedattribution'] = test

# %%
test = correct_json_column(df['averagingperiod'], 'test averaging period conversion')
results = validate_json_column(test['test averaging period conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleanedaveragingperiod'] = test

# %%
test = correct_json_column(df['coordinates'], 'test coordinate conversion')
results = validate_json_column(test['test coordinate conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleanedcoordinates'] = test

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2014-07-17T01:00:00.000Z, local=2014-07-1...      pm25
# 1  {utc=2014-07-17T02:00:00.000Z, local=2014-07-1...      pm25
# 2  {utc=2014-07-17T00:00:00.000Z, local=2014-07-1...      pm25
# 3  {utc=2014-07-16T22:00:00.000Z, local=2014-07-1...      pm25
# 4  {utc=2014-07-16T16:00:00.000Z, local=2014-07-1...      pm25
#
#                  location  value   unit             city  \
# 0  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
# 1  SPARTAN - Mammoth Cave    5.4  µg/m³  Mammoth Cave NP
# 2  SPARTAN - Mammoth Cave    5.1  µg/m³  Mammoth Cave NP
# 3  SPARTAN - Mammoth Cave    4.1  µg/m³  Mammoth Cave NP
# 4  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
#
#                                          attribution          averagingperiod  \
# 0  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 1  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 2  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 3  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 4  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
#
#                             coordinates country sourcename sourcetype  mobile  \
# 0  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 1  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 2  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 3  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 4  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
#
#                                          cleaneddate  \
# 0  {"utc":"2014-07-17T01:00:00.000Z"," local":"20...
# 1  {"utc":"2014-07-17T02:00:00.000Z"," local":"20...
# 2  {"utc":"2014-07-17T00:00:00.000Z"," local":"20...
# 3  {"utc":"2014-07-16T22:00:00.000Z"," local":"20...
# 4  {"utc":"2014-07-16T16:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"SPARTAN Network"," url":"http://www...
# 1  {"[{name":"SPARTAN Network"," url":"http://www...
# 2  {"[{name":"SPARTAN Network"," url":"http://www...
# 3  {"[{name":"SPARTAN Network"," url":"http://www...
# 4  {"[{name":"SPARTAN Network"," url":"http://www...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                              cleanedcoordinates
# 0  {"latitude":"37.132"," longitude":"-86.148"}
# 1  {"latitude":"37.132"," longitude":"-86.148"}
# 2  {"latitude":"37.132"," longitude":"-86.148"}
# 3  {"latitude":"37.132"," longitude":"-86.148"}
# 4  {"latitude":"37.132"," longitude":"-86.148"}

# %%
df_trans = df

# %%
df_trans = pd.concat([df_trans, df_trans.cleanedcoordinates.apply(json.loads).apply(pd.Series)], axis = 1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2014-07-17T01:00:00.000Z, local=2014-07-1...      pm25
# 1  {utc=2014-07-17T02:00:00.000Z, local=2014-07-1...      pm25
# 2  {utc=2014-07-17T00:00:00.000Z, local=2014-07-1...      pm25
# 3  {utc=2014-07-16T22:00:00.000Z, local=2014-07-1...      pm25
# 4  {utc=2014-07-16T16:00:00.000Z, local=2014-07-1...      pm25
#
#                  location  value   unit             city  \
# 0  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
# 1  SPARTAN - Mammoth Cave    5.4  µg/m³  Mammoth Cave NP
# 2  SPARTAN - Mammoth Cave    5.1  µg/m³  Mammoth Cave NP
# 3  SPARTAN - Mammoth Cave    4.1  µg/m³  Mammoth Cave NP
# 4  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
#
#                                          attribution          averagingperiod  \
# 0  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 1  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 2  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 3  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 4  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
#
#                             coordinates country sourcename sourcetype  mobile  \
# 0  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 1  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 2  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 3  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
# 4  {latitude=37.132, longitude=-86.148}      US    Spartan   research   False
#
#                                          cleaneddate  \
# 0  {"utc":"2014-07-17T01:00:00.000Z"," local":"20...
# 1  {"utc":"2014-07-17T02:00:00.000Z"," local":"20...
# 2  {"utc":"2014-07-17T00:00:00.000Z"," local":"20...
# 3  {"utc":"2014-07-16T22:00:00.000Z"," local":"20...
# 4  {"utc":"2014-07-16T16:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"SPARTAN Network"," url":"http://www...
# 1  {"[{name":"SPARTAN Network"," url":"http://www...
# 2  {"[{name":"SPARTAN Network"," url":"http://www...
# 3  {"[{name":"SPARTAN Network"," url":"http://www...
# 4  {"[{name":"SPARTAN Network"," url":"http://www...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                              cleanedcoordinates latitude  longitude
# 0  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 1  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 2  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 3  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 4  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148

# %%
df_trans = pd.concat([df_trans, df_trans.cleaneddate.apply(json.loads).apply(pd.Series)], axis = 1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2014-07-17T01:00:00.000Z, local=2014-07-1...      pm25
# 1  {utc=2014-07-17T02:00:00.000Z, local=2014-07-1...      pm25
# 2  {utc=2014-07-17T00:00:00.000Z, local=2014-07-1...      pm25
# 3  {utc=2014-07-16T22:00:00.000Z, local=2014-07-1...      pm25
# 4  {utc=2014-07-16T16:00:00.000Z, local=2014-07-1...      pm25
#
#                  location  value   unit             city  \
# 0  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
# 1  SPARTAN - Mammoth Cave    5.4  µg/m³  Mammoth Cave NP
# 2  SPARTAN - Mammoth Cave    5.1  µg/m³  Mammoth Cave NP
# 3  SPARTAN - Mammoth Cave    4.1  µg/m³  Mammoth Cave NP
# 4  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
#
#                                          attribution          averagingperiod  \
# 0  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 1  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 2  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 3  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 4  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
#
#                             coordinates country  ... sourcetype mobile  \
# 0  {latitude=37.132, longitude=-86.148}      US  ...   research  False
# 1  {latitude=37.132, longitude=-86.148}      US  ...   research  False
# 2  {latitude=37.132, longitude=-86.148}      US  ...   research  False
# 3  {latitude=37.132, longitude=-86.148}      US  ...   research  False
# 4  {latitude=37.132, longitude=-86.148}      US  ...   research  False
#
#                                          cleaneddate  \
# 0  {"utc":"2014-07-17T01:00:00.000Z"," local":"20...
# 1  {"utc":"2014-07-17T02:00:00.000Z"," local":"20...
# 2  {"utc":"2014-07-17T00:00:00.000Z"," local":"20...
# 3  {"utc":"2014-07-16T22:00:00.000Z"," local":"20...
# 4  {"utc":"2014-07-16T16:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"SPARTAN Network"," url":"http://www...
# 1  {"[{name":"SPARTAN Network"," url":"http://www...
# 2  {"[{name":"SPARTAN Network"," url":"http://www...
# 3  {"[{name":"SPARTAN Network"," url":"http://www...
# 4  {"[{name":"SPARTAN Network"," url":"http://www...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                              cleanedcoordinates latitude  longitude  \
# 0  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 1  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 2  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 3  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 4  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
#
#                         utc                      local
# 0  2014-07-17T01:00:00.000Z  2014-07-16T21:00:00-04:00
# 1  2014-07-17T02:00:00.000Z  2014-07-16T22:00:00-04:00
# 2  2014-07-17T00:00:00.000Z  2014-07-16T20:00:00-04:00
# 3  2014-07-16T22:00:00.000Z  2014-07-16T18:00:00-04:00
# 4  2014-07-16T16:00:00.000Z  2014-07-16T12:00:00-04:00
#
# [5 rows x 21 columns]

# %%
df_trans = pd.concat([df_trans, df_trans.cleanedattribution.apply(json.loads).apply(pd.Series)], axis = 1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2014-07-17T01:00:00.000Z, local=2014-07-1...      pm25
# 1  {utc=2014-07-17T02:00:00.000Z, local=2014-07-1...      pm25
# 2  {utc=2014-07-17T00:00:00.000Z, local=2014-07-1...      pm25
# 3  {utc=2014-07-16T22:00:00.000Z, local=2014-07-1...      pm25
# 4  {utc=2014-07-16T16:00:00.000Z, local=2014-07-1...      pm25
#
#                  location  value   unit             city  \
# 0  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
# 1  SPARTAN - Mammoth Cave    5.4  µg/m³  Mammoth Cave NP
# 2  SPARTAN - Mammoth Cave    5.1  µg/m³  Mammoth Cave NP
# 3  SPARTAN - Mammoth Cave    4.1  µg/m³  Mammoth Cave NP
# 4  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
#
#                                          attribution          averagingperiod  \
# 0  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 1  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 2  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 3  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 4  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
#
#                             coordinates country  ...  \
# 0  {latitude=37.132, longitude=-86.148}      US  ...
# 1  {latitude=37.132, longitude=-86.148}      US  ...
# 2  {latitude=37.132, longitude=-86.148}      US  ...
# 3  {latitude=37.132, longitude=-86.148}      US  ...
# 4  {latitude=37.132, longitude=-86.148}      US  ...
#
#                                          cleaneddate  \
# 0  {"utc":"2014-07-17T01:00:00.000Z"," local":"20...
# 1  {"utc":"2014-07-17T02:00:00.000Z"," local":"20...
# 2  {"utc":"2014-07-17T00:00:00.000Z"," local":"20...
# 3  {"utc":"2014-07-16T22:00:00.000Z"," local":"20...
# 4  {"utc":"2014-07-16T16:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"SPARTAN Network"," url":"http://www...
# 1  {"[{name":"SPARTAN Network"," url":"http://www...
# 2  {"[{name":"SPARTAN Network"," url":"http://www...
# 3  {"[{name":"SPARTAN Network"," url":"http://www...
# 4  {"[{name":"SPARTAN Network"," url":"http://www...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                              cleanedcoordinates latitude  longitude  \
# 0  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 1  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 2  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 3  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 4  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
#
#                         utc                      local           [{name  \
# 0  2014-07-17T01:00:00.000Z  2014-07-16T21:00:00-04:00  SPARTAN Network
# 1  2014-07-17T02:00:00.000Z  2014-07-16T22:00:00-04:00  SPARTAN Network
# 2  2014-07-17T00:00:00.000Z  2014-07-16T20:00:00-04:00  SPARTAN Network
# 3  2014-07-16T22:00:00.000Z  2014-07-16T18:00:00-04:00  SPARTAN Network
# 4  2014-07-16T16:00:00.000Z  2014-07-16T12:00:00-04:00  SPARTAN Network
#
#                                url
# 0  http://www.spartan-network.org/
# 1  http://www.spartan-network.org/
# 2  http://www.spartan-network.org/
# 3  http://www.spartan-network.org/
# 4  http://www.spartan-network.org/
#
# [5 rows x 23 columns]

# %%
df_trans = pd.concat([df_trans, df_trans.cleanedaveragingperiod.apply(json.loads).apply(pd.Series)], axis = 1)

# %%
df_trans.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2014-07-17T01:00:00.000Z, local=2014-07-1...      pm25
# 1  {utc=2014-07-17T02:00:00.000Z, local=2014-07-1...      pm25
# 2  {utc=2014-07-17T00:00:00.000Z, local=2014-07-1...      pm25
# 3  {utc=2014-07-16T22:00:00.000Z, local=2014-07-1...      pm25
# 4  {utc=2014-07-16T16:00:00.000Z, local=2014-07-1...      pm25
#
#                  location  value   unit             city  \
# 0  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
# 1  SPARTAN - Mammoth Cave    5.4  µg/m³  Mammoth Cave NP
# 2  SPARTAN - Mammoth Cave    5.1  µg/m³  Mammoth Cave NP
# 3  SPARTAN - Mammoth Cave    4.1  µg/m³  Mammoth Cave NP
# 4  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
#
#                                          attribution          averagingperiod  \
# 0  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 1  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 2  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 3  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 4  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
#
#                             coordinates country  ...  \
# 0  {latitude=37.132, longitude=-86.148}      US  ...
# 1  {latitude=37.132, longitude=-86.148}      US  ...
# 2  {latitude=37.132, longitude=-86.148}      US  ...
# 3  {latitude=37.132, longitude=-86.148}      US  ...
# 4  {latitude=37.132, longitude=-86.148}      US  ...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                              cleanedcoordinates  latitude  longitude  \
# 0  {"latitude":"37.132"," longitude":"-86.148"}    37.132    -86.148
# 1  {"latitude":"37.132"," longitude":"-86.148"}    37.132    -86.148
# 2  {"latitude":"37.132"," longitude":"-86.148"}    37.132    -86.148
# 3  {"latitude":"37.132"," longitude":"-86.148"}    37.132    -86.148
# 4  {"latitude":"37.132"," longitude":"-86.148"}    37.132    -86.148
#
#                         utc                      local           [{name  \
# 0  2014-07-17T01:00:00.000Z  2014-07-16T21:00:00-04:00  SPARTAN Network
# 1  2014-07-17T02:00:00.000Z  2014-07-16T22:00:00-04:00  SPARTAN Network
# 2  2014-07-17T00:00:00.000Z  2014-07-16T20:00:00-04:00  SPARTAN Network
# 3  2014-07-16T22:00:00.000Z  2014-07-16T18:00:00-04:00  SPARTAN Network
# 4  2014-07-16T16:00:00.000Z  2014-07-16T12:00:00-04:00  SPARTAN Network
#
#                                url   unit  value
# 0  http://www.spartan-network.org/  hours    1.0
# 1  http://www.spartan-network.org/  hours    1.0
# 2  http://www.spartan-network.org/  hours    1.0
# 3  http://www.spartan-network.org/  hours    1.0
# 4  http://www.spartan-network.org/  hours    1.0
#
# [5 rows x 25 columns]

# %%
df_trans.drop('date', axis =1, inplace=True)

# %%
df_trans.head()
# Out:
#   parameter                location  value   unit             city  \
# 0      pm25  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
# 1      pm25  SPARTAN - Mammoth Cave    5.4  µg/m³  Mammoth Cave NP
# 2      pm25  SPARTAN - Mammoth Cave    5.1  µg/m³  Mammoth Cave NP
# 3      pm25  SPARTAN - Mammoth Cave    4.1  µg/m³  Mammoth Cave NP
# 4      pm25  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP
#
#                                          attribution          averagingperiod  \
# 0  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 1  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 2  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 3  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
# 4  [{name=SPARTAN Network, url=http://www.spartan...  {unit=hours, value=1.0}
#
#                             coordinates country sourcename  ...  \
# 0  {latitude=37.132, longitude=-86.148}      US    Spartan  ...
# 1  {latitude=37.132, longitude=-86.148}      US    Spartan  ...
# 2  {latitude=37.132, longitude=-86.148}      US    Spartan  ...
# 3  {latitude=37.132, longitude=-86.148}      US    Spartan  ...
# 4  {latitude=37.132, longitude=-86.148}      US    Spartan  ...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                              cleanedcoordinates latitude  longitude  \
# 0  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 1  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 2  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 3  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
# 4  {"latitude":"37.132"," longitude":"-86.148"}   37.132    -86.148
#
#                         utc                      local           [{name  \
# 0  2014-07-17T01:00:00.000Z  2014-07-16T21:00:00-04:00  SPARTAN Network
# 1  2014-07-17T02:00:00.000Z  2014-07-16T22:00:00-04:00  SPARTAN Network
# 2  2014-07-17T00:00:00.000Z  2014-07-16T20:00:00-04:00  SPARTAN Network
# 3  2014-07-16T22:00:00.000Z  2014-07-16T18:00:00-04:00  SPARTAN Network
# 4  2014-07-16T16:00:00.000Z  2014-07-16T12:00:00-04:00  SPARTAN Network
#
#                                url   unit  value
# 0  http://www.spartan-network.org/  hours    1.0
# 1  http://www.spartan-network.org/  hours    1.0
# 2  http://www.spartan-network.org/  hours    1.0
# 3  http://www.spartan-network.org/  hours    1.0
# 4  http://www.spartan-network.org/  hours    1.0
#
# [5 rows x 24 columns]

# %%
df_trans.drop(['attribution','averagingperiod','coordinates','cleanedaveragingperiod','cleanedcoordinates'], axis = 1, inplace = True)

# %%
df_trans.head()
# Out:
#   parameter                location  value   unit             city country  \
# 0      pm25  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP      US
# 1      pm25  SPARTAN - Mammoth Cave    5.4  µg/m³  Mammoth Cave NP      US
# 2      pm25  SPARTAN - Mammoth Cave    5.1  µg/m³  Mammoth Cave NP      US
# 3      pm25  SPARTAN - Mammoth Cave    4.1  µg/m³  Mammoth Cave NP      US
# 4      pm25  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP      US
#
#   sourcename sourcetype  mobile  \
# 0    Spartan   research   False
# 1    Spartan   research   False
# 2    Spartan   research   False
# 3    Spartan   research   False
# 4    Spartan   research   False
#
#                                          cleaneddate  \
# 0  {"utc":"2014-07-17T01:00:00.000Z"," local":"20...
# 1  {"utc":"2014-07-17T02:00:00.000Z"," local":"20...
# 2  {"utc":"2014-07-17T00:00:00.000Z"," local":"20...
# 3  {"utc":"2014-07-16T22:00:00.000Z"," local":"20...
# 4  {"utc":"2014-07-16T16:00:00.000Z"," local":"20...
#
#                                   cleanedattribution latitude  longitude  \
# 0  {"[{name":"SPARTAN Network"," url":"http://www...   37.132    -86.148
# 1  {"[{name":"SPARTAN Network"," url":"http://www...   37.132    -86.148
# 2  {"[{name":"SPARTAN Network"," url":"http://www...   37.132    -86.148
# 3  {"[{name":"SPARTAN Network"," url":"http://www...   37.132    -86.148
# 4  {"[{name":"SPARTAN Network"," url":"http://www...   37.132    -86.148
#
#                         utc                      local           [{name  \
# 0  2014-07-17T01:00:00.000Z  2014-07-16T21:00:00-04:00  SPARTAN Network
# 1  2014-07-17T02:00:00.000Z  2014-07-16T22:00:00-04:00  SPARTAN Network
# 2  2014-07-17T00:00:00.000Z  2014-07-16T20:00:00-04:00  SPARTAN Network
# 3  2014-07-16T22:00:00.000Z  2014-07-16T18:00:00-04:00  SPARTAN Network
# 4  2014-07-16T16:00:00.000Z  2014-07-16T12:00:00-04:00  SPARTAN Network
#
#                                url   unit  value
# 0  http://www.spartan-network.org/  hours    1.0
# 1  http://www.spartan-network.org/  hours    1.0
# 2  http://www.spartan-network.org/  hours    1.0
# 3  http://www.spartan-network.org/  hours    1.0
# 4  http://www.spartan-network.org/  hours    1.0

# %%
df_trans.drop(['cleaneddate','cleanedattribution'], axis = 1, inplace = True)

# %%
df_trans.head()
# Out:
#   parameter                location  value   unit             city country  \
# 0      pm25  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP      US
# 1      pm25  SPARTAN - Mammoth Cave    5.4  µg/m³  Mammoth Cave NP      US
# 2      pm25  SPARTAN - Mammoth Cave    5.1  µg/m³  Mammoth Cave NP      US
# 3      pm25  SPARTAN - Mammoth Cave    4.1  µg/m³  Mammoth Cave NP      US
# 4      pm25  SPARTAN - Mammoth Cave    5.6  µg/m³  Mammoth Cave NP      US
#
#   sourcename sourcetype  mobile latitude  longitude                       utc  \
# 0    Spartan   research   False   37.132    -86.148  2014-07-17T01:00:00.000Z
# 1    Spartan   research   False   37.132    -86.148  2014-07-17T02:00:00.000Z
# 2    Spartan   research   False   37.132    -86.148  2014-07-17T00:00:00.000Z
# 3    Spartan   research   False   37.132    -86.148  2014-07-16T22:00:00.000Z
# 4    Spartan   research   False   37.132    -86.148  2014-07-16T16:00:00.000Z
#
#                        local           [{name  \
# 0  2014-07-16T21:00:00-04:00  SPARTAN Network
# 1  2014-07-16T22:00:00-04:00  SPARTAN Network
# 2  2014-07-16T20:00:00-04:00  SPARTAN Network
# 3  2014-07-16T18:00:00-04:00  SPARTAN Network
# 4  2014-07-16T12:00:00-04:00  SPARTAN Network
#
#                                url   unit  value
# 0  http://www.spartan-network.org/  hours    1.0
# 1  http://www.spartan-network.org/  hours    1.0
# 2  http://www.spartan-network.org/  hours    1.0
# 3  http://www.spartan-network.org/  hours    1.0
# 4  http://www.spartan-network.org/  hours    1.0

# %%
df_trans.rename(columns={'unit': 'concentration unit'}, inplace=True)

# %%
df_trans.head()
# Out:
#   parameter                location  value concentration unit  \
# 0      pm25  SPARTAN - Mammoth Cave    5.6              µg/m³
# 1      pm25  SPARTAN - Mammoth Cave    5.4              µg/m³
# 2      pm25  SPARTAN - Mammoth Cave    5.1              µg/m³
# 3      pm25  SPARTAN - Mammoth Cave    4.1              µg/m³
# 4      pm25  SPARTAN - Mammoth Cave    5.6              µg/m³
#
#               city country sourcename sourcetype  mobile latitude  longitude  \
# 0  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 1  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 2  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 3  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 4  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
#
#                         utc                      local           [{name  \
# 0  2014-07-17T01:00:00.000Z  2014-07-16T21:00:00-04:00  SPARTAN Network
# 1  2014-07-17T02:00:00.000Z  2014-07-16T22:00:00-04:00  SPARTAN Network
# 2  2014-07-17T00:00:00.000Z  2014-07-16T20:00:00-04:00  SPARTAN Network
# 3  2014-07-16T22:00:00.000Z  2014-07-16T18:00:00-04:00  SPARTAN Network
# 4  2014-07-16T16:00:00.000Z  2014-07-16T12:00:00-04:00  SPARTAN Network
#
#                                url concentration unit  value
# 0  http://www.spartan-network.org/              hours    1.0
# 1  http://www.spartan-network.org/              hours    1.0
# 2  http://www.spartan-network.org/              hours    1.0
# 3  http://www.spartan-network.org/              hours    1.0
# 4  http://www.spartan-network.org/              hours    1.0

# %%
df_trans.rename(columns={df_trans.columns[15]: 'averaging time unit'}, inplace=True)

# %%
df_trans.rename(columns={df_trans.columns[13]: 'source'}, inplace=True)

# %%
df_trans.head()
# Out:
#   parameter                location  value concentration unit  \
# 0      pm25  SPARTAN - Mammoth Cave    5.6              µg/m³
# 1      pm25  SPARTAN - Mammoth Cave    5.4              µg/m³
# 2      pm25  SPARTAN - Mammoth Cave    5.1              µg/m³
# 3      pm25  SPARTAN - Mammoth Cave    4.1              µg/m³
# 4      pm25  SPARTAN - Mammoth Cave    5.6              µg/m³
#
#               city country sourcename sourcetype  mobile latitude  longitude  \
# 0  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 1  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 2  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 3  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 4  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
#
#                         utc                      local           source  \
# 0  2014-07-17T01:00:00.000Z  2014-07-16T21:00:00-04:00  SPARTAN Network
# 1  2014-07-17T02:00:00.000Z  2014-07-16T22:00:00-04:00  SPARTAN Network
# 2  2014-07-17T00:00:00.000Z  2014-07-16T20:00:00-04:00  SPARTAN Network
# 3  2014-07-16T22:00:00.000Z  2014-07-16T18:00:00-04:00  SPARTAN Network
# 4  2014-07-16T16:00:00.000Z  2014-07-16T12:00:00-04:00  SPARTAN Network
#
#                                url concentration unit  value
# 0  http://www.spartan-network.org/              hours    1.0
# 1  http://www.spartan-network.org/              hours    1.0
# 2  http://www.spartan-network.org/              hours    1.0
# 3  http://www.spartan-network.org/              hours    1.0
# 4  http://www.spartan-network.org/              hours    1.0

# %%
df_trans.rename(columns={df_trans.columns[16]: 'averaging time'},inplace=True)

# %%
df_trans.head()
# Out:
#   parameter                location  value averaging time unit  \
# 0      pm25  SPARTAN - Mammoth Cave    5.6               µg/m³
# 1      pm25  SPARTAN - Mammoth Cave    5.4               µg/m³
# 2      pm25  SPARTAN - Mammoth Cave    5.1               µg/m³
# 3      pm25  SPARTAN - Mammoth Cave    4.1               µg/m³
# 4      pm25  SPARTAN - Mammoth Cave    5.6               µg/m³
#
#               city country sourcename sourcetype  mobile latitude  longitude  \
# 0  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 1  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 2  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 3  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
# 4  Mammoth Cave NP      US    Spartan   research   False   37.132    -86.148
#
#                         utc                      local           source  \
# 0  2014-07-17T01:00:00.000Z  2014-07-16T21:00:00-04:00  SPARTAN Network
# 1  2014-07-17T02:00:00.000Z  2014-07-16T22:00:00-04:00  SPARTAN Network
# 2  2014-07-17T00:00:00.000Z  2014-07-16T20:00:00-04:00  SPARTAN Network
# 3  2014-07-16T22:00:00.000Z  2014-07-16T18:00:00-04:00  SPARTAN Network
# 4  2014-07-16T16:00:00.000Z  2014-07-16T12:00:00-04:00  SPARTAN Network
#
#                                url averaging time unit averaging time
# 0  http://www.spartan-network.org/               hours            1.0
# 1  http://www.spartan-network.org/               hours            1.0
# 2  http://www.spartan-network.org/               hours            1.0
# 3  http://www.spartan-network.org/               hours            1.0
# 4  http://www.spartan-network.org/               hours            1.0

# %%
df_trans.to_csv('2014 AQ Clean.csv', index=False)
