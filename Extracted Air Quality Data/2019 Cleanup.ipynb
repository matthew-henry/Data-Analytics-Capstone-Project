# %% [markdown]
# # Cleanup and Exploration of 2019 AQ Data

# %%
import pandas as pd
import json as json

# %%
df = pd.read_csv('2019 AQ.csv')

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 1  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
# 2  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 3  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...       so2
# 4  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
#
#          location  value   unit         city  \
# 0          Ashton  0.021    ppm   Walterboro
# 1          Ashton  3.000  µg/m³   Walterboro
# 2  Congaree Bluff  0.026    ppm     Columbia
# 3  Congaree Bluff  0.000    ppm     Columbia
# 4        TK Gregg  1.200  µg/m³  Spartanburg
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                               coordinates country sourcename  sourcetype  \
# 0   {latitude=33.0078, longitude=-80.965}      US     AirNow  government
# 1   {latitude=33.0078, longitude=-80.965}      US     AirNow  government
# 2  {latitude=33.8147, longitude=-80.7811}      US     AirNow  government
# 3  {latitude=33.8147, longitude=-80.7811}      US     AirNow  government
# 4  {latitude=34.9556, longitude=-81.9248}      US     AirNow  government
#
#    mobile
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False

# %% [markdown]
# The entry is not valid json.  The field will need processing code.

# %%
def validate_json_fields(field: str) -> bool:
    """This function validates a JSON entry is valid.  Returns True if so, False if otherwise."""
    try:
        json.loads(field)
        return True
    except ValueError:
        return False

# %%
def validate_json_column(series: pd.Series):
    temp_df = pd.DataFrame()
    temp_df['values'] = series
    temp_df['validity'] = series.apply(validate_json_fields)
    return temp_df

# %% [markdown]
# ## Validation of composite fields as json

# %%
output = validate_json_column(df['date'])

# %%
output.head()
# Out:
#                                               values  validity
# 0  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...     False
# 1  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...     False
# 2  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...     False
# 3  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...     False
# 4  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['attribution'])
output.head()
# Out:
#                                               values  validity
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...     False
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...     False
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...     False
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...     False
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['averagingperiod'])
output.head()
# Out:
#                     values  validity
# 0  {unit=hours, value=1.0}     False
# 1  {unit=hours, value=1.0}     False
# 2  {unit=hours, value=1.0}     False
# 3  {unit=hours, value=1.0}     False
# 4  {unit=hours, value=1.0}     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
output = validate_json_column(df['coordinates'])
output.head()
# Out:
#                                    values  validity
# 0   {latitude=33.0078, longitude=-80.965}     False
# 1   {latitude=33.0078, longitude=-80.965}     False
# 2  {latitude=33.8147, longitude=-80.7811}     False
# 3  {latitude=33.8147, longitude=-80.7811}     False
# 4  {latitude=34.9556, longitude=-81.9248}     False

# %%
output[output['validity'] == True].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %% [markdown]
# All of the composite fields are in a "JSON-like format"  need to convert to JSON.

# %% [markdown]
# ## Reprocessing the Multivalue Fields into Valid JSON

# %%
def correct_field_to_json(arg: str) -> str:
    string = arg.lstrip("{{")
    string = string.rstrip("]}")
    strings = string.split(",")
    new_strings = []
    for entry in strings:
        index = entry.find('=')
        entry = '"' + entry[0:index] + '"' + ':' + '"'+ entry[index+1:len(entry)]+'"'
        new_strings.append(entry)
    output_string = (',').join(entry for entry in new_strings)
    output_string = '{' + output_string + '}'
    return output_string

# %%
def correct_json_column(series: pd.Series, column_name: str) -> pd.DataFrame:
    temp_df = pd.DataFrame()
    temp_df[column_name] = series.apply(correct_field_to_json)
    return temp_df

# %%
test = correct_json_column(df['date'], 'test date conversion')
results = validate_json_column(test['test date conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleaneddate'] = test

# %%
test = correct_json_column(df['attribution'], 'test attribute conversion')
results = validate_json_column(test['test attribute conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
results.head()
# Out:
#                                               values  validity
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...      True
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...      True
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...      True
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...      True
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...      True

# %%
df['cleanedattribution'] = test

# %%
test = correct_json_column(df['averagingperiod'], 'test averaging period conversion')
results = validate_json_column(test['test averaging period conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleanedaveragingperiod'] = test

# %%
test = correct_json_column(df['coordinates'], 'test coordinate conversion')
results = validate_json_column(test['test coordinate conversion'])
results[results['validity'] == False].describe()
# Out:
#        values validity
# count       0        0
# unique      0        0
# top       NaN      NaN
# freq      NaN      NaN

# %%
df['cleanedcoordinates'] = test

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 1  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
# 2  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 3  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...       so2
# 4  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
#
#          location  value   unit         city  \
# 0          Ashton  0.021    ppm   Walterboro
# 1          Ashton  3.000  µg/m³   Walterboro
# 2  Congaree Bluff  0.026    ppm     Columbia
# 3  Congaree Bluff  0.000    ppm     Columbia
# 4        TK Gregg  1.200  µg/m³  Spartanburg
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                               coordinates country sourcename  sourcetype  \
# 0   {latitude=33.0078, longitude=-80.965}      US     AirNow  government
# 1   {latitude=33.0078, longitude=-80.965}      US     AirNow  government
# 2  {latitude=33.8147, longitude=-80.7811}      US     AirNow  government
# 3  {latitude=33.8147, longitude=-80.7811}      US     AirNow  government
# 4  {latitude=34.9556, longitude=-81.9248}      US     AirNow  government
#
#    mobile                                        cleaneddate  \
# 0   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 1   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 2   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 3   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 4   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                cleanedcoordinates
# 0   {"latitude":"33.0078"," longitude":"-80.965"}
# 1   {"latitude":"33.0078"," longitude":"-80.965"}
# 2  {"latitude":"33.8147"," longitude":"-80.7811"}
# 3  {"latitude":"33.8147"," longitude":"-80.7811"}
# 4  {"latitude":"34.9556"," longitude":"-81.9248"}

# %%
import ujson as ujson

# %%
#df_trans = pd.concat([df_trans, df_trans.cleanedcoordinates.apply(json.loads).apply(pd.Series)], axis = 1)
expanded_datascope = df['cleanedcoordinates'].apply(ujson.loads)
expanded_datascope = pd.json_normalize(expanded_datascope)
df = pd.concat([df, expanded_datascope], axis =1)

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 1  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
# 2  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 3  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...       so2
# 4  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
#
#          location  value   unit         city  \
# 0          Ashton  0.021    ppm   Walterboro
# 1          Ashton  3.000  µg/m³   Walterboro
# 2  Congaree Bluff  0.026    ppm     Columbia
# 3  Congaree Bluff  0.000    ppm     Columbia
# 4        TK Gregg  1.200  µg/m³  Spartanburg
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                               coordinates country sourcename  sourcetype  \
# 0   {latitude=33.0078, longitude=-80.965}      US     AirNow  government
# 1   {latitude=33.0078, longitude=-80.965}      US     AirNow  government
# 2  {latitude=33.8147, longitude=-80.7811}      US     AirNow  government
# 3  {latitude=33.8147, longitude=-80.7811}      US     AirNow  government
# 4  {latitude=34.9556, longitude=-81.9248}      US     AirNow  government
#
#    mobile                                        cleaneddate  \
# 0   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 1   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 2   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 3   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 4   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                cleanedcoordinates latitude  longitude
# 0   {"latitude":"33.0078"," longitude":"-80.965"}  33.0078    -80.965
# 1   {"latitude":"33.0078"," longitude":"-80.965"}  33.0078    -80.965
# 2  {"latitude":"33.8147"," longitude":"-80.7811"}  33.8147   -80.7811
# 3  {"latitude":"33.8147"," longitude":"-80.7811"}  33.8147   -80.7811
# 4  {"latitude":"34.9556"," longitude":"-81.9248"}  34.9556   -81.9248

# %%
#df_trans = pd.concat([df_trans, df_trans.cleaneddate.apply(ujson.loads).apply(pd.Series)], axis = 1)
expanded_datascope = df['cleaneddate'].apply(ujson.loads)
expanded_datascope = pd.json_normalize(expanded_datascope)
df = pd.concat([df, expanded_datascope], axis =1)

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 1  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
# 2  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 3  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...       so2
# 4  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
#
#          location  value   unit         city  \
# 0          Ashton  0.021    ppm   Walterboro
# 1          Ashton  3.000  µg/m³   Walterboro
# 2  Congaree Bluff  0.026    ppm     Columbia
# 3  Congaree Bluff  0.000    ppm     Columbia
# 4        TK Gregg  1.200  µg/m³  Spartanburg
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                               coordinates country  ...  sourcetype mobile  \
# 0   {latitude=33.0078, longitude=-80.965}      US  ...  government  False
# 1   {latitude=33.0078, longitude=-80.965}      US  ...  government  False
# 2  {latitude=33.8147, longitude=-80.7811}      US  ...  government  False
# 3  {latitude=33.8147, longitude=-80.7811}      US  ...  government  False
# 4  {latitude=34.9556, longitude=-81.9248}      US  ...  government  False
#
#                                          cleaneddate  \
# 0  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 1  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 2  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 3  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
# 4  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...
#
#                                   cleanedattribution  \
# 0  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 1  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 2  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 3  {"[{name":"US EPA AirNow"," url":"http://www.a...
# 4  {"[{name":"US EPA AirNow"," url":"http://www.a...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                cleanedcoordinates latitude  longitude  \
# 0   {"latitude":"33.0078"," longitude":"-80.965"}  33.0078    -80.965
# 1   {"latitude":"33.0078"," longitude":"-80.965"}  33.0078    -80.965
# 2  {"latitude":"33.8147"," longitude":"-80.7811"}  33.8147   -80.7811
# 3  {"latitude":"33.8147"," longitude":"-80.7811"}  33.8147   -80.7811
# 4  {"latitude":"34.9556"," longitude":"-81.9248"}  34.9556   -81.9248
#
#                         utc                      local
# 0  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 1  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 2  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 3  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 4  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
#
# [5 rows x 21 columns]

# %%
#df_trans = pd.concat([df_trans, df_trans.cleanedattribution.apply(json.loads).apply(pd.Series)], axis = 1) This line is EXTREMELY SLOW TRYING TO OPTIMIZE.
expanded_datascope = df['cleanedattribution'].apply(ujson.loads)
expanded_datascope = pd.json_normalize(expanded_datascope)
df = pd.concat([df, expanded_datascope], axis =1)

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 1  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
# 2  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 3  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...       so2
# 4  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
#
#          location  value   unit         city  \
# 0          Ashton  0.021    ppm   Walterboro
# 1          Ashton  3.000  µg/m³   Walterboro
# 2  Congaree Bluff  0.026    ppm     Columbia
# 3  Congaree Bluff  0.000    ppm     Columbia
# 4        TK Gregg  1.200  µg/m³  Spartanburg
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                               coordinates country  ...  \
# 0   {latitude=33.0078, longitude=-80.965}      US  ...
# 1   {latitude=33.0078, longitude=-80.965}      US  ...
# 2  {latitude=33.8147, longitude=-80.7811}      US  ...
# 3  {latitude=33.8147, longitude=-80.7811}      US  ...
# 4  {latitude=34.9556, longitude=-81.9248}      US  ...
#
#                                cleanedcoordinates latitude   longitude  \
# 0   {"latitude":"33.0078"," longitude":"-80.965"}  33.0078     -80.965
# 1   {"latitude":"33.0078"," longitude":"-80.965"}  33.0078     -80.965
# 2  {"latitude":"33.8147"," longitude":"-80.7811"}  33.8147    -80.7811
# 3  {"latitude":"33.8147"," longitude":"-80.7811"}  33.8147    -80.7811
# 4  {"latitude":"34.9556"," longitude":"-81.9248"}  34.9556    -81.9248
#
#                         utc                      local         [{name   url  \
# 0  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 1  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 2  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 3  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 4  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
#
#                  {name  Great Lake  and Energ
# 0  South Carolina DHEC         NaN        NaN
# 1  South Carolina DHEC         NaN        NaN
# 2  South Carolina DHEC         NaN        NaN
# 3  South Carolina DHEC         NaN        NaN
# 4  South Carolina DHEC         NaN        NaN
#
# [5 rows x 26 columns]

# %%
df.drop(' {name', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 1  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
# 2  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 3  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...       so2
# 4  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
#
#          location  value   unit         city  \
# 0          Ashton  0.021    ppm   Walterboro
# 1          Ashton  3.000  µg/m³   Walterboro
# 2  Congaree Bluff  0.026    ppm     Columbia
# 3  Congaree Bluff  0.000    ppm     Columbia
# 4        TK Gregg  1.200  µg/m³  Spartanburg
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                               coordinates country  ...  \
# 0   {latitude=33.0078, longitude=-80.965}      US  ...
# 1   {latitude=33.0078, longitude=-80.965}      US  ...
# 2  {latitude=33.8147, longitude=-80.7811}      US  ...
# 3  {latitude=33.8147, longitude=-80.7811}      US  ...
# 4  {latitude=34.9556, longitude=-81.9248}      US  ...
#
#             cleanedaveragingperiod  \
# 0  {"unit":"hours"," value":"1.0"}
# 1  {"unit":"hours"," value":"1.0"}
# 2  {"unit":"hours"," value":"1.0"}
# 3  {"unit":"hours"," value":"1.0"}
# 4  {"unit":"hours"," value":"1.0"}
#
#                                cleanedcoordinates  latitude  longitude  \
# 0   {"latitude":"33.0078"," longitude":"-80.965"}   33.0078    -80.965
# 1   {"latitude":"33.0078"," longitude":"-80.965"}   33.0078    -80.965
# 2  {"latitude":"33.8147"," longitude":"-80.7811"}   33.8147   -80.7811
# 3  {"latitude":"33.8147"," longitude":"-80.7811"}   33.8147   -80.7811
# 4  {"latitude":"34.9556"," longitude":"-81.9248"}   34.9556   -81.9248
#
#                         utc                      local         [{name   url  \
# 0  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 1  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 2  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 3  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 4  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
#
#    Great Lake  and Energ
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN
#
# [5 rows x 25 columns]

# %%
#df_trans = pd.concat([df_trans, df_trans.cleanedaveragingperiod.apply(json.loads).apply(pd.Series)], axis = 1)
expanded_datascope = df['cleanedaveragingperiod'].apply(ujson.loads)
expanded_datascope = pd.json_normalize(expanded_datascope)
df = pd.concat([df, expanded_datascope], axis =1)

# %%
df.head()
# Out:
#                                                 date parameter  \
# 0  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 1  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
# 2  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...        o3
# 3  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...       so2
# 4  {utc=2019-01-02T18:00:00.000Z, local=2019-01-0...      pm25
#
#          location  value   unit         city  \
# 0          Ashton  0.021    ppm   Walterboro
# 1          Ashton  3.000  µg/m³   Walterboro
# 2  Congaree Bluff  0.026    ppm     Columbia
# 3  Congaree Bluff  0.000    ppm     Columbia
# 4        TK Gregg  1.200  µg/m³  Spartanburg
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                               coordinates country  ... latitude  longitude  \
# 0   {latitude=33.0078, longitude=-80.965}      US  ...  33.0078    -80.965
# 1   {latitude=33.0078, longitude=-80.965}      US  ...  33.0078    -80.965
# 2  {latitude=33.8147, longitude=-80.7811}      US  ...  33.8147   -80.7811
# 3  {latitude=33.8147, longitude=-80.7811}      US  ...  33.8147   -80.7811
# 4  {latitude=34.9556, longitude=-81.9248}      US  ...  34.9556   -81.9248
#
#                         utc                      local         [{name   url  \
# 0  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 1  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 2  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 3  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 4  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
#
#    Great Lake  and Energ   unit  value
# 0         NaN        NaN  hours    1.0
# 1         NaN        NaN  hours    1.0
# 2         NaN        NaN  hours    1.0
# 3         NaN        NaN  hours    1.0
# 4         NaN        NaN  hours    1.0
#
# [5 rows x 27 columns]

# %%
df.drop('date', axis =1, inplace=True)

# %%
df.head()
# Out:
#   parameter        location  value   unit         city  \
# 0        o3          Ashton  0.021    ppm   Walterboro
# 1      pm25          Ashton  3.000  µg/m³   Walterboro
# 2        o3  Congaree Bluff  0.026    ppm     Columbia
# 3       so2  Congaree Bluff  0.000    ppm     Columbia
# 4      pm25        TK Gregg  1.200  µg/m³  Spartanburg
#
#                                          attribution          averagingperiod  \
# 0  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 1  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 2  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 3  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
# 4  [{name=US EPA AirNow, url=http://www.airnow.go...  {unit=hours, value=1.0}
#
#                               coordinates country sourcename  ... latitude  \
# 0   {latitude=33.0078, longitude=-80.965}      US     AirNow  ...  33.0078
# 1   {latitude=33.0078, longitude=-80.965}      US     AirNow  ...  33.0078
# 2  {latitude=33.8147, longitude=-80.7811}      US     AirNow  ...  33.8147
# 3  {latitude=33.8147, longitude=-80.7811}      US     AirNow  ...  33.8147
# 4  {latitude=34.9556, longitude=-81.9248}      US     AirNow  ...  34.9556
#
#     longitude                       utc                      local  \
# 0     -80.965  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 1     -80.965  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 2    -80.7811  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 3    -80.7811  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 4    -81.9248  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
#
#           [{name   url  Great Lake  and Energ   unit  value
# 0  US EPA AirNow  null         NaN        NaN  hours    1.0
# 1  US EPA AirNow  null         NaN        NaN  hours    1.0
# 2  US EPA AirNow  null         NaN        NaN  hours    1.0
# 3  US EPA AirNow  null         NaN        NaN  hours    1.0
# 4  US EPA AirNow  null         NaN        NaN  hours    1.0
#
# [5 rows x 26 columns]

# %%
df.drop(['attribution','averagingperiod','coordinates','cleanedaveragingperiod','cleanedcoordinates'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#   parameter        location  value   unit         city country sourcename  \
# 0        o3          Ashton  0.021    ppm   Walterboro      US     AirNow
# 1      pm25          Ashton  3.000  µg/m³   Walterboro      US     AirNow
# 2        o3  Congaree Bluff  0.026    ppm     Columbia      US     AirNow
# 3       so2  Congaree Bluff  0.000    ppm     Columbia      US     AirNow
# 4      pm25        TK Gregg  1.200  µg/m³  Spartanburg      US     AirNow
#
#    sourcetype  mobile                                        cleaneddate  ...  \
# 0  government   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...  ...
# 1  government   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...  ...
# 2  government   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...  ...
# 3  government   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...  ...
# 4  government   False  {"utc":"2019-01-02T18:00:00.000Z"," local":"20...  ...
#
#   latitude  longitude                       utc                      local  \
# 0  33.0078    -80.965  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 1  33.0078    -80.965  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 2  33.8147   -80.7811  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 3  33.8147   -80.7811  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
# 4  34.9556   -81.9248  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00
#
#           [{name   url  Great Lake  and Energ   unit  value
# 0  US EPA AirNow  null         NaN        NaN  hours    1.0
# 1  US EPA AirNow  null         NaN        NaN  hours    1.0
# 2  US EPA AirNow  null         NaN        NaN  hours    1.0
# 3  US EPA AirNow  null         NaN        NaN  hours    1.0
# 4  US EPA AirNow  null         NaN        NaN  hours    1.0
#
# [5 rows x 21 columns]

# %%
df.drop(['cleaneddate','cleanedattribution'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#   parameter        location  value   unit         city country sourcename  \
# 0        o3          Ashton  0.021    ppm   Walterboro      US     AirNow
# 1      pm25          Ashton  3.000  µg/m³   Walterboro      US     AirNow
# 2        o3  Congaree Bluff  0.026    ppm     Columbia      US     AirNow
# 3       so2  Congaree Bluff  0.000    ppm     Columbia      US     AirNow
# 4      pm25        TK Gregg  1.200  µg/m³  Spartanburg      US     AirNow
#
#    sourcetype  mobile latitude  longitude                       utc  \
# 0  government   False  33.0078    -80.965  2019-01-02T18:00:00.000Z
# 1  government   False  33.0078    -80.965  2019-01-02T18:00:00.000Z
# 2  government   False  33.8147   -80.7811  2019-01-02T18:00:00.000Z
# 3  government   False  33.8147   -80.7811  2019-01-02T18:00:00.000Z
# 4  government   False  34.9556   -81.9248  2019-01-02T18:00:00.000Z
#
#                        local         [{name   url  Great Lake  and Energ  \
# 0  2019-01-02T13:00:00-05:00  US EPA AirNow  null         NaN        NaN
# 1  2019-01-02T13:00:00-05:00  US EPA AirNow  null         NaN        NaN
# 2  2019-01-02T13:00:00-05:00  US EPA AirNow  null         NaN        NaN
# 3  2019-01-02T13:00:00-05:00  US EPA AirNow  null         NaN        NaN
# 4  2019-01-02T13:00:00-05:00  US EPA AirNow  null         NaN        NaN
#
#     unit  value
# 0  hours    1.0
# 1  hours    1.0
# 2  hours    1.0
# 3  hours    1.0
# 4  hours    1.0

# %%
#df_trans.rename(columns={df_trans.columns[15]: 'averaging time unit'}, inplace=True)
df.columns.values[3]='concentration unit'

# %%
df.head()
# Out:
#   parameter        location  value concentration unit         city country  \
# 0        o3          Ashton  0.021                ppm   Walterboro      US
# 1      pm25          Ashton  3.000              µg/m³   Walterboro      US
# 2        o3  Congaree Bluff  0.026                ppm     Columbia      US
# 3       so2  Congaree Bluff  0.000                ppm     Columbia      US
# 4      pm25        TK Gregg  1.200              µg/m³  Spartanburg      US
#
#   sourcename  sourcetype  mobile latitude  longitude  \
# 0     AirNow  government   False  33.0078    -80.965
# 1     AirNow  government   False  33.0078    -80.965
# 2     AirNow  government   False  33.8147   -80.7811
# 3     AirNow  government   False  33.8147   -80.7811
# 4     AirNow  government   False  34.9556   -81.9248
#
#                         utc                      local         [{name   url  \
# 0  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 1  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 2  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 3  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 4  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
#
#    Great Lake  and Energ   unit  value
# 0         NaN        NaN  hours    1.0
# 1         NaN        NaN  hours    1.0
# 2         NaN        NaN  hours    1.0
# 3         NaN        NaN  hours    1.0
# 4         NaN        NaN  hours    1.0

# %%
#df_trans.rename(columns={df_trans.columns[15]: 'averaging time unit'}, inplace=True)
df.columns.values[15] = 'averaging time unit'

# %%
#df_trans.rename(columns={df_trans.columns[13]: 'source'}, inplace=True)
df.columns.values[13] = 'source'

# %%
df.head()
# Out:
#   parameter        location  value concentration unit         city country  \
# 0        o3          Ashton  0.021                ppm   Walterboro      US
# 1      pm25          Ashton  3.000              µg/m³   Walterboro      US
# 2        o3  Congaree Bluff  0.026                ppm     Columbia      US
# 3       so2  Congaree Bluff  0.000                ppm     Columbia      US
# 4      pm25        TK Gregg  1.200              µg/m³  Spartanburg      US
#
#   sourcename  sourcetype  mobile latitude  longitude  \
# 0     AirNow  government   False  33.0078    -80.965
# 1     AirNow  government   False  33.0078    -80.965
# 2     AirNow  government   False  33.8147   -80.7811
# 3     AirNow  government   False  33.8147   -80.7811
# 4     AirNow  government   False  34.9556   -81.9248
#
#                         utc                      local         source   url  \
# 0  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 1  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 2  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 3  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 4  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
#
#   averaging time unit  and Energ   unit  value
# 0                 NaN        NaN  hours    1.0
# 1                 NaN        NaN  hours    1.0
# 2                 NaN        NaN  hours    1.0
# 3                 NaN        NaN  hours    1.0
# 4                 NaN        NaN  hours    1.0

# %%
#df_trans.rename(columns={df_trans.columns[16]: 'averaging time'},inplace=True)
df.columns.values[16] = 'averaging time'

# %%
df.head()
# Out:
#   parameter        location  value concentration unit         city country  \
# 0        o3          Ashton  0.021                ppm   Walterboro      US
# 1      pm25          Ashton  3.000              µg/m³   Walterboro      US
# 2        o3  Congaree Bluff  0.026                ppm     Columbia      US
# 3       so2  Congaree Bluff  0.000                ppm     Columbia      US
# 4      pm25        TK Gregg  1.200              µg/m³  Spartanburg      US
#
#   sourcename  sourcetype  mobile latitude  longitude  \
# 0     AirNow  government   False  33.0078    -80.965
# 1     AirNow  government   False  33.0078    -80.965
# 2     AirNow  government   False  33.8147   -80.7811
# 3     AirNow  government   False  33.8147   -80.7811
# 4     AirNow  government   False  34.9556   -81.9248
#
#                         utc                      local         source   url  \
# 0  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 1  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 2  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 3  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 4  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
#
#   averaging time unit averaging time   unit  value
# 0                 NaN            NaN  hours    1.0
# 1                 NaN            NaN  hours    1.0
# 2                 NaN            NaN  hours    1.0
# 3                 NaN            NaN  hours    1.0
# 4                 NaN            NaN  hours    1.0

# %%
df.to_csv('2019 AQ Clean.csv', index=False)

# %%
df.drop(['averaging time unit', 'averaging time'], axis =1, inplace=True)

# %%
df.head()
# Out:
#   parameter        location  value concentration unit         city country  \
# 0        o3          Ashton  0.021                ppm   Walterboro      US
# 1      pm25          Ashton  3.000              µg/m³   Walterboro      US
# 2        o3  Congaree Bluff  0.026                ppm     Columbia      US
# 3       so2  Congaree Bluff  0.000                ppm     Columbia      US
# 4      pm25        TK Gregg  1.200              µg/m³  Spartanburg      US
#
#   sourcename  sourcetype  mobile latitude  longitude  \
# 0     AirNow  government   False  33.0078    -80.965
# 1     AirNow  government   False  33.0078    -80.965
# 2     AirNow  government   False  33.8147   -80.7811
# 3     AirNow  government   False  33.8147   -80.7811
# 4     AirNow  government   False  34.9556   -81.9248
#
#                         utc                      local         source   url  \
# 0  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 1  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 2  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 3  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 4  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
#
#     unit  value
# 0  hours    1.0
# 1  hours    1.0
# 2  hours    1.0
# 3  hours    1.0
# 4  hours    1.0

# %%
df.columns.values[15] = 'averaging time unit'
df.columns.values[16] = 'averaging time'
df.head()
# Out:
#   parameter        location  value concentration unit         city country  \
# 0        o3          Ashton  0.021                ppm   Walterboro      US
# 1      pm25          Ashton  3.000              µg/m³   Walterboro      US
# 2        o3  Congaree Bluff  0.026                ppm     Columbia      US
# 3       so2  Congaree Bluff  0.000                ppm     Columbia      US
# 4      pm25        TK Gregg  1.200              µg/m³  Spartanburg      US
#
#   sourcename  sourcetype  mobile latitude  longitude  \
# 0     AirNow  government   False  33.0078    -80.965
# 1     AirNow  government   False  33.0078    -80.965
# 2     AirNow  government   False  33.8147   -80.7811
# 3     AirNow  government   False  33.8147   -80.7811
# 4     AirNow  government   False  34.9556   -81.9248
#
#                         utc                      local         source   url  \
# 0  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 1  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 2  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 3  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
# 4  2019-01-02T18:00:00.000Z  2019-01-02T13:00:00-05:00  US EPA AirNow  null
#
#   averaging time unit averaging time
# 0               hours            1.0
# 1               hours            1.0
# 2               hours            1.0
# 3               hours            1.0
# 4               hours            1.0

# %%
df.to_csv('2019 AQ Clean.csv', index=False)
